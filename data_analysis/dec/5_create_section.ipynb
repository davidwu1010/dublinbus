# %% [markdown]
# # 1. Introduction

# %% [markdown]
# The purpose of this notebook is to create initial cleaning of the section data, and to export the cleaned data to a csv file.

# %% [markdown]
# # 2. Setup & Data Load

# %% [markdown]
# Import required modules and packages:

# %%
# import pandas for data analysis
import pandas as pd

#import numpy
import numpy as np

# %%
import gc
gc.collect()
# Out:
# 22

# %% [markdown]
# ### load leavetime

# %%
df_leaveTime=pd.read_csv("../clean_data/leavetime_DEC.csv",index_col=0)
df_leaveTime
# Out:
# D:\Software\Anaconda\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-12-01  8132169            1          807            27000
# 1         2018-12-01  8132169            2          808            27062
# 2         2018-12-01  8132169            3          809            27098
# 3         2018-12-01  8132169            4          810            27156
# 4         2018-12-01  8132169            5          811            27193
# ...              ...      ...          ...          ...              ...
# 5645900   2018-12-20  8463889           16          528            54716
# 5645901   2018-12-20  8463889           17          529            54754
# 5645902   2018-12-20  8463889           18          530            54798
# 5645903   2018-12-20  8463889           19          531            54850
# 5645904   2018-12-20  8463889           20          709            54909
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID
# 0                 27106           27106    2868382
# 1                 27147           27156    2868382
# 2                 27182           27222    2868382
# 3                 27258           27267    2868382
# 4                 27309           27309    2868382
# ...                 ...             ...        ...
# 5645900           54872           54872    3265691
# 5645901           54915           54926    3265691
# 5645902           54962           54962    3265691
# 5645903           54991           54991    3265691
# 5645904           55038           55049    3265691
#
# [5494579 rows x 8 columns]

# %%
df_leaveTime.sort_values(by=['DayOfService','TripID','ProgrNumber'],ascending=[True,True,True])
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-12-01  8132169            1          807            27000
# 1         2018-12-01  8132169            2          808            27062
# 2         2018-12-01  8132169            3          809            27098
# 3         2018-12-01  8132169            4          810            27156
# 4         2018-12-01  8132169            5          811            27193
# ...              ...      ...          ...          ...              ...
# 5645900   2018-12-20  8463889           16          528            54716
# 5645901   2018-12-20  8463889           17          529            54754
# 5645902   2018-12-20  8463889           18          530            54798
# 5645903   2018-12-20  8463889           19          531            54850
# 5645904   2018-12-20  8463889           20          709            54909
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID
# 0                 27106           27106    2868382
# 1                 27147           27156    2868382
# 2                 27182           27222    2868382
# 3                 27258           27267    2868382
# 4                 27309           27309    2868382
# ...                 ...             ...        ...
# 5645900           54872           54872    3265691
# 5645901           54915           54926    3265691
# 5645902           54962           54962    3265691
# 5645903           54991           54991    3265691
# 5645904           55038           55049    3265691
#
# [5494579 rows x 8 columns]

# %%
df_leaveTime.columns
# Out:
# Index(['DayOfService', 'TripID', 'ProgrNumber', 'StopPointID',
#        'PlannedTime_Arr', 'ActualTime_Arr', 'ActualTime_Dep', 'VehicleID'],
#       dtype='object')

# %% [markdown]
# ### load trips

# %%
df_trips=pd.read_csv("../initial_data/RT_Trips.csv",index_col=0)
df_trips
# Out:
# D:\Software\Anaconda\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#         ActualTime_Arr  ActualTime_Dep DayOfService Direction  LineID  \
# 0           2018-01-01         5955277           16     16_20       1
# 1           2018-01-01         5955278           16     16_24       2
# 2           2018-01-01         5955279           16     16_20       1
# 3           2018-01-01         5955280           16     16_24       2
# 4           2018-01-01         5955281           16     16_20       1
# ...                ...             ...          ...       ...     ...
# 2182632     2018-12-31         8592110           11     11_42       2
# 2182633     2018-12-31         8592113           7A     7A_85       1
# 2182634     2018-12-31         8592114           7A     7A_87       2
# 2182635     2018-12-31         8592115           7A     7A_85       1
# 2182636     2018-12-31         8592116           7A     7A_87       2
#
#          PlannedTime_Arr  PlannedTime_Dep  RouteID   TripID
# 0                  30000            33932  30029.0  33184.0
# 1                  36000            40588  35865.0  39653.0
# 2                  42000            47365  41980.0  46619.0
# 3                  48000            53590  48008.0  53790.0
# 4                  54000            59288  54221.0  59344.0
# ...                  ...              ...      ...      ...
# 2182632            75600            78677  75659.0  79491.0
# 2182633            38700            42098  38607.0  42454.0
# 2182634            44100            48149  43990.0  48039.0
# 2182635            49500            52723  49622.0  54138.0
# 2182636            54900            58565  54905.0  59262.0
#
# [2182637 rows x 9 columns]

# %%
df_trips.columns=['DayOfService','TripID','LineID','RouteID','Direction','PlannedTime_Dep','PlannedTime_Arr','ActualTime_Dep','ActualTime_Arr']
df_trips
# Out:
#         DayOfService   TripID LineID RouteID  Direction  PlannedTime_Dep  \
# 0         2018-01-01  5955277     16   16_20          1            30000
# 1         2018-01-01  5955278     16   16_24          2            36000
# 2         2018-01-01  5955279     16   16_20          1            42000
# 3         2018-01-01  5955280     16   16_24          2            48000
# 4         2018-01-01  5955281     16   16_20          1            54000
# ...              ...      ...    ...     ...        ...              ...
# 2182632   2018-12-31  8592110     11   11_42          2            75600
# 2182633   2018-12-31  8592113     7A   7A_85          1            38700
# 2182634   2018-12-31  8592114     7A   7A_87          2            44100
# 2182635   2018-12-31  8592115     7A   7A_85          1            49500
# 2182636   2018-12-31  8592116     7A   7A_87          2            54900
#
#          PlannedTime_Arr  ActualTime_Dep  ActualTime_Arr
# 0                  33932         30029.0         33184.0
# 1                  40588         35865.0         39653.0
# 2                  47365         41980.0         46619.0
# 3                  53590         48008.0         53790.0
# 4                  59288         54221.0         59344.0
# ...                  ...             ...             ...
# 2182632            78677         75659.0         79491.0
# 2182633            42098         38607.0         42454.0
# 2182634            48149         43990.0         48039.0
# 2182635            52723         49622.0         54138.0
# 2182636            58565         54905.0         59262.0
#
# [2182637 rows x 9 columns]

# %%
df_trips_simple=df_trips[['DayOfService','TripID','LineID','RouteID']]
df_trips_simple
# Out:
#         DayOfService   TripID LineID RouteID
# 0         2018-01-01  5955277     16   16_20
# 1         2018-01-01  5955278     16   16_24
# 2         2018-01-01  5955279     16   16_20
# 3         2018-01-01  5955280     16   16_24
# 4         2018-01-01  5955281     16   16_20
# ...              ...      ...    ...     ...
# 2182632   2018-12-31  8592110     11   11_42
# 2182633   2018-12-31  8592113     7A   7A_85
# 2182634   2018-12-31  8592114     7A   7A_87
# 2182635   2018-12-31  8592115     7A   7A_85
# 2182636   2018-12-31  8592116     7A   7A_87
#
# [2182637 rows x 4 columns]

# %% [markdown]
# ### merge two dataset

# %%
section=pd.merge(df_leaveTime,df_trips_simple,how='left',on=['DayOfService','TripID'])
section
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-12-01  8132169            1          807            27000
# 1         2018-12-01  8132169            2          808            27062
# 2         2018-12-01  8132169            3          809            27098
# 3         2018-12-01  8132169            4          810            27156
# 4         2018-12-01  8132169            5          811            27193
# ...              ...      ...          ...          ...              ...
# 5494574   2018-12-20  8463889           16          528            54716
# 5494575   2018-12-20  8463889           17          529            54754
# 5494576   2018-12-20  8463889           18          530            54798
# 5494577   2018-12-20  8463889           19          531            54850
# 5494578   2018-12-20  8463889           20          709            54909
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID
# 0                 27106           27106    2868382    46A  46A_74
# 1                 27147           27156    2868382    46A  46A_74
# 2                 27182           27222    2868382    46A  46A_74
# 3                 27258           27267    2868382    46A  46A_74
# 4                 27309           27309    2868382    46A  46A_74
# ...                 ...             ...        ...    ...     ...
# 5494574           54872           54872    3265691    29A  29A_14
# 5494575           54915           54926    3265691    29A  29A_14
# 5494576           54962           54962    3265691    29A  29A_14
# 5494577           54991           54991    3265691    29A  29A_14
# 5494578           55038           55049    3265691    29A  29A_14
#
# [5494579 rows x 10 columns]

# %% [markdown]
# ### add previous stops

# %%
section_copy=section[['TripID','StopPointID','ActualTime_Arr']]
section_copy.columns=['TripID_2','StopPoint_2','ActualTime_Arr_2']
section_copy
# Out:
#          TripID_2  StopPoint_2  ActualTime_Arr_2
# 0         8132169          807             27106
# 1         8132169          808             27147
# 2         8132169          809             27182
# 3         8132169          810             27258
# 4         8132169          811             27309
# ...           ...          ...               ...
# 5494574   8463889          528             54872
# 5494575   8463889          529             54915
# 5494576   8463889          530             54962
# 5494577   8463889          531             54991
# 5494578   8463889          709             55038
#
# [5494579 rows x 3 columns]

# %%
section_copy.drop(axis=0, index=0,inplace=True)
section_copy
# Out:
# D:\Software\Anaconda\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#          TripID_2  StopPoint_2  ActualTime_Arr_2
# 1         8132169          808             27147
# 2         8132169          809             27182
# 3         8132169          810             27258
# 4         8132169          811             27309
# 5         8132169          812             27333
# ...           ...          ...               ...
# 5494574   8463889          528             54872
# 5494575   8463889          529             54915
# 5494576   8463889          530             54962
# 5494577   8463889          531             54991
# 5494578   8463889          709             55038
#
# [5494578 rows x 3 columns]

# %%
# add new rows
section_copy.loc['new_raw'] = '3'
section_copy
# Out:
# D:\Software\Anaconda\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#         TripID_2 StopPoint_2 ActualTime_Arr_2
# 1        8132169         808            27147
# 2        8132169         809            27182
# 3        8132169         810            27258
# 4        8132169         811            27309
# 5        8132169         812            27333
# ...          ...         ...              ...
# 5494575  8463889         529            54915
# 5494576  8463889         530            54962
# 5494577  8463889         531            54991
# 5494578  8463889         709            55038
# new_raw        3           3                3
#
# [5494579 rows x 3 columns]

# %%
# adject the index
section_copy.index=np.arange(0,5494579)
section_copy
# Out:
#         TripID_2 StopPoint_2 ActualTime_Arr_2
# 0        8132169         808            27147
# 1        8132169         809            27182
# 2        8132169         810            27258
# 3        8132169         811            27309
# 4        8132169         812            27333
# ...          ...         ...              ...
# 5494574  8463889         529            54915
# 5494575  8463889         530            54962
# 5494576  8463889         531            54991
# 5494577  8463889         709            55038
# 5494578        3           3                3
#
# [5494579 rows x 3 columns]

# %%
section_combine = pd.concat([section, section_copy], axis=1,ignore_index=True)

# %%
col_name=[]
for col in section.columns:
    col_name.append(col)
col_name.append('TripID_2')
col_name.append('StopPoint_2')
col_name.append('ActualTime_Arr_2')
col_name
# Out:
# ['DayOfService',
#  'TripID',
#  'ProgrNumber',
#  'StopPointID',
#  'PlannedTime_Arr',
#  'ActualTime_Arr',
#  'ActualTime_Dep',
#  'VehicleID',
#  'LineID',
#  'RouteID',
#  'TripID_2',
#  'StopPoint_2',
#  'ActualTime_Arr_2']

# %%
section_combine.columns=col_name
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-12-01  8132169            1          807            27000
# 1         2018-12-01  8132169            2          808            27062
# 2         2018-12-01  8132169            3          809            27098
# 3         2018-12-01  8132169            4          810            27156
# 4         2018-12-01  8132169            5          811            27193
# ...              ...      ...          ...          ...              ...
# 5494574   2018-12-20  8463889           16          528            54716
# 5494575   2018-12-20  8463889           17          529            54754
# 5494576   2018-12-20  8463889           18          530            54798
# 5494577   2018-12-20  8463889           19          531            54850
# 5494578   2018-12-20  8463889           20          709            54909
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 27106           27106    2868382    46A  46A_74  8132169
# 1                 27147           27156    2868382    46A  46A_74  8132169
# 2                 27182           27222    2868382    46A  46A_74  8132169
# 3                 27258           27267    2868382    46A  46A_74  8132169
# 4                 27309           27309    2868382    46A  46A_74  8132169
# ...                 ...             ...        ...    ...     ...      ...
# 5494574           54872           54872    3265691    29A  29A_14  8463889
# 5494575           54915           54926    3265691    29A  29A_14  8463889
# 5494576           54962           54962    3265691    29A  29A_14  8463889
# 5494577           54991           54991    3265691    29A  29A_14  8463889
# 5494578           55038           55049    3265691    29A  29A_14        3
#
#         StopPoint_2 ActualTime_Arr_2
# 0               808            27147
# 1               809            27182
# 2               810            27258
# 3               811            27309
# 4               812            27333
# ...             ...              ...
# 5494574         529            54915
# 5494575         530            54962
# 5494576         531            54991
# 5494577         709            55038
# 5494578           3                3
#
# [5494579 rows x 13 columns]

# %%
#drop the last rows
section_combine.drop(axis=0, index=5494578,inplace=True)
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-12-01  8132169            1          807            27000
# 1         2018-12-01  8132169            2          808            27062
# 2         2018-12-01  8132169            3          809            27098
# 3         2018-12-01  8132169            4          810            27156
# 4         2018-12-01  8132169            5          811            27193
# ...              ...      ...          ...          ...              ...
# 5494573   2018-12-20  8463889           15          527            54676
# 5494574   2018-12-20  8463889           16          528            54716
# 5494575   2018-12-20  8463889           17          529            54754
# 5494576   2018-12-20  8463889           18          530            54798
# 5494577   2018-12-20  8463889           19          531            54850
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 27106           27106    2868382    46A  46A_74  8132169
# 1                 27147           27156    2868382    46A  46A_74  8132169
# 2                 27182           27222    2868382    46A  46A_74  8132169
# 3                 27258           27267    2868382    46A  46A_74  8132169
# 4                 27309           27309    2868382    46A  46A_74  8132169
# ...                 ...             ...        ...    ...     ...      ...
# 5494573           54851           54851    3265691    29A  29A_14  8463889
# 5494574           54872           54872    3265691    29A  29A_14  8463889
# 5494575           54915           54926    3265691    29A  29A_14  8463889
# 5494576           54962           54962    3265691    29A  29A_14  8463889
# 5494577           54991           54991    3265691    29A  29A_14  8463889
#
#         StopPoint_2 ActualTime_Arr_2
# 0               808            27147
# 1               809            27182
# 2               810            27258
# 3               811            27309
# 4               812            27333
# ...             ...              ...
# 5494573         528            54872
# 5494574         529            54915
# 5494575         530            54962
# 5494576         531            54991
# 5494577         709            55038
#
# [5494578 rows x 13 columns]

# %%
section_combine['trip_q']=section_combine['TripID_2']-section_combine['TripID']

# %%
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-12-01  8132169            1          807            27000
# 1         2018-12-01  8132169            2          808            27062
# 2         2018-12-01  8132169            3          809            27098
# 3         2018-12-01  8132169            4          810            27156
# 4         2018-12-01  8132169            5          811            27193
# ...              ...      ...          ...          ...              ...
# 5494573   2018-12-20  8463889           15          527            54676
# 5494574   2018-12-20  8463889           16          528            54716
# 5494575   2018-12-20  8463889           17          529            54754
# 5494576   2018-12-20  8463889           18          530            54798
# 5494577   2018-12-20  8463889           19          531            54850
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 27106           27106    2868382    46A  46A_74  8132169
# 1                 27147           27156    2868382    46A  46A_74  8132169
# 2                 27182           27222    2868382    46A  46A_74  8132169
# 3                 27258           27267    2868382    46A  46A_74  8132169
# 4                 27309           27309    2868382    46A  46A_74  8132169
# ...                 ...             ...        ...    ...     ...      ...
# 5494573           54851           54851    3265691    29A  29A_14  8463889
# 5494574           54872           54872    3265691    29A  29A_14  8463889
# 5494575           54915           54926    3265691    29A  29A_14  8463889
# 5494576           54962           54962    3265691    29A  29A_14  8463889
# 5494577           54991           54991    3265691    29A  29A_14  8463889
#
#         StopPoint_2 ActualTime_Arr_2 trip_q
# 0               808            27147      0
# 1               809            27182      0
# 2               810            27258      0
# 3               811            27309      0
# 4               812            27333      0
# ...             ...              ...    ...
# 5494573         528            54872      0
# 5494574         529            54915      0
# 5494575         530            54962      0
# 5494576         531            54991      0
# 5494577         709            55038      0
#
# [5494578 rows x 14 columns]

# %%
section_combine['trip_q'].value_counts()
# Out:
#  0        5389966
#  1          91070
#  2           2551
#  3            973
#  5            714
#            ...
#  129            1
#  130            1
#  131            1
#  137            1
# -16385          1
# Name: trip_q, Length: 148, dtype: int64

# %%
# if trip_q !=0, we do not need it 
x=section_combine[section_combine['trip_q']==0]

# %%
x['TravelTime']=x['ActualTime_Arr_2']-x['ActualTime_Dep']
x
# Out:
# D:\Software\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-12-01  8132169            1          807            27000
# 1         2018-12-01  8132169            2          808            27062
# 2         2018-12-01  8132169            3          809            27098
# 3         2018-12-01  8132169            4          810            27156
# 4         2018-12-01  8132169            5          811            27193
# ...              ...      ...          ...          ...              ...
# 5494573   2018-12-20  8463889           15          527            54676
# 5494574   2018-12-20  8463889           16          528            54716
# 5494575   2018-12-20  8463889           17          529            54754
# 5494576   2018-12-20  8463889           18          530            54798
# 5494577   2018-12-20  8463889           19          531            54850
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 27106           27106    2868382    46A  46A_74  8132169
# 1                 27147           27156    2868382    46A  46A_74  8132169
# 2                 27182           27222    2868382    46A  46A_74  8132169
# 3                 27258           27267    2868382    46A  46A_74  8132169
# 4                 27309           27309    2868382    46A  46A_74  8132169
# ...                 ...             ...        ...    ...     ...      ...
# 5494573           54851           54851    3265691    29A  29A_14  8463889
# 5494574           54872           54872    3265691    29A  29A_14  8463889
# 5494575           54915           54926    3265691    29A  29A_14  8463889
# 5494576           54962           54962    3265691    29A  29A_14  8463889
# 5494577           54991           54991    3265691    29A  29A_14  8463889
#
#         StopPoint_2 ActualTime_Arr_2 trip_q TravelTime
# 0               808            27147      0         41
# 1               809            27182      0         26
# 2               810            27258      0         36
# 3               811            27309      0         42
# 4               812            27333      0         24
# ...             ...              ...    ...        ...
# 5494573         528            54872      0         21
# 5494574         529            54915      0         43
# 5494575         530            54962      0         36
# 5494576         531            54991      0         29
# 5494577         709            55038      0         47
#
# [5389966 rows x 15 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %% [markdown]
# ### there are a lot of unmormal value, drop traveltime which is smaller than 0 first

# %%
x=x[x['TravelTime']>0]

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %%
#drop traveltime >=3000
x=x[x['TravelTime']<3000]

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %%
x.to_csv("../clean_data/dec_section.csv",index=None)
