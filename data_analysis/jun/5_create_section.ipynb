# %% [markdown]
# # 1. Introduction

# %% [markdown]
# The purpose of this notebook is to create initial cleaning of the section data, and to export the cleaned data to a csv file.

# %% [markdown]
# # 2. Setup & Data Load

# %% [markdown]
# Import required modules and packages:

# %%
# import pandas for data analysis
import pandas as pd

#import numpy
import numpy as np

# %%
import gc
gc.collect()
# Out:
# 22

# %% [markdown]
# ### load leavetime

# %%
df_leaveTime=pd.read_csv("../clean_data/leavetime_JUN.csv",index_col=0)
df_leaveTime
# Out:
# D:\Software\Anaconda\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-06-01  6830584            1          248            27600
# 1         2018-06-01  6830584            2          249            27644
# 2         2018-06-01  6830584            3          250            27726
# 3         2018-06-01  6830584            4          251            27774
# 4         2018-06-01  6830584            5          252            27881
# ...              ...      ...          ...          ...              ...
# 9754598   2018-06-30  7115963           53         3115            73358
# 9754599   2018-06-30  7115963           54         3116            73419
# 9754600   2018-06-30  7115963           55         6085            73490
# 9754601   2018-06-30  7115963           56         2026            73567
# 9754602   2018-06-30  7115963           57         7226            73637
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID
# 0                 27628           27628    2868390
# 1                 27677           27691    2868390
# 2                 27765           27792    2868390
# 3                 27838           27870    2868390
# 4                 27912           27940    2868390
# ...                 ...             ...        ...
# 9754598           73986           74002    2693249
# 9754599           74041           74041    2693249
# 9754600           74129           74141    2693249
# 9754601           74201           74217    2693249
# 9754602           74272           74272    2693249
#
# [9267830 rows x 8 columns]

# %%
df_leaveTime.sort_values(by=['DayOfService','TripID','ProgrNumber'],ascending=[True,True,True])
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-06-01  6830584            1          248            27600
# 1         2018-06-01  6830584            2          249            27644
# 2         2018-06-01  6830584            3          250            27726
# 3         2018-06-01  6830584            4          251            27774
# 4         2018-06-01  6830584            5          252            27881
# ...              ...      ...          ...          ...              ...
# 9754598   2018-06-30  7115963           53         3115            73358
# 9754599   2018-06-30  7115963           54         3116            73419
# 9754600   2018-06-30  7115963           55         6085            73490
# 9754601   2018-06-30  7115963           56         2026            73567
# 9754602   2018-06-30  7115963           57         7226            73637
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID
# 0                 27628           27628    2868390
# 1                 27677           27691    2868390
# 2                 27765           27792    2868390
# 3                 27838           27870    2868390
# 4                 27912           27940    2868390
# ...                 ...             ...        ...
# 9754598           73986           74002    2693249
# 9754599           74041           74041    2693249
# 9754600           74129           74141    2693249
# 9754601           74201           74217    2693249
# 9754602           74272           74272    2693249
#
# [9267830 rows x 8 columns]

# %%
df_leaveTime.columns
# Out:
# Index(['DayOfService', 'TripID', 'ProgrNumber', 'StopPointID',
#        'PlannedTime_Arr', 'ActualTime_Arr', 'ActualTime_Dep', 'VehicleID'],
#       dtype='object')

# %% [markdown]
# ### load trips

# %%
df_trips=pd.read_csv("../initial_data/RT_Trips.csv",index_col=0)
df_trips
# Out:
# D:\Software\Anaconda\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#         ActualTime_Arr  ActualTime_Dep DayOfService Direction  LineID  \
# 0           2018-01-01         5955277           16     16_20       1
# 1           2018-01-01         5955278           16     16_24       2
# 2           2018-01-01         5955279           16     16_20       1
# 3           2018-01-01         5955280           16     16_24       2
# 4           2018-01-01         5955281           16     16_20       1
# ...                ...             ...          ...       ...     ...
# 2182632     2018-12-31         8592110           11     11_42       2
# 2182633     2018-12-31         8592113           7A     7A_85       1
# 2182634     2018-12-31         8592114           7A     7A_87       2
# 2182635     2018-12-31         8592115           7A     7A_85       1
# 2182636     2018-12-31         8592116           7A     7A_87       2
#
#          PlannedTime_Arr  PlannedTime_Dep  RouteID   TripID
# 0                  30000            33932  30029.0  33184.0
# 1                  36000            40588  35865.0  39653.0
# 2                  42000            47365  41980.0  46619.0
# 3                  48000            53590  48008.0  53790.0
# 4                  54000            59288  54221.0  59344.0
# ...                  ...              ...      ...      ...
# 2182632            75600            78677  75659.0  79491.0
# 2182633            38700            42098  38607.0  42454.0
# 2182634            44100            48149  43990.0  48039.0
# 2182635            49500            52723  49622.0  54138.0
# 2182636            54900            58565  54905.0  59262.0
#
# [2182637 rows x 9 columns]

# %%
df_trips.columns=['DayOfService','TripID','LineID','RouteID','Direction','PlannedTime_Dep','PlannedTime_Arr','ActualTime_Dep','ActualTime_Arr']
df_trips
# Out:
#         DayOfService   TripID LineID RouteID  Direction  PlannedTime_Dep  \
# 0         2018-01-01  5955277     16   16_20          1            30000
# 1         2018-01-01  5955278     16   16_24          2            36000
# 2         2018-01-01  5955279     16   16_20          1            42000
# 3         2018-01-01  5955280     16   16_24          2            48000
# 4         2018-01-01  5955281     16   16_20          1            54000
# ...              ...      ...    ...     ...        ...              ...
# 2182632   2018-12-31  8592110     11   11_42          2            75600
# 2182633   2018-12-31  8592113     7A   7A_85          1            38700
# 2182634   2018-12-31  8592114     7A   7A_87          2            44100
# 2182635   2018-12-31  8592115     7A   7A_85          1            49500
# 2182636   2018-12-31  8592116     7A   7A_87          2            54900
#
#          PlannedTime_Arr  ActualTime_Dep  ActualTime_Arr
# 0                  33932         30029.0         33184.0
# 1                  40588         35865.0         39653.0
# 2                  47365         41980.0         46619.0
# 3                  53590         48008.0         53790.0
# 4                  59288         54221.0         59344.0
# ...                  ...             ...             ...
# 2182632            78677         75659.0         79491.0
# 2182633            42098         38607.0         42454.0
# 2182634            48149         43990.0         48039.0
# 2182635            52723         49622.0         54138.0
# 2182636            58565         54905.0         59262.0
#
# [2182637 rows x 9 columns]

# %%
df_trips_simple=df_trips[['DayOfService','TripID','LineID','RouteID']]
df_trips_simple
# Out:
#         DayOfService   TripID LineID RouteID
# 0         2018-01-01  5955277     16   16_20
# 1         2018-01-01  5955278     16   16_24
# 2         2018-01-01  5955279     16   16_20
# 3         2018-01-01  5955280     16   16_24
# 4         2018-01-01  5955281     16   16_20
# ...              ...      ...    ...     ...
# 2182632   2018-12-31  8592110     11   11_42
# 2182633   2018-12-31  8592113     7A   7A_85
# 2182634   2018-12-31  8592114     7A   7A_87
# 2182635   2018-12-31  8592115     7A   7A_85
# 2182636   2018-12-31  8592116     7A   7A_87
#
# [2182637 rows x 4 columns]

# %% [markdown]
# ### merge two dataset

# %%
section=pd.merge(df_leaveTime,df_trips_simple,how='left',on=['DayOfService','TripID'])
section
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-06-01  6830584            1          248            27600
# 1         2018-06-01  6830584            2          249            27644
# 2         2018-06-01  6830584            3          250            27726
# 3         2018-06-01  6830584            4          251            27774
# 4         2018-06-01  6830584            5          252            27881
# ...              ...      ...          ...          ...              ...
# 9267825   2018-06-30  7115963           53         3115            73358
# 9267826   2018-06-30  7115963           54         3116            73419
# 9267827   2018-06-30  7115963           55         6085            73490
# 9267828   2018-06-30  7115963           56         2026            73567
# 9267829   2018-06-30  7115963           57         7226            73637
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID
# 0                 27628           27628    2868390     14   14_15
# 1                 27677           27691    2868390     14   14_15
# 2                 27765           27792    2868390     14   14_15
# 3                 27838           27870    2868390     14   14_15
# 4                 27912           27940    2868390     14   14_15
# ...                 ...             ...        ...    ...     ...
# 9267825           73986           74002    2693249      4    4_10
# 9267826           74041           74041    2693249      4    4_10
# 9267827           74129           74141    2693249      4    4_10
# 9267828           74201           74217    2693249      4    4_10
# 9267829           74272           74272    2693249      4    4_10
#
# [9267830 rows x 10 columns]

# %% [markdown]
# ### add previous stops

# %%
section_copy=section[['TripID','StopPointID','ActualTime_Arr']]
section_copy.columns=['TripID_2','StopPoint_2','ActualTime_Arr_2']
section_copy
# Out:
#          TripID_2  StopPoint_2  ActualTime_Arr_2
# 0         6830584          248             27628
# 1         6830584          249             27677
# 2         6830584          250             27765
# 3         6830584          251             27838
# 4         6830584          252             27912
# ...           ...          ...               ...
# 9267825   7115963         3115             73986
# 9267826   7115963         3116             74041
# 9267827   7115963         6085             74129
# 9267828   7115963         2026             74201
# 9267829   7115963         7226             74272
#
# [9267830 rows x 3 columns]

# %%
section_copy.drop(axis=0, index=0,inplace=True)
section_copy
# Out:
# D:\Software\Anaconda\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#          TripID_2  StopPoint_2  ActualTime_Arr_2
# 1         6830584          249             27677
# 2         6830584          250             27765
# 3         6830584          251             27838
# 4         6830584          252             27912
# 5         6830584          255             27977
# ...           ...          ...               ...
# 9267825   7115963         3115             73986
# 9267826   7115963         3116             74041
# 9267827   7115963         6085             74129
# 9267828   7115963         2026             74201
# 9267829   7115963         7226             74272
#
# [9267829 rows x 3 columns]

# %%
# add new rows
section_copy.loc['new_raw'] = '3'
section_copy
# Out:
# D:\Software\Anaconda\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#         TripID_2 StopPoint_2 ActualTime_Arr_2
# 1        6830584         249            27677
# 2        6830584         250            27765
# 3        6830584         251            27838
# 4        6830584         252            27912
# 5        6830584         255            27977
# ...          ...         ...              ...
# 9267826  7115963        3116            74041
# 9267827  7115963        6085            74129
# 9267828  7115963        2026            74201
# 9267829  7115963        7226            74272
# new_raw        3           3                3
#
# [9267830 rows x 3 columns]

# %%
# adject the index
section_copy.index=np.arange(0,9267830)
section_copy
# Out:
#         TripID_2 StopPoint_2 ActualTime_Arr_2
# 0        6830584         249            27677
# 1        6830584         250            27765
# 2        6830584         251            27838
# 3        6830584         252            27912
# 4        6830584         255            27977
# ...          ...         ...              ...
# 9267825  7115963        3116            74041
# 9267826  7115963        6085            74129
# 9267827  7115963        2026            74201
# 9267828  7115963        7226            74272
# 9267829        3           3                3
#
# [9267830 rows x 3 columns]

# %%
section_combine = pd.concat([section, section_copy], axis=1,ignore_index=True)

# %%
col_name=[]
for col in section.columns:
    col_name.append(col)
col_name.append('TripID_2')
col_name.append('StopPoint_2')
col_name.append('ActualTime_Arr_2')
col_name
# Out:
# ['DayOfService',
#  'TripID',
#  'ProgrNumber',
#  'StopPointID',
#  'PlannedTime_Arr',
#  'ActualTime_Arr',
#  'ActualTime_Dep',
#  'VehicleID',
#  'LineID',
#  'RouteID',
#  'TripID_2',
#  'StopPoint_2',
#  'ActualTime_Arr_2']

# %%
section_combine.columns=col_name
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-06-01  6830584            1          248            27600
# 1         2018-06-01  6830584            2          249            27644
# 2         2018-06-01  6830584            3          250            27726
# 3         2018-06-01  6830584            4          251            27774
# 4         2018-06-01  6830584            5          252            27881
# ...              ...      ...          ...          ...              ...
# 9267825   2018-06-30  7115963           53         3115            73358
# 9267826   2018-06-30  7115963           54         3116            73419
# 9267827   2018-06-30  7115963           55         6085            73490
# 9267828   2018-06-30  7115963           56         2026            73567
# 9267829   2018-06-30  7115963           57         7226            73637
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 27628           27628    2868390     14   14_15  6830584
# 1                 27677           27691    2868390     14   14_15  6830584
# 2                 27765           27792    2868390     14   14_15  6830584
# 3                 27838           27870    2868390     14   14_15  6830584
# 4                 27912           27940    2868390     14   14_15  6830584
# ...                 ...             ...        ...    ...     ...      ...
# 9267825           73986           74002    2693249      4    4_10  7115963
# 9267826           74041           74041    2693249      4    4_10  7115963
# 9267827           74129           74141    2693249      4    4_10  7115963
# 9267828           74201           74217    2693249      4    4_10  7115963
# 9267829           74272           74272    2693249      4    4_10        3
#
#         StopPoint_2 ActualTime_Arr_2
# 0               249            27677
# 1               250            27765
# 2               251            27838
# 3               252            27912
# 4               255            27977
# ...             ...              ...
# 9267825        3116            74041
# 9267826        6085            74129
# 9267827        2026            74201
# 9267828        7226            74272
# 9267829           3                3
#
# [9267830 rows x 13 columns]

# %%
#drop the last rows
section_combine.drop(axis=0, index=9267829,inplace=True)
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-06-01  6830584            1          248            27600
# 1         2018-06-01  6830584            2          249            27644
# 2         2018-06-01  6830584            3          250            27726
# 3         2018-06-01  6830584            4          251            27774
# 4         2018-06-01  6830584            5          252            27881
# ...              ...      ...          ...          ...              ...
# 9267824   2018-06-30  7115963           52         3114            73325
# 9267825   2018-06-30  7115963           53         3115            73358
# 9267826   2018-06-30  7115963           54         3116            73419
# 9267827   2018-06-30  7115963           55         6085            73490
# 9267828   2018-06-30  7115963           56         2026            73567
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 27628           27628    2868390     14   14_15  6830584
# 1                 27677           27691    2868390     14   14_15  6830584
# 2                 27765           27792    2868390     14   14_15  6830584
# 3                 27838           27870    2868390     14   14_15  6830584
# 4                 27912           27940    2868390     14   14_15  6830584
# ...                 ...             ...        ...    ...     ...      ...
# 9267824           73959           73959    2693249      4    4_10  7115963
# 9267825           73986           74002    2693249      4    4_10  7115963
# 9267826           74041           74041    2693249      4    4_10  7115963
# 9267827           74129           74141    2693249      4    4_10  7115963
# 9267828           74201           74217    2693249      4    4_10  7115963
#
#         StopPoint_2 ActualTime_Arr_2
# 0               249            27677
# 1               250            27765
# 2               251            27838
# 3               252            27912
# 4               255            27977
# ...             ...              ...
# 9267824        3115            73986
# 9267825        3116            74041
# 9267826        6085            74129
# 9267827        2026            74201
# 9267828        7226            74272
#
# [9267829 rows x 13 columns]

# %%
section_combine['trip_q']=section_combine['TripID_2']-section_combine['TripID']

# %%
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-06-01  6830584            1          248            27600
# 1         2018-06-01  6830584            2          249            27644
# 2         2018-06-01  6830584            3          250            27726
# 3         2018-06-01  6830584            4          251            27774
# 4         2018-06-01  6830584            5          252            27881
# ...              ...      ...          ...          ...              ...
# 9267824   2018-06-30  7115963           52         3114            73325
# 9267825   2018-06-30  7115963           53         3115            73358
# 9267826   2018-06-30  7115963           54         3116            73419
# 9267827   2018-06-30  7115963           55         6085            73490
# 9267828   2018-06-30  7115963           56         2026            73567
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 27628           27628    2868390     14   14_15  6830584
# 1                 27677           27691    2868390     14   14_15  6830584
# 2                 27765           27792    2868390     14   14_15  6830584
# 3                 27838           27870    2868390     14   14_15  6830584
# 4                 27912           27940    2868390     14   14_15  6830584
# ...                 ...             ...        ...    ...     ...      ...
# 9267824           73959           73959    2693249      4    4_10  7115963
# 9267825           73986           74002    2693249      4    4_10  7115963
# 9267826           74041           74041    2693249      4    4_10  7115963
# 9267827           74129           74141    2693249      4    4_10  7115963
# 9267828           74201           74217    2693249      4    4_10  7115963
#
#         StopPoint_2 ActualTime_Arr_2 trip_q
# 0               249            27677      0
# 1               250            27765      0
# 2               251            27838      0
# 3               252            27912      0
# 4               255            27977      0
# ...             ...              ...    ...
# 9267824        3115            73986      0
# 9267825        3116            74041      0
# 9267826        6085            74129      0
# 9267827        2026            74201      0
# 9267828        7226            74272      0
#
# [9267829 rows x 14 columns]

# %%
section_combine['trip_q'].value_counts()
# Out:
#  0        9085801
#  1         159934
#  2           3358
#  3           1633
#  4           1301
#            ...
#  187            1
#  191            1
#  200            1
#  202            1
# -17162          1
# Name: trip_q, Length: 185, dtype: int64

# %%
# if trip_q !=0, we do not need it 
x=section_combine[section_combine['trip_q']==0]

# %%
x['TravelTime']=x['ActualTime_Arr_2']-x['ActualTime_Dep']
x
# Out:
# D:\Software\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-06-01  6830584            1          248            27600
# 1         2018-06-01  6830584            2          249            27644
# 2         2018-06-01  6830584            3          250            27726
# 3         2018-06-01  6830584            4          251            27774
# 4         2018-06-01  6830584            5          252            27881
# ...              ...      ...          ...          ...              ...
# 9267824   2018-06-30  7115963           52         3114            73325
# 9267825   2018-06-30  7115963           53         3115            73358
# 9267826   2018-06-30  7115963           54         3116            73419
# 9267827   2018-06-30  7115963           55         6085            73490
# 9267828   2018-06-30  7115963           56         2026            73567
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 27628           27628    2868390     14   14_15  6830584
# 1                 27677           27691    2868390     14   14_15  6830584
# 2                 27765           27792    2868390     14   14_15  6830584
# 3                 27838           27870    2868390     14   14_15  6830584
# 4                 27912           27940    2868390     14   14_15  6830584
# ...                 ...             ...        ...    ...     ...      ...
# 9267824           73959           73959    2693249      4    4_10  7115963
# 9267825           73986           74002    2693249      4    4_10  7115963
# 9267826           74041           74041    2693249      4    4_10  7115963
# 9267827           74129           74141    2693249      4    4_10  7115963
# 9267828           74201           74217    2693249      4    4_10  7115963
#
#         StopPoint_2 ActualTime_Arr_2 trip_q TravelTime
# 0               249            27677      0         49
# 1               250            27765      0         74
# 2               251            27838      0         46
# 3               252            27912      0         42
# 4               255            27977      0         37
# ...             ...              ...    ...        ...
# 9267824        3115            73986      0         27
# 9267825        3116            74041      0         39
# 9267826        6085            74129      0         88
# 9267827        2026            74201      0         60
# 9267828        7226            74272      0         55
#
# [9085801 rows x 15 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %% [markdown]
# ### there are a lot of unmormal value, drop traveltime which is smaller than 0 first

# %%
x=x[x['TravelTime']>0]

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %%
#drop traveltime >=3000
x=x[x['TravelTime']<3000]

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %%
x.to_csv("../clean_data/jun_section.csv",index=None)
