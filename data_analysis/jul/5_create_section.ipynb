# %% [markdown]
# # 1. Introduction

# %% [markdown]
# The purpose of this notebook is to create initial cleaning of the section data, and to export the cleaned data to a csv file.

# %% [markdown]
# # 2. Setup & Data Load

# %% [markdown]
# Import required modules and packages:

# %%
# import pandas for data analysis
import pandas as pd

#import numpy
import numpy as np

# %%
import gc
gc.collect()
# Out:
# 22

# %% [markdown]
# ### load leavetime

# %%
df_leaveTime=pd.read_csv("../clean_data/leavetime_JUl.csv",index_col=0)
df_leaveTime
# Out:
# D:\Software\Anaconda\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#          DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0          2018-07-01  7133190            1         6290            49680
# 1          2018-07-01  7133190            2         7120            49760
# 2          2018-07-01  7133190            3         7119            49805
# 3          2018-07-01  7133190            4         7127            49842
# 4          2018-07-01  7133190            5         7143            49905
# ...               ...      ...          ...          ...              ...
# 10115694   2018-07-31  7332457           46         1417            66889
# 10115695   2018-07-31  7332457           47         1418            66944
# 10115696   2018-07-31  7332457           48         5149            66982
# 10115697   2018-07-31  7332457           49         1419            67017
# 10115698   2018-07-31  7332457           50         6094            67065
#
#           ActualTime_Arr  ActualTime_Dep  VehicleID
# 0                  49560           49560    1932343
# 1                  49786           49794    1932343
# 2                  49825           49835    1932343
# 3                  49866           49888    1932343
# 4                  49929           49978    1932343
# ...                  ...             ...        ...
# 10115694           67585           67598    1001215
# 10115695           67634           67652    1001215
# 10115696           67689           67689    1001215
# 10115697           67711           67723    1001215
# 10115698           67858           67858    1001215
#
# [9606191 rows x 8 columns]

# %%
df_leaveTime.sort_values(by=['DayOfService','TripID','ProgrNumber'],ascending=[True,True,True])
# Out:
#          DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0          2018-07-01  7133190            1         6290            49680
# 1          2018-07-01  7133190            2         7120            49760
# 2          2018-07-01  7133190            3         7119            49805
# 3          2018-07-01  7133190            4         7127            49842
# 4          2018-07-01  7133190            5         7143            49905
# ...               ...      ...          ...          ...              ...
# 10115694   2018-07-31  7332457           46         1417            66889
# 10115695   2018-07-31  7332457           47         1418            66944
# 10115696   2018-07-31  7332457           48         5149            66982
# 10115697   2018-07-31  7332457           49         1419            67017
# 10115698   2018-07-31  7332457           50         6094            67065
#
#           ActualTime_Arr  ActualTime_Dep  VehicleID
# 0                  49560           49560    1932343
# 1                  49786           49794    1932343
# 2                  49825           49835    1932343
# 3                  49866           49888    1932343
# 4                  49929           49978    1932343
# ...                  ...             ...        ...
# 10115694           67585           67598    1001215
# 10115695           67634           67652    1001215
# 10115696           67689           67689    1001215
# 10115697           67711           67723    1001215
# 10115698           67858           67858    1001215
#
# [9606191 rows x 8 columns]

# %%
df_leaveTime.columns
# Out:
# Index(['DayOfService', 'TripID', 'ProgrNumber', 'StopPointID',
#        'PlannedTime_Arr', 'ActualTime_Arr', 'ActualTime_Dep', 'VehicleID'],
#       dtype='object')

# %% [markdown]
# ### load trips

# %%
df_trips=pd.read_csv("../initial_data/RT_Trips.csv",index_col=0)
df_trips
# Out:
# D:\Software\Anaconda\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#         ActualTime_Arr  ActualTime_Dep DayOfService Direction  LineID  \
# 0           2018-01-01         5955277           16     16_20       1
# 1           2018-01-01         5955278           16     16_24       2
# 2           2018-01-01         5955279           16     16_20       1
# 3           2018-01-01         5955280           16     16_24       2
# 4           2018-01-01         5955281           16     16_20       1
# ...                ...             ...          ...       ...     ...
# 2182632     2018-12-31         8592110           11     11_42       2
# 2182633     2018-12-31         8592113           7A     7A_85       1
# 2182634     2018-12-31         8592114           7A     7A_87       2
# 2182635     2018-12-31         8592115           7A     7A_85       1
# 2182636     2018-12-31         8592116           7A     7A_87       2
#
#          PlannedTime_Arr  PlannedTime_Dep  RouteID   TripID
# 0                  30000            33932  30029.0  33184.0
# 1                  36000            40588  35865.0  39653.0
# 2                  42000            47365  41980.0  46619.0
# 3                  48000            53590  48008.0  53790.0
# 4                  54000            59288  54221.0  59344.0
# ...                  ...              ...      ...      ...
# 2182632            75600            78677  75659.0  79491.0
# 2182633            38700            42098  38607.0  42454.0
# 2182634            44100            48149  43990.0  48039.0
# 2182635            49500            52723  49622.0  54138.0
# 2182636            54900            58565  54905.0  59262.0
#
# [2182637 rows x 9 columns]

# %%
df_trips.columns=['DayOfService','TripID','LineID','RouteID','Direction','PlannedTime_Dep','PlannedTime_Arr','ActualTime_Dep','ActualTime_Arr']
df_trips
# Out:
#         DayOfService   TripID LineID RouteID  Direction  PlannedTime_Dep  \
# 0         2018-01-01  5955277     16   16_20          1            30000
# 1         2018-01-01  5955278     16   16_24          2            36000
# 2         2018-01-01  5955279     16   16_20          1            42000
# 3         2018-01-01  5955280     16   16_24          2            48000
# 4         2018-01-01  5955281     16   16_20          1            54000
# ...              ...      ...    ...     ...        ...              ...
# 2182632   2018-12-31  8592110     11   11_42          2            75600
# 2182633   2018-12-31  8592113     7A   7A_85          1            38700
# 2182634   2018-12-31  8592114     7A   7A_87          2            44100
# 2182635   2018-12-31  8592115     7A   7A_85          1            49500
# 2182636   2018-12-31  8592116     7A   7A_87          2            54900
#
#          PlannedTime_Arr  ActualTime_Dep  ActualTime_Arr
# 0                  33932         30029.0         33184.0
# 1                  40588         35865.0         39653.0
# 2                  47365         41980.0         46619.0
# 3                  53590         48008.0         53790.0
# 4                  59288         54221.0         59344.0
# ...                  ...             ...             ...
# 2182632            78677         75659.0         79491.0
# 2182633            42098         38607.0         42454.0
# 2182634            48149         43990.0         48039.0
# 2182635            52723         49622.0         54138.0
# 2182636            58565         54905.0         59262.0
#
# [2182637 rows x 9 columns]

# %%
df_trips_simple=df_trips[['DayOfService','TripID','LineID','RouteID']]
df_trips_simple
# Out:
#         DayOfService   TripID LineID RouteID
# 0         2018-01-01  5955277     16   16_20
# 1         2018-01-01  5955278     16   16_24
# 2         2018-01-01  5955279     16   16_20
# 3         2018-01-01  5955280     16   16_24
# 4         2018-01-01  5955281     16   16_20
# ...              ...      ...    ...     ...
# 2182632   2018-12-31  8592110     11   11_42
# 2182633   2018-12-31  8592113     7A   7A_85
# 2182634   2018-12-31  8592114     7A   7A_87
# 2182635   2018-12-31  8592115     7A   7A_85
# 2182636   2018-12-31  8592116     7A   7A_87
#
# [2182637 rows x 4 columns]

# %% [markdown]
# ### merge two dataset

# %%
section=pd.merge(df_leaveTime,df_trips_simple,how='left',on=['DayOfService','TripID'])
section
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-07-01  7133190            1         6290            49680
# 1         2018-07-01  7133190            2         7120            49760
# 2         2018-07-01  7133190            3         7119            49805
# 3         2018-07-01  7133190            4         7127            49842
# 4         2018-07-01  7133190            5         7143            49905
# ...              ...      ...          ...          ...              ...
# 9606186   2018-07-31  7332457           46         1417            66889
# 9606187   2018-07-31  7332457           47         1418            66944
# 9606188   2018-07-31  7332457           48         5149            66982
# 9606189   2018-07-31  7332457           49         1419            67017
# 9606190   2018-07-31  7332457           50         6094            67065
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID  RouteID
# 0                 49560           49560    1932343    25B  25B_271
# 1                 49786           49794    1932343    25B  25B_271
# 2                 49825           49835    1932343    25B  25B_271
# 3                 49866           49888    1932343    25B  25B_271
# 4                 49929           49978    1932343    25B  25B_271
# ...                 ...             ...        ...    ...      ...
# 9606186           67585           67598    1001215    122   122_18
# 9606187           67634           67652    1001215    122   122_18
# 9606188           67689           67689    1001215    122   122_18
# 9606189           67711           67723    1001215    122   122_18
# 9606190           67858           67858    1001215    122   122_18
#
# [9606191 rows x 10 columns]

# %% [markdown]
# ### add previous stops

# %%
section_copy=section[['TripID','StopPointID','ActualTime_Arr']]
section_copy.columns=['TripID_2','StopPoint_2','ActualTime_Arr_2']
section_copy
# Out:
#          TripID_2  StopPoint_2  ActualTime_Arr_2
# 0         7133190         6290             49560
# 1         7133190         7120             49786
# 2         7133190         7119             49825
# 3         7133190         7127             49866
# 4         7133190         7143             49929
# ...           ...          ...               ...
# 9606186   7332457         1417             67585
# 9606187   7332457         1418             67634
# 9606188   7332457         5149             67689
# 9606189   7332457         1419             67711
# 9606190   7332457         6094             67858
#
# [9606191 rows x 3 columns]

# %%
section_copy.drop(axis=0, index=0,inplace=True)
section_copy
# Out:
# D:\Software\Anaconda\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#          TripID_2  StopPoint_2  ActualTime_Arr_2
# 1         7133190         7120             49786
# 2         7133190         7119             49825
# 3         7133190         7127             49866
# 4         7133190         7143             49929
# 5         7133190         3368             50052
# ...           ...          ...               ...
# 9606186   7332457         1417             67585
# 9606187   7332457         1418             67634
# 9606188   7332457         5149             67689
# 9606189   7332457         1419             67711
# 9606190   7332457         6094             67858
#
# [9606190 rows x 3 columns]

# %%
# add new rows
section_copy.loc['new_raw'] = '3'
section_copy
# Out:
# D:\Software\Anaconda\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#         TripID_2 StopPoint_2 ActualTime_Arr_2
# 1        7133190        7120            49786
# 2        7133190        7119            49825
# 3        7133190        7127            49866
# 4        7133190        7143            49929
# 5        7133190        3368            50052
# ...          ...         ...              ...
# 9606187  7332457        1418            67634
# 9606188  7332457        5149            67689
# 9606189  7332457        1419            67711
# 9606190  7332457        6094            67858
# new_raw        3           3                3
#
# [9606191 rows x 3 columns]

# %%
# adject the index
section_copy.index=np.arange(0,9606191)
section_copy
# Out:
#         TripID_2 StopPoint_2 ActualTime_Arr_2
# 0        7133190        7120            49786
# 1        7133190        7119            49825
# 2        7133190        7127            49866
# 3        7133190        7143            49929
# 4        7133190        3368            50052
# ...          ...         ...              ...
# 9606186  7332457        1418            67634
# 9606187  7332457        5149            67689
# 9606188  7332457        1419            67711
# 9606189  7332457        6094            67858
# 9606190        3           3                3
#
# [9606191 rows x 3 columns]

# %%
section_combine = pd.concat([section, section_copy], axis=1,ignore_index=True)

# %%
col_name=[]
for col in section.columns:
    col_name.append(col)
col_name.append('TripID_2')
col_name.append('StopPoint_2')
col_name.append('ActualTime_Arr_2')
col_name
# Out:
# ['DayOfService',
#  'TripID',
#  'ProgrNumber',
#  'StopPointID',
#  'PlannedTime_Arr',
#  'ActualTime_Arr',
#  'ActualTime_Dep',
#  'VehicleID',
#  'LineID',
#  'RouteID',
#  'TripID_2',
#  'StopPoint_2',
#  'ActualTime_Arr_2']

# %%
section_combine.columns=col_name
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-07-01  7133190            1         6290            49680
# 1         2018-07-01  7133190            2         7120            49760
# 2         2018-07-01  7133190            3         7119            49805
# 3         2018-07-01  7133190            4         7127            49842
# 4         2018-07-01  7133190            5         7143            49905
# ...              ...      ...          ...          ...              ...
# 9606186   2018-07-31  7332457           46         1417            66889
# 9606187   2018-07-31  7332457           47         1418            66944
# 9606188   2018-07-31  7332457           48         5149            66982
# 9606189   2018-07-31  7332457           49         1419            67017
# 9606190   2018-07-31  7332457           50         6094            67065
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID  RouteID TripID_2  \
# 0                 49560           49560    1932343    25B  25B_271  7133190
# 1                 49786           49794    1932343    25B  25B_271  7133190
# 2                 49825           49835    1932343    25B  25B_271  7133190
# 3                 49866           49888    1932343    25B  25B_271  7133190
# 4                 49929           49978    1932343    25B  25B_271  7133190
# ...                 ...             ...        ...    ...      ...      ...
# 9606186           67585           67598    1001215    122   122_18  7332457
# 9606187           67634           67652    1001215    122   122_18  7332457
# 9606188           67689           67689    1001215    122   122_18  7332457
# 9606189           67711           67723    1001215    122   122_18  7332457
# 9606190           67858           67858    1001215    122   122_18        3
#
#         StopPoint_2 ActualTime_Arr_2
# 0              7120            49786
# 1              7119            49825
# 2              7127            49866
# 3              7143            49929
# 4              3368            50052
# ...             ...              ...
# 9606186        1418            67634
# 9606187        5149            67689
# 9606188        1419            67711
# 9606189        6094            67858
# 9606190           3                3
#
# [9606191 rows x 13 columns]

# %%
#drop the last rows
section_combine.drop(axis=0, index=9606190,inplace=True)
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-07-01  7133190            1         6290            49680
# 1         2018-07-01  7133190            2         7120            49760
# 2         2018-07-01  7133190            3         7119            49805
# 3         2018-07-01  7133190            4         7127            49842
# 4         2018-07-01  7133190            5         7143            49905
# ...              ...      ...          ...          ...              ...
# 9606185   2018-07-31  7332457           45         1415            66830
# 9606186   2018-07-31  7332457           46         1417            66889
# 9606187   2018-07-31  7332457           47         1418            66944
# 9606188   2018-07-31  7332457           48         5149            66982
# 9606189   2018-07-31  7332457           49         1419            67017
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID  RouteID TripID_2  \
# 0                 49560           49560    1932343    25B  25B_271  7133190
# 1                 49786           49794    1932343    25B  25B_271  7133190
# 2                 49825           49835    1932343    25B  25B_271  7133190
# 3                 49866           49888    1932343    25B  25B_271  7133190
# 4                 49929           49978    1932343    25B  25B_271  7133190
# ...                 ...             ...        ...    ...      ...      ...
# 9606185           67522           67546    1001215    122   122_18  7332457
# 9606186           67585           67598    1001215    122   122_18  7332457
# 9606187           67634           67652    1001215    122   122_18  7332457
# 9606188           67689           67689    1001215    122   122_18  7332457
# 9606189           67711           67723    1001215    122   122_18  7332457
#
#         StopPoint_2 ActualTime_Arr_2
# 0              7120            49786
# 1              7119            49825
# 2              7127            49866
# 3              7143            49929
# 4              3368            50052
# ...             ...              ...
# 9606185        1417            67585
# 9606186        1418            67634
# 9606187        5149            67689
# 9606188        1419            67711
# 9606189        6094            67858
#
# [9606190 rows x 13 columns]

# %%
section_combine['trip_q']=section_combine['TripID_2']-section_combine['TripID']

# %%
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-07-01  7133190            1         6290            49680
# 1         2018-07-01  7133190            2         7120            49760
# 2         2018-07-01  7133190            3         7119            49805
# 3         2018-07-01  7133190            4         7127            49842
# 4         2018-07-01  7133190            5         7143            49905
# ...              ...      ...          ...          ...              ...
# 9606185   2018-07-31  7332457           45         1415            66830
# 9606186   2018-07-31  7332457           46         1417            66889
# 9606187   2018-07-31  7332457           47         1418            66944
# 9606188   2018-07-31  7332457           48         5149            66982
# 9606189   2018-07-31  7332457           49         1419            67017
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID  RouteID TripID_2  \
# 0                 49560           49560    1932343    25B  25B_271  7133190
# 1                 49786           49794    1932343    25B  25B_271  7133190
# 2                 49825           49835    1932343    25B  25B_271  7133190
# 3                 49866           49888    1932343    25B  25B_271  7133190
# 4                 49929           49978    1932343    25B  25B_271  7133190
# ...                 ...             ...        ...    ...      ...      ...
# 9606185           67522           67546    1001215    122   122_18  7332457
# 9606186           67585           67598    1001215    122   122_18  7332457
# 9606187           67634           67652    1001215    122   122_18  7332457
# 9606188           67689           67689    1001215    122   122_18  7332457
# 9606189           67711           67723    1001215    122   122_18  7332457
#
#         StopPoint_2 ActualTime_Arr_2 trip_q
# 0              7120            49786      0
# 1              7119            49825      0
# 2              7127            49866      0
# 3              7143            49929      0
# 4              3368            50052      0
# ...             ...              ...    ...
# 9606185        1417            67585      0
# 9606186        1418            67634      0
# 9606187        5149            67689      0
# 9606188        1419            67711      0
# 9606189        6094            67858      0
#
# [9606190 rows x 14 columns]

# %%
section_combine['trip_q'].value_counts()
# Out:
#  0        9417747
#  1         170876
#  2           2378
#  3           1057
#  11           731
#            ...
#  166            1
#  197            1
#  214            1
#  221            1
# -17115          1
# Name: trip_q, Length: 184, dtype: int64

# %%
# if trip_q !=0, we do not need it 
x=section_combine[section_combine['trip_q']==0]

# %%
x['TravelTime']=x['ActualTime_Arr_2']-x['ActualTime_Dep']
x
# Out:
# D:\Software\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-07-01  7133190            1         6290            49680
# 1         2018-07-01  7133190            2         7120            49760
# 2         2018-07-01  7133190            3         7119            49805
# 3         2018-07-01  7133190            4         7127            49842
# 4         2018-07-01  7133190            5         7143            49905
# ...              ...      ...          ...          ...              ...
# 9606185   2018-07-31  7332457           45         1415            66830
# 9606186   2018-07-31  7332457           46         1417            66889
# 9606187   2018-07-31  7332457           47         1418            66944
# 9606188   2018-07-31  7332457           48         5149            66982
# 9606189   2018-07-31  7332457           49         1419            67017
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID  RouteID TripID_2  \
# 0                 49560           49560    1932343    25B  25B_271  7133190
# 1                 49786           49794    1932343    25B  25B_271  7133190
# 2                 49825           49835    1932343    25B  25B_271  7133190
# 3                 49866           49888    1932343    25B  25B_271  7133190
# 4                 49929           49978    1932343    25B  25B_271  7133190
# ...                 ...             ...        ...    ...      ...      ...
# 9606185           67522           67546    1001215    122   122_18  7332457
# 9606186           67585           67598    1001215    122   122_18  7332457
# 9606187           67634           67652    1001215    122   122_18  7332457
# 9606188           67689           67689    1001215    122   122_18  7332457
# 9606189           67711           67723    1001215    122   122_18  7332457
#
#         StopPoint_2 ActualTime_Arr_2 trip_q TravelTime
# 0              7120            49786      0        226
# 1              7119            49825      0         31
# 2              7127            49866      0         31
# 3              7143            49929      0         41
# 4              3368            50052      0         74
# ...             ...              ...    ...        ...
# 9606185        1417            67585      0         39
# 9606186        1418            67634      0         36
# 9606187        5149            67689      0         37
# 9606188        1419            67711      0         22
# 9606189        6094            67858      0        135
#
# [9417747 rows x 15 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %% [markdown]
# ### there are a lot of unmormal value, drop traveltime which is smaller than 0 first

# %%
x=x[x['TravelTime']>0]

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %%
#drop traveltime >=3000
x=x[x['TravelTime']<3000]

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %%
x.to_csv("../clean_data/jul_section.csv",index=None)
