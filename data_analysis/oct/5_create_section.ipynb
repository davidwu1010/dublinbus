# %% [markdown]
# # 1. Introduction

# %% [markdown]
# The purpose of this notebook is to create initial cleaning of the section data, and to export the cleaned data to a csv file.

# %% [markdown]
# # 2. Setup & Data Load

# %% [markdown]
# Import required modules and packages:

# %%
# import pandas for data analysis
import pandas as pd

#import numpy
import numpy as np

# %%
import gc
gc.collect()
# Out:
# 22

# %% [markdown]
# ### load leavetime

# %%
df_leaveTime=pd.read_csv("../clean_data/leavetime_OCT.csv",index_col=0)
df_leaveTime
# Out:
# D:\Software\Anaconda\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-10-01  7774781            1          248            24300
# 1         2018-10-01  7774781            2          249            24338
# 2         2018-10-01  7774781            3          250            24406
# 3         2018-10-01  7774781            4          251            24446
# 4         2018-10-01  7774781            5          252            24532
# ...              ...      ...          ...          ...              ...
# 9981893   2018-10-31  8081188           42          908            86043
# 9981894   2018-10-31  8081188           43          909            86075
# 9981895   2018-10-31  8081188           44          786            86109
# 9981896   2018-10-31  8081188           45          792            86236
# 9981897   2018-10-31  8081188           47          320            86392
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID
# 0                 24299           24299    2693256
# 1                 24328           24343    2693256
# 2                 24392           24408    2693256
# 3                 24433           24461    2693256
# 4                 24492           24513    2693256
# ...                 ...             ...        ...
# 9981893           86328           86328    2172238
# 9981894           86369           86369    2172238
# 9981895           86396           86414    2172238
# 9981896           86519           86565    2172238
# 9981897           86674           86674    2172238
#
# [9582772 rows x 8 columns]

# %%
df_leaveTime.sort_values(by=['DayOfService','TripID','ProgrNumber'],ascending=[True,True,True])
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-10-01  7774781            1          248            24300
# 1         2018-10-01  7774781            2          249            24338
# 2         2018-10-01  7774781            3          250            24406
# 3         2018-10-01  7774781            4          251            24446
# 4         2018-10-01  7774781            5          252            24532
# ...              ...      ...          ...          ...              ...
# 9981893   2018-10-31  8081188           42          908            86043
# 9981894   2018-10-31  8081188           43          909            86075
# 9981895   2018-10-31  8081188           44          786            86109
# 9981896   2018-10-31  8081188           45          792            86236
# 9981897   2018-10-31  8081188           47          320            86392
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID
# 0                 24299           24299    2693256
# 1                 24328           24343    2693256
# 2                 24392           24408    2693256
# 3                 24433           24461    2693256
# 4                 24492           24513    2693256
# ...                 ...             ...        ...
# 9981893           86328           86328    2172238
# 9981894           86369           86369    2172238
# 9981895           86396           86414    2172238
# 9981896           86519           86565    2172238
# 9981897           86674           86674    2172238
#
# [9582772 rows x 8 columns]

# %%
df_leaveTime.columns
# Out:
# Index(['DayOfService', 'TripID', 'ProgrNumber', 'StopPointID',
#        'PlannedTime_Arr', 'ActualTime_Arr', 'ActualTime_Dep', 'VehicleID'],
#       dtype='object')

# %% [markdown]
# ### load trips

# %%
df_trips=pd.read_csv("../initial_data/RT_Trips.csv",index_col=0)
df_trips
# Out:
# D:\Software\Anaconda\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#         ActualTime_Arr  ActualTime_Dep DayOfService Direction  LineID  \
# 0           2018-01-01         5955277           16     16_20       1
# 1           2018-01-01         5955278           16     16_24       2
# 2           2018-01-01         5955279           16     16_20       1
# 3           2018-01-01         5955280           16     16_24       2
# 4           2018-01-01         5955281           16     16_20       1
# ...                ...             ...          ...       ...     ...
# 2182632     2018-12-31         8592110           11     11_42       2
# 2182633     2018-12-31         8592113           7A     7A_85       1
# 2182634     2018-12-31         8592114           7A     7A_87       2
# 2182635     2018-12-31         8592115           7A     7A_85       1
# 2182636     2018-12-31         8592116           7A     7A_87       2
#
#          PlannedTime_Arr  PlannedTime_Dep  RouteID   TripID
# 0                  30000            33932  30029.0  33184.0
# 1                  36000            40588  35865.0  39653.0
# 2                  42000            47365  41980.0  46619.0
# 3                  48000            53590  48008.0  53790.0
# 4                  54000            59288  54221.0  59344.0
# ...                  ...              ...      ...      ...
# 2182632            75600            78677  75659.0  79491.0
# 2182633            38700            42098  38607.0  42454.0
# 2182634            44100            48149  43990.0  48039.0
# 2182635            49500            52723  49622.0  54138.0
# 2182636            54900            58565  54905.0  59262.0
#
# [2182637 rows x 9 columns]

# %%
df_trips.columns=['DayOfService','TripID','LineID','RouteID','Direction','PlannedTime_Dep','PlannedTime_Arr','ActualTime_Dep','ActualTime_Arr']
df_trips
# Out:
#         DayOfService   TripID LineID RouteID  Direction  PlannedTime_Dep  \
# 0         2018-01-01  5955277     16   16_20          1            30000
# 1         2018-01-01  5955278     16   16_24          2            36000
# 2         2018-01-01  5955279     16   16_20          1            42000
# 3         2018-01-01  5955280     16   16_24          2            48000
# 4         2018-01-01  5955281     16   16_20          1            54000
# ...              ...      ...    ...     ...        ...              ...
# 2182632   2018-12-31  8592110     11   11_42          2            75600
# 2182633   2018-12-31  8592113     7A   7A_85          1            38700
# 2182634   2018-12-31  8592114     7A   7A_87          2            44100
# 2182635   2018-12-31  8592115     7A   7A_85          1            49500
# 2182636   2018-12-31  8592116     7A   7A_87          2            54900
#
#          PlannedTime_Arr  ActualTime_Dep  ActualTime_Arr
# 0                  33932         30029.0         33184.0
# 1                  40588         35865.0         39653.0
# 2                  47365         41980.0         46619.0
# 3                  53590         48008.0         53790.0
# 4                  59288         54221.0         59344.0
# ...                  ...             ...             ...
# 2182632            78677         75659.0         79491.0
# 2182633            42098         38607.0         42454.0
# 2182634            48149         43990.0         48039.0
# 2182635            52723         49622.0         54138.0
# 2182636            58565         54905.0         59262.0
#
# [2182637 rows x 9 columns]

# %%
df_trips_simple=df_trips[['DayOfService','TripID','LineID','RouteID']]
df_trips_simple
# Out:
#         DayOfService   TripID LineID RouteID
# 0         2018-01-01  5955277     16   16_20
# 1         2018-01-01  5955278     16   16_24
# 2         2018-01-01  5955279     16   16_20
# 3         2018-01-01  5955280     16   16_24
# 4         2018-01-01  5955281     16   16_20
# ...              ...      ...    ...     ...
# 2182632   2018-12-31  8592110     11   11_42
# 2182633   2018-12-31  8592113     7A   7A_85
# 2182634   2018-12-31  8592114     7A   7A_87
# 2182635   2018-12-31  8592115     7A   7A_85
# 2182636   2018-12-31  8592116     7A   7A_87
#
# [2182637 rows x 4 columns]

# %% [markdown]
# ### merge two dataset

# %%
section=pd.merge(df_leaveTime,df_trips_simple,how='left',on=['DayOfService','TripID'])
section
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-10-01  7774781            1          248            24300
# 1         2018-10-01  7774781            2          249            24338
# 2         2018-10-01  7774781            3          250            24406
# 3         2018-10-01  7774781            4          251            24446
# 4         2018-10-01  7774781            5          252            24532
# ...              ...      ...          ...          ...              ...
# 9582767   2018-10-31  8081188           42          908            86043
# 9582768   2018-10-31  8081188           43          909            86075
# 9582769   2018-10-31  8081188           44          786            86109
# 9582770   2018-10-31  8081188           45          792            86236
# 9582771   2018-10-31  8081188           47          320            86392
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID
# 0                 24299           24299    2693256     14   14_15
# 1                 24328           24343    2693256     14   14_15
# 2                 24392           24408    2693256     14   14_15
# 3                 24433           24461    2693256     14   14_15
# 4                 24492           24513    2693256     14   14_15
# ...                 ...             ...        ...    ...     ...
# 9582767           86328           86328    2172238    46A  46A_66
# 9582768           86369           86369    2172238    46A  46A_66
# 9582769           86396           86414    2172238    46A  46A_66
# 9582770           86519           86565    2172238    46A  46A_66
# 9582771           86674           86674    2172238    46A  46A_66
#
# [9582772 rows x 10 columns]

# %% [markdown]
# ### add previous stops

# %%
section_copy=section[['TripID','StopPointID','ActualTime_Arr']]
section_copy.columns=['TripID_2','StopPoint_2','ActualTime_Arr_2']
section_copy
# Out:
#          TripID_2  StopPoint_2  ActualTime_Arr_2
# 0         7774781          248             24299
# 1         7774781          249             24328
# 2         7774781          250             24392
# 3         7774781          251             24433
# 4         7774781          252             24492
# ...           ...          ...               ...
# 9582767   8081188          908             86328
# 9582768   8081188          909             86369
# 9582769   8081188          786             86396
# 9582770   8081188          792             86519
# 9582771   8081188          320             86674
#
# [9582772 rows x 3 columns]

# %%
section_copy.drop(axis=0, index=0,inplace=True)
section_copy
# Out:
# D:\Software\Anaconda\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#          TripID_2  StopPoint_2  ActualTime_Arr_2
# 1         7774781          249             24328
# 2         7774781          250             24392
# 3         7774781          251             24433
# 4         7774781          252             24492
# 5         7774781          255             24541
# ...           ...          ...               ...
# 9582767   8081188          908             86328
# 9582768   8081188          909             86369
# 9582769   8081188          786             86396
# 9582770   8081188          792             86519
# 9582771   8081188          320             86674
#
# [9582771 rows x 3 columns]

# %%
# add new rows
section_copy.loc['new_raw'] = '3'
section_copy
# Out:
# D:\Software\Anaconda\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#         TripID_2 StopPoint_2 ActualTime_Arr_2
# 1        7774781         249            24328
# 2        7774781         250            24392
# 3        7774781         251            24433
# 4        7774781         252            24492
# 5        7774781         255            24541
# ...          ...         ...              ...
# 9582768  8081188         909            86369
# 9582769  8081188         786            86396
# 9582770  8081188         792            86519
# 9582771  8081188         320            86674
# new_raw        3           3                3
#
# [9582772 rows x 3 columns]

# %%
# adject the index
section_copy.index=np.arange(0,9582772)
section_copy
# Out:
#         TripID_2 StopPoint_2 ActualTime_Arr_2
# 0        7774781         249            24328
# 1        7774781         250            24392
# 2        7774781         251            24433
# 3        7774781         252            24492
# 4        7774781         255            24541
# ...          ...         ...              ...
# 9582767  8081188         909            86369
# 9582768  8081188         786            86396
# 9582769  8081188         792            86519
# 9582770  8081188         320            86674
# 9582771        3           3                3
#
# [9582772 rows x 3 columns]

# %%
section_combine = pd.concat([section, section_copy], axis=1,ignore_index=True)

# %%
col_name=[]
for col in section.columns:
    col_name.append(col)
col_name.append('TripID_2')
col_name.append('StopPoint_2')
col_name.append('ActualTime_Arr_2')
col_name
# Out:
# ['DayOfService',
#  'TripID',
#  'ProgrNumber',
#  'StopPointID',
#  'PlannedTime_Arr',
#  'ActualTime_Arr',
#  'ActualTime_Dep',
#  'VehicleID',
#  'LineID',
#  'RouteID',
#  'TripID_2',
#  'StopPoint_2',
#  'ActualTime_Arr_2']

# %%
section_combine.columns=col_name
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-10-01  7774781            1          248            24300
# 1         2018-10-01  7774781            2          249            24338
# 2         2018-10-01  7774781            3          250            24406
# 3         2018-10-01  7774781            4          251            24446
# 4         2018-10-01  7774781            5          252            24532
# ...              ...      ...          ...          ...              ...
# 9582767   2018-10-31  8081188           42          908            86043
# 9582768   2018-10-31  8081188           43          909            86075
# 9582769   2018-10-31  8081188           44          786            86109
# 9582770   2018-10-31  8081188           45          792            86236
# 9582771   2018-10-31  8081188           47          320            86392
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 24299           24299    2693256     14   14_15  7774781
# 1                 24328           24343    2693256     14   14_15  7774781
# 2                 24392           24408    2693256     14   14_15  7774781
# 3                 24433           24461    2693256     14   14_15  7774781
# 4                 24492           24513    2693256     14   14_15  7774781
# ...                 ...             ...        ...    ...     ...      ...
# 9582767           86328           86328    2172238    46A  46A_66  8081188
# 9582768           86369           86369    2172238    46A  46A_66  8081188
# 9582769           86396           86414    2172238    46A  46A_66  8081188
# 9582770           86519           86565    2172238    46A  46A_66  8081188
# 9582771           86674           86674    2172238    46A  46A_66        3
#
#         StopPoint_2 ActualTime_Arr_2
# 0               249            24328
# 1               250            24392
# 2               251            24433
# 3               252            24492
# 4               255            24541
# ...             ...              ...
# 9582767         909            86369
# 9582768         786            86396
# 9582769         792            86519
# 9582770         320            86674
# 9582771           3                3
#
# [9582772 rows x 13 columns]

# %%
#drop the last rows
section_combine.drop(axis=0, index=9582771,inplace=True)
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-10-01  7774781            1          248            24300
# 1         2018-10-01  7774781            2          249            24338
# 2         2018-10-01  7774781            3          250            24406
# 3         2018-10-01  7774781            4          251            24446
# 4         2018-10-01  7774781            5          252            24532
# ...              ...      ...          ...          ...              ...
# 9582766   2018-10-31  8081188           41          907            86018
# 9582767   2018-10-31  8081188           42          908            86043
# 9582768   2018-10-31  8081188           43          909            86075
# 9582769   2018-10-31  8081188           44          786            86109
# 9582770   2018-10-31  8081188           45          792            86236
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 24299           24299    2693256     14   14_15  7774781
# 1                 24328           24343    2693256     14   14_15  7774781
# 2                 24392           24408    2693256     14   14_15  7774781
# 3                 24433           24461    2693256     14   14_15  7774781
# 4                 24492           24513    2693256     14   14_15  7774781
# ...                 ...             ...        ...    ...     ...      ...
# 9582766           86313           86313    2172238    46A  46A_66  8081188
# 9582767           86328           86328    2172238    46A  46A_66  8081188
# 9582768           86369           86369    2172238    46A  46A_66  8081188
# 9582769           86396           86414    2172238    46A  46A_66  8081188
# 9582770           86519           86565    2172238    46A  46A_66  8081188
#
#         StopPoint_2 ActualTime_Arr_2
# 0               249            24328
# 1               250            24392
# 2               251            24433
# 3               252            24492
# 4               255            24541
# ...             ...              ...
# 9582766         908            86328
# 9582767         909            86369
# 9582768         786            86396
# 9582769         792            86519
# 9582770         320            86674
#
# [9582771 rows x 13 columns]

# %%
section_combine['trip_q']=section_combine['TripID_2']-section_combine['TripID']

# %%
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-10-01  7774781            1          248            24300
# 1         2018-10-01  7774781            2          249            24338
# 2         2018-10-01  7774781            3          250            24406
# 3         2018-10-01  7774781            4          251            24446
# 4         2018-10-01  7774781            5          252            24532
# ...              ...      ...          ...          ...              ...
# 9582766   2018-10-31  8081188           41          907            86018
# 9582767   2018-10-31  8081188           42          908            86043
# 9582768   2018-10-31  8081188           43          909            86075
# 9582769   2018-10-31  8081188           44          786            86109
# 9582770   2018-10-31  8081188           45          792            86236
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 24299           24299    2693256     14   14_15  7774781
# 1                 24328           24343    2693256     14   14_15  7774781
# 2                 24392           24408    2693256     14   14_15  7774781
# 3                 24433           24461    2693256     14   14_15  7774781
# 4                 24492           24513    2693256     14   14_15  7774781
# ...                 ...             ...        ...    ...     ...      ...
# 9582766           86313           86313    2172238    46A  46A_66  8081188
# 9582767           86328           86328    2172238    46A  46A_66  8081188
# 9582768           86369           86369    2172238    46A  46A_66  8081188
# 9582769           86396           86414    2172238    46A  46A_66  8081188
# 9582770           86519           86565    2172238    46A  46A_66  8081188
#
#         StopPoint_2 ActualTime_Arr_2 trip_q
# 0               249            24328      0
# 1               250            24392      0
# 2               251            24433      0
# 3               252            24492      0
# 4               255            24541      0
# ...             ...              ...    ...
# 9582766         908            86328      0
# 9582767         909            86369      0
# 9582768         786            86396      0
# 9582769         792            86519      0
# 9582770         320            86674      0
#
# [9582771 rows x 14 columns]

# %%
section_combine['trip_q'].value_counts()
# Out:
# 0      9396572
# 1       168040
# 2         3144
# 3          989
# 11         737
#         ...
# 177          1
# 175          1
# 174          1
# 137          1
# 153          1
# Name: trip_q, Length: 179, dtype: int64

# %%
# if trip_q !=0, we do not need it 
x=section_combine[section_combine['trip_q']==0]

# %%
x['TravelTime']=x['ActualTime_Arr_2']-x['ActualTime_Dep']
x
# Out:
# D:\Software\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-10-01  7774781            1          248            24300
# 1         2018-10-01  7774781            2          249            24338
# 2         2018-10-01  7774781            3          250            24406
# 3         2018-10-01  7774781            4          251            24446
# 4         2018-10-01  7774781            5          252            24532
# ...              ...      ...          ...          ...              ...
# 9582766   2018-10-31  8081188           41          907            86018
# 9582767   2018-10-31  8081188           42          908            86043
# 9582768   2018-10-31  8081188           43          909            86075
# 9582769   2018-10-31  8081188           44          786            86109
# 9582770   2018-10-31  8081188           45          792            86236
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 24299           24299    2693256     14   14_15  7774781
# 1                 24328           24343    2693256     14   14_15  7774781
# 2                 24392           24408    2693256     14   14_15  7774781
# 3                 24433           24461    2693256     14   14_15  7774781
# 4                 24492           24513    2693256     14   14_15  7774781
# ...                 ...             ...        ...    ...     ...      ...
# 9582766           86313           86313    2172238    46A  46A_66  8081188
# 9582767           86328           86328    2172238    46A  46A_66  8081188
# 9582768           86369           86369    2172238    46A  46A_66  8081188
# 9582769           86396           86414    2172238    46A  46A_66  8081188
# 9582770           86519           86565    2172238    46A  46A_66  8081188
#
#         StopPoint_2 ActualTime_Arr_2 trip_q TravelTime
# 0               249            24328      0         29
# 1               250            24392      0         49
# 2               251            24433      0         25
# 3               252            24492      0         31
# 4               255            24541      0         28
# ...             ...              ...    ...        ...
# 9582766         908            86328      0         15
# 9582767         909            86369      0         41
# 9582768         786            86396      0         27
# 9582769         792            86519      0        105
# 9582770         320            86674      0        109
#
# [9396572 rows x 15 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %% [markdown]
# ### there are a lot of unmormal value, drop traveltime which is smaller than 0 first

# %%
x=x[x['TravelTime']>0]

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %%
#drop traveltime >=3000
x=x[x['TravelTime']<3000]

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %%
x.to_csv("../clean_data/oct_section.csv",index=None)
