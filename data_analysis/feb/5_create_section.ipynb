# %% [markdown]
# # 1. Introduction

# %% [markdown]
# The purpose of this notebook is to create initial cleaning of the section data, and to export the cleaned data to a csv file.

# %% [markdown]
# # 2. Setup & Data Load

# %% [markdown]
# Import required modules and packages:

# %%
# import pandas for data analysis
import pandas as pd

#import numpy
import numpy as np

# %%
import gc
gc.collect()
# Out:
# 22

# %% [markdown]
# ### load leavetime

# %%
df_leaveTime=pd.read_csv("../clean_data/leavetime_feb.csv",index_col=0)
df_leaveTime
# Out:
# D:\Software\Anaconda\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-02-01  6228561            1         7571            82800
# 1         2018-02-01  6228561            2          207            82961
# 2         2018-02-01  6228561            3          208            83006
# 3         2018-02-01  6228561            4          209            83051
# 4         2018-02-01  6228561            5          210            83080
# ...              ...      ...          ...          ...              ...
# 9423743   2018-02-28  6297813           55          444            66070
# 9423744   2018-02-28  6297813           56          445            66109
# 9423745   2018-02-28  6297813           57         4779            66150
# 9423746   2018-02-28  6297813           58         7057            66201
# 9423747   2018-02-28  6297813           59         4847            66239
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID
# 0                 82824           82824    2534805
# 1                 83036           83036    2534805
# 2                 83070           83070    2534805
# 3                 83103           83103    2534805
# 4                 83129           83129    2534805
# ...                 ...             ...        ...
# 9423743           64492           64504    2868379
# 9423744           64535           64535    2868379
# 9423745           64565           64565    2868379
# 9423746           64603           64603    2868379
# 9423747           64664           64664    2868379
#
# [8962243 rows x 8 columns]

# %%
df_leaveTime.sort_values(by=['DayOfService','TripID','ProgrNumber'],ascending=[True,True,True])
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-02-01  6228561            1         7571            82800
# 1         2018-02-01  6228561            2          207            82961
# 2         2018-02-01  6228561            3          208            83006
# 3         2018-02-01  6228561            4          209            83051
# 4         2018-02-01  6228561            5          210            83080
# ...              ...      ...          ...          ...              ...
# 9423743   2018-02-28  6297813           55          444            66070
# 9423744   2018-02-28  6297813           56          445            66109
# 9423745   2018-02-28  6297813           57         4779            66150
# 9423746   2018-02-28  6297813           58         7057            66201
# 9423747   2018-02-28  6297813           59         4847            66239
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID
# 0                 82824           82824    2534805
# 1                 83036           83036    2534805
# 2                 83070           83070    2534805
# 3                 83103           83103    2534805
# 4                 83129           83129    2534805
# ...                 ...             ...        ...
# 9423743           64492           64504    2868379
# 9423744           64535           64535    2868379
# 9423745           64565           64565    2868379
# 9423746           64603           64603    2868379
# 9423747           64664           64664    2868379
#
# [8962243 rows x 8 columns]

# %%
df_leaveTime.columns
# Out:
# Index(['DayOfService', 'TripID', 'ProgrNumber', 'StopPointID',
#        'PlannedTime_Arr', 'ActualTime_Arr', 'ActualTime_Dep', 'VehicleID'],
#       dtype='object')

# %% [markdown]
# ### load trips

# %%
df_trips=pd.read_csv("../initial_data/RT_Trips.csv",index_col=0)
df_trips
# Out:
# D:\Software\Anaconda\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#         ActualTime_Arr  ActualTime_Dep DayOfService Direction  LineID  \
# 0           2018-01-01         5955277           16     16_20       1
# 1           2018-01-01         5955278           16     16_24       2
# 2           2018-01-01         5955279           16     16_20       1
# 3           2018-01-01         5955280           16     16_24       2
# 4           2018-01-01         5955281           16     16_20       1
# ...                ...             ...          ...       ...     ...
# 2182632     2018-12-31         8592110           11     11_42       2
# 2182633     2018-12-31         8592113           7A     7A_85       1
# 2182634     2018-12-31         8592114           7A     7A_87       2
# 2182635     2018-12-31         8592115           7A     7A_85       1
# 2182636     2018-12-31         8592116           7A     7A_87       2
#
#          PlannedTime_Arr  PlannedTime_Dep  RouteID   TripID
# 0                  30000            33932  30029.0  33184.0
# 1                  36000            40588  35865.0  39653.0
# 2                  42000            47365  41980.0  46619.0
# 3                  48000            53590  48008.0  53790.0
# 4                  54000            59288  54221.0  59344.0
# ...                  ...              ...      ...      ...
# 2182632            75600            78677  75659.0  79491.0
# 2182633            38700            42098  38607.0  42454.0
# 2182634            44100            48149  43990.0  48039.0
# 2182635            49500            52723  49622.0  54138.0
# 2182636            54900            58565  54905.0  59262.0
#
# [2182637 rows x 9 columns]

# %%
df_trips.columns=['DayOfService','TripID','LineID','RouteID','Direction','PlannedTime_Dep','PlannedTime_Arr','ActualTime_Dep','ActualTime_Arr']
df_trips
# Out:
#         DayOfService   TripID LineID RouteID  Direction  PlannedTime_Dep  \
# 0         2018-01-01  5955277     16   16_20          1            30000
# 1         2018-01-01  5955278     16   16_24          2            36000
# 2         2018-01-01  5955279     16   16_20          1            42000
# 3         2018-01-01  5955280     16   16_24          2            48000
# 4         2018-01-01  5955281     16   16_20          1            54000
# ...              ...      ...    ...     ...        ...              ...
# 2182632   2018-12-31  8592110     11   11_42          2            75600
# 2182633   2018-12-31  8592113     7A   7A_85          1            38700
# 2182634   2018-12-31  8592114     7A   7A_87          2            44100
# 2182635   2018-12-31  8592115     7A   7A_85          1            49500
# 2182636   2018-12-31  8592116     7A   7A_87          2            54900
#
#          PlannedTime_Arr  ActualTime_Dep  ActualTime_Arr
# 0                  33932         30029.0         33184.0
# 1                  40588         35865.0         39653.0
# 2                  47365         41980.0         46619.0
# 3                  53590         48008.0         53790.0
# 4                  59288         54221.0         59344.0
# ...                  ...             ...             ...
# 2182632            78677         75659.0         79491.0
# 2182633            42098         38607.0         42454.0
# 2182634            48149         43990.0         48039.0
# 2182635            52723         49622.0         54138.0
# 2182636            58565         54905.0         59262.0
#
# [2182637 rows x 9 columns]

# %%
df_trips_simple=df_trips[['DayOfService','TripID','LineID','RouteID']]
df_trips_simple
# Out:
#         DayOfService   TripID LineID RouteID
# 0         2018-01-01  5955277     16   16_20
# 1         2018-01-01  5955278     16   16_24
# 2         2018-01-01  5955279     16   16_20
# 3         2018-01-01  5955280     16   16_24
# 4         2018-01-01  5955281     16   16_20
# ...              ...      ...    ...     ...
# 2182632   2018-12-31  8592110     11   11_42
# 2182633   2018-12-31  8592113     7A   7A_85
# 2182634   2018-12-31  8592114     7A   7A_87
# 2182635   2018-12-31  8592115     7A   7A_85
# 2182636   2018-12-31  8592116     7A   7A_87
#
# [2182637 rows x 4 columns]

# %% [markdown]
# ### merge two dataset

# %%
section=pd.merge(df_leaveTime,df_trips_simple,how='left',on=['DayOfService','TripID'])
section
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-02-01  6228561            1         7571            82800
# 1         2018-02-01  6228561            2          207            82961
# 2         2018-02-01  6228561            3          208            83006
# 3         2018-02-01  6228561            4          209            83051
# 4         2018-02-01  6228561            5          210            83080
# ...              ...      ...          ...          ...              ...
# 8962238   2018-02-28  6297813           55          444            66070
# 8962239   2018-02-28  6297813           56          445            66109
# 8962240   2018-02-28  6297813           57         4779            66150
# 8962241   2018-02-28  6297813           58         7057            66201
# 8962242   2018-02-28  6297813           59         4847            66239
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID
# 0                 82824           82824    2534805     44   44_40
# 1                 83036           83036    2534805     44   44_40
# 2                 83070           83070    2534805     44   44_40
# 3                 83103           83103    2534805     44   44_40
# 4                 83129           83129    2534805     44   44_40
# ...                 ...             ...        ...    ...     ...
# 8962238           64492           64504    2868379     11   11_40
# 8962239           64535           64535    2868379     11   11_40
# 8962240           64565           64565    2868379     11   11_40
# 8962241           64603           64603    2868379     11   11_40
# 8962242           64664           64664    2868379     11   11_40
#
# [8962243 rows x 10 columns]

# %% [markdown]
# ### add previous stops

# %%
section_copy=section[['TripID','StopPointID','ActualTime_Arr']]
section_copy.columns=['TripID_2','StopPoint_2','ActualTime_Arr_2']
section_copy
# Out:
#          TripID_2  StopPoint_2  ActualTime_Arr_2
# 0         6228561         7571             82824
# 1         6228561          207             83036
# 2         6228561          208             83070
# 3         6228561          209             83103
# 4         6228561          210             83129
# ...           ...          ...               ...
# 8962238   6297813          444             64492
# 8962239   6297813          445             64535
# 8962240   6297813         4779             64565
# 8962241   6297813         7057             64603
# 8962242   6297813         4847             64664
#
# [8962243 rows x 3 columns]

# %%
section_copy.drop(axis=0, index=0,inplace=True)
section_copy
# Out:
# D:\Software\Anaconda\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#          TripID_2  StopPoint_2  ActualTime_Arr_2
# 1         6228561          207             83036
# 2         6228561          208             83070
# 3         6228561          209             83103
# 4         6228561          210             83129
# 5         6228561          211             83185
# ...           ...          ...               ...
# 8962238   6297813          444             64492
# 8962239   6297813          445             64535
# 8962240   6297813         4779             64565
# 8962241   6297813         7057             64603
# 8962242   6297813         4847             64664
#
# [8962242 rows x 3 columns]

# %%
# add new rows
section_copy.loc['new_raw'] = '3'
section_copy
# Out:
# D:\Software\Anaconda\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#         TripID_2 StopPoint_2 ActualTime_Arr_2
# 1        6228561         207            83036
# 2        6228561         208            83070
# 3        6228561         209            83103
# 4        6228561         210            83129
# 5        6228561         211            83185
# ...          ...         ...              ...
# 8962239  6297813         445            64535
# 8962240  6297813        4779            64565
# 8962241  6297813        7057            64603
# 8962242  6297813        4847            64664
# new_raw        3           3                3
#
# [8962243 rows x 3 columns]

# %%
# adject the index
section_copy.index=np.arange(0,8962243)
section_copy
# Out:
#         TripID_2 StopPoint_2 ActualTime_Arr_2
# 0        6228561         207            83036
# 1        6228561         208            83070
# 2        6228561         209            83103
# 3        6228561         210            83129
# 4        6228561         211            83185
# ...          ...         ...              ...
# 8962238  6297813         445            64535
# 8962239  6297813        4779            64565
# 8962240  6297813        7057            64603
# 8962241  6297813        4847            64664
# 8962242        3           3                3
#
# [8962243 rows x 3 columns]

# %%
section_combine = pd.concat([section, section_copy], axis=1,ignore_index=True)

# %%
col_name=[]
for col in section.columns:
    col_name.append(col)
col_name.append('TripID_2')
col_name.append('StopPoint_2')
col_name.append('ActualTime_Arr_2')
col_name
# Out:
# ['DayOfService',
#  'TripID',
#  'ProgrNumber',
#  'StopPointID',
#  'PlannedTime_Arr',
#  'ActualTime_Arr',
#  'ActualTime_Dep',
#  'VehicleID',
#  'LineID',
#  'RouteID',
#  'TripID_2',
#  'StopPoint_2',
#  'ActualTime_Arr_2']

# %%
section_combine.columns=col_name
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-02-01  6228561            1         7571            82800
# 1         2018-02-01  6228561            2          207            82961
# 2         2018-02-01  6228561            3          208            83006
# 3         2018-02-01  6228561            4          209            83051
# 4         2018-02-01  6228561            5          210            83080
# ...              ...      ...          ...          ...              ...
# 8962238   2018-02-28  6297813           55          444            66070
# 8962239   2018-02-28  6297813           56          445            66109
# 8962240   2018-02-28  6297813           57         4779            66150
# 8962241   2018-02-28  6297813           58         7057            66201
# 8962242   2018-02-28  6297813           59         4847            66239
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 82824           82824    2534805     44   44_40  6228561
# 1                 83036           83036    2534805     44   44_40  6228561
# 2                 83070           83070    2534805     44   44_40  6228561
# 3                 83103           83103    2534805     44   44_40  6228561
# 4                 83129           83129    2534805     44   44_40  6228561
# ...                 ...             ...        ...    ...     ...      ...
# 8962238           64492           64504    2868379     11   11_40  6297813
# 8962239           64535           64535    2868379     11   11_40  6297813
# 8962240           64565           64565    2868379     11   11_40  6297813
# 8962241           64603           64603    2868379     11   11_40  6297813
# 8962242           64664           64664    2868379     11   11_40        3
#
#         StopPoint_2 ActualTime_Arr_2
# 0               207            83036
# 1               208            83070
# 2               209            83103
# 3               210            83129
# 4               211            83185
# ...             ...              ...
# 8962238         445            64535
# 8962239        4779            64565
# 8962240        7057            64603
# 8962241        4847            64664
# 8962242           3                3
#
# [8962243 rows x 13 columns]

# %%
#drop the last rows
section_combine.drop(axis=0, index=8962242,inplace=True)
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-02-01  6228561            1         7571            82800
# 1         2018-02-01  6228561            2          207            82961
# 2         2018-02-01  6228561            3          208            83006
# 3         2018-02-01  6228561            4          209            83051
# 4         2018-02-01  6228561            5          210            83080
# ...              ...      ...          ...          ...              ...
# 8962237   2018-02-28  6297813           54          443            66037
# 8962238   2018-02-28  6297813           55          444            66070
# 8962239   2018-02-28  6297813           56          445            66109
# 8962240   2018-02-28  6297813           57         4779            66150
# 8962241   2018-02-28  6297813           58         7057            66201
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 82824           82824    2534805     44   44_40  6228561
# 1                 83036           83036    2534805     44   44_40  6228561
# 2                 83070           83070    2534805     44   44_40  6228561
# 3                 83103           83103    2534805     44   44_40  6228561
# 4                 83129           83129    2534805     44   44_40  6228561
# ...                 ...             ...        ...    ...     ...      ...
# 8962237           64464           64464    2868379     11   11_40  6297813
# 8962238           64492           64504    2868379     11   11_40  6297813
# 8962239           64535           64535    2868379     11   11_40  6297813
# 8962240           64565           64565    2868379     11   11_40  6297813
# 8962241           64603           64603    2868379     11   11_40  6297813
#
#         StopPoint_2 ActualTime_Arr_2
# 0               207            83036
# 1               208            83070
# 2               209            83103
# 3               210            83129
# 4               211            83185
# ...             ...              ...
# 8962237         444            64492
# 8962238         445            64535
# 8962239        4779            64565
# 8962240        7057            64603
# 8962241        4847            64664
#
# [8962242 rows x 13 columns]

# %%
section_combine['trip_q']=section_combine['TripID_2']-section_combine['TripID']

# %%
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-02-01  6228561            1         7571            82800
# 1         2018-02-01  6228561            2          207            82961
# 2         2018-02-01  6228561            3          208            83006
# 3         2018-02-01  6228561            4          209            83051
# 4         2018-02-01  6228561            5          210            83080
# ...              ...      ...          ...          ...              ...
# 8962237   2018-02-28  6297813           54          443            66037
# 8962238   2018-02-28  6297813           55          444            66070
# 8962239   2018-02-28  6297813           56          445            66109
# 8962240   2018-02-28  6297813           57         4779            66150
# 8962241   2018-02-28  6297813           58         7057            66201
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 82824           82824    2534805     44   44_40  6228561
# 1                 83036           83036    2534805     44   44_40  6228561
# 2                 83070           83070    2534805     44   44_40  6228561
# 3                 83103           83103    2534805     44   44_40  6228561
# 4                 83129           83129    2534805     44   44_40  6228561
# ...                 ...             ...        ...    ...     ...      ...
# 8962237           64464           64464    2868379     11   11_40  6297813
# 8962238           64492           64504    2868379     11   11_40  6297813
# 8962239           64535           64535    2868379     11   11_40  6297813
# 8962240           64565           64565    2868379     11   11_40  6297813
# 8962241           64603           64603    2868379     11   11_40  6297813
#
#         StopPoint_2 ActualTime_Arr_2 trip_q
# 0               207            83036      0
# 1               208            83070      0
# 2               209            83103      0
# 3               210            83129      0
# 4               211            83185      0
# ...             ...              ...    ...
# 8962237         444            64492      0
# 8962238         445            64535      0
# 8962239        4779            64565      0
# 8962240        7057            64603      0
# 8962241        4847            64664      0
#
# [8962242 rows x 14 columns]

# %%
section_combine['trip_q'].value_counts()
# Out:
#  0        8786147
#  1         160203
#  2           2396
#  3            659
#  11           632
#            ...
#  154            1
#  150            1
#  97             1
#  106            1
# -17225          1
# Name: trip_q, Length: 154, dtype: int64

# %%
# if trip_q !=0, we do not need it 
x=section_combine[section_combine['trip_q']==0]

# %%
x['TravelTime']=x['ActualTime_Arr_2']-x['ActualTime_Dep']
x
# Out:
# D:\Software\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-02-01  6228561            1         7571            82800
# 1         2018-02-01  6228561            2          207            82961
# 2         2018-02-01  6228561            3          208            83006
# 3         2018-02-01  6228561            4          209            83051
# 4         2018-02-01  6228561            5          210            83080
# ...              ...      ...          ...          ...              ...
# 8962237   2018-02-28  6297813           54          443            66037
# 8962238   2018-02-28  6297813           55          444            66070
# 8962239   2018-02-28  6297813           56          445            66109
# 8962240   2018-02-28  6297813           57         4779            66150
# 8962241   2018-02-28  6297813           58         7057            66201
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 82824           82824    2534805     44   44_40  6228561
# 1                 83036           83036    2534805     44   44_40  6228561
# 2                 83070           83070    2534805     44   44_40  6228561
# 3                 83103           83103    2534805     44   44_40  6228561
# 4                 83129           83129    2534805     44   44_40  6228561
# ...                 ...             ...        ...    ...     ...      ...
# 8962237           64464           64464    2868379     11   11_40  6297813
# 8962238           64492           64504    2868379     11   11_40  6297813
# 8962239           64535           64535    2868379     11   11_40  6297813
# 8962240           64565           64565    2868379     11   11_40  6297813
# 8962241           64603           64603    2868379     11   11_40  6297813
#
#         StopPoint_2 ActualTime_Arr_2 trip_q TravelTime
# 0               207            83036      0        212
# 1               208            83070      0         34
# 2               209            83103      0         33
# 3               210            83129      0         26
# 4               211            83185      0         56
# ...             ...              ...    ...        ...
# 8962237         444            64492      0         28
# 8962238         445            64535      0         31
# 8962239        4779            64565      0         30
# 8962240        7057            64603      0         38
# 8962241        4847            64664      0         61
#
# [8786147 rows x 15 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %% [markdown]
# ### there are a lot of unmormal value, drop traveltime which is smaller than 0 first

# %%
x=x[x['TravelTime']>0]

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %%
#drop traveltime >=3000
x=x[x['TravelTime']<3000]

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %%
x.to_csv("../clean_data/feb_section.csv",index=None)
