# %% [markdown]
# # 1. Introduction

# %% [markdown]
# The purpose of this notebook is to create initial cleaning of the section data, and to export the cleaned data to a csv file.

# %% [markdown]
# # 2. Setup & Data Load

# %% [markdown]
# Import required modules and packages:

# %%
# import pandas for data analysis
import pandas as pd

#import numpy
import numpy as np

# %%
import gc
gc.collect()
# Out:
# 22

# %% [markdown]
# ### load leavetime

# %%
df_leaveTime=pd.read_csv("../clean_data/leavetime_apr.csv",index_col=0)
df_leaveTime
# Out:
# D:\Software\Anaconda\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-04-01  6578855            1         4392            84600
# 1         2018-04-01  6578855            2         2458            84631
# 2         2018-04-01  6578855            3         2446            84662
# 3         2018-04-01  6578855            4         2459            84693
# 4         2018-04-01  6578855            5         2460            84729
# ...              ...      ...          ...          ...              ...
# 9863043   2018-04-30  6665601           70          618            75791
# 9863044   2018-04-30  6665601           71          619            75825
# 9863045   2018-04-30  6665601           72          675            75843
# 9863046   2018-04-30  6665601           73          620            75960
# 9863047   2018-04-30  6665601           74         7569            76030
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID
# 0                 84590           84590    2693269
# 1                 84633           84633    2693269
# 2                 84663           84663    2693269
# 3                 84687           84687    2693269
# 4                 84716           84716    2693269
# ...                 ...             ...        ...
# 9863043           75786           75786    1001074
# 9863044           75863           75876    1001074
# 9863045           75892           75892    1001074
# 9863046           75966           75966    1001074
# 9863047           76160           76160    1001074
#
# [9378394 rows x 8 columns]

# %%
df_leaveTime.sort_values(by=['DayOfService','TripID','ProgrNumber'],ascending=[True,True,True])
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-04-01  6578855            1         4392            84600
# 1         2018-04-01  6578855            2         2458            84631
# 2         2018-04-01  6578855            3         2446            84662
# 3         2018-04-01  6578855            4         2459            84693
# 4         2018-04-01  6578855            5         2460            84729
# ...              ...      ...          ...          ...              ...
# 9863043   2018-04-30  6665601           70          618            75791
# 9863044   2018-04-30  6665601           71          619            75825
# 9863045   2018-04-30  6665601           72          675            75843
# 9863046   2018-04-30  6665601           73          620            75960
# 9863047   2018-04-30  6665601           74         7569            76030
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID
# 0                 84590           84590    2693269
# 1                 84633           84633    2693269
# 2                 84663           84663    2693269
# 3                 84687           84687    2693269
# 4                 84716           84716    2693269
# ...                 ...             ...        ...
# 9863043           75786           75786    1001074
# 9863044           75863           75876    1001074
# 9863045           75892           75892    1001074
# 9863046           75966           75966    1001074
# 9863047           76160           76160    1001074
#
# [9378394 rows x 8 columns]

# %%
df_leaveTime.columns
# Out:
# Index(['DayOfService', 'TripID', 'ProgrNumber', 'StopPointID',
#        'PlannedTime_Arr', 'ActualTime_Arr', 'ActualTime_Dep', 'VehicleID'],
#       dtype='object')

# %% [markdown]
# ### load trips

# %%
df_trips=pd.read_csv("../initial_data/RT_Trips.csv",index_col=0)
df_trips
# Out:
# D:\Software\Anaconda\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#         ActualTime_Arr  ActualTime_Dep DayOfService Direction  LineID  \
# 0           2018-01-01         5955277           16     16_20       1
# 1           2018-01-01         5955278           16     16_24       2
# 2           2018-01-01         5955279           16     16_20       1
# 3           2018-01-01         5955280           16     16_24       2
# 4           2018-01-01         5955281           16     16_20       1
# ...                ...             ...          ...       ...     ...
# 2182632     2018-12-31         8592110           11     11_42       2
# 2182633     2018-12-31         8592113           7A     7A_85       1
# 2182634     2018-12-31         8592114           7A     7A_87       2
# 2182635     2018-12-31         8592115           7A     7A_85       1
# 2182636     2018-12-31         8592116           7A     7A_87       2
#
#          PlannedTime_Arr  PlannedTime_Dep  RouteID   TripID
# 0                  30000            33932  30029.0  33184.0
# 1                  36000            40588  35865.0  39653.0
# 2                  42000            47365  41980.0  46619.0
# 3                  48000            53590  48008.0  53790.0
# 4                  54000            59288  54221.0  59344.0
# ...                  ...              ...      ...      ...
# 2182632            75600            78677  75659.0  79491.0
# 2182633            38700            42098  38607.0  42454.0
# 2182634            44100            48149  43990.0  48039.0
# 2182635            49500            52723  49622.0  54138.0
# 2182636            54900            58565  54905.0  59262.0
#
# [2182637 rows x 9 columns]

# %%
df_trips.columns=['DayOfService','TripID','LineID','RouteID','Direction','PlannedTime_Dep','PlannedTime_Arr','ActualTime_Dep','ActualTime_Arr']
df_trips
# Out:
#         DayOfService   TripID LineID RouteID  Direction  PlannedTime_Dep  \
# 0         2018-01-01  5955277     16   16_20          1            30000
# 1         2018-01-01  5955278     16   16_24          2            36000
# 2         2018-01-01  5955279     16   16_20          1            42000
# 3         2018-01-01  5955280     16   16_24          2            48000
# 4         2018-01-01  5955281     16   16_20          1            54000
# ...              ...      ...    ...     ...        ...              ...
# 2182632   2018-12-31  8592110     11   11_42          2            75600
# 2182633   2018-12-31  8592113     7A   7A_85          1            38700
# 2182634   2018-12-31  8592114     7A   7A_87          2            44100
# 2182635   2018-12-31  8592115     7A   7A_85          1            49500
# 2182636   2018-12-31  8592116     7A   7A_87          2            54900
#
#          PlannedTime_Arr  ActualTime_Dep  ActualTime_Arr
# 0                  33932         30029.0         33184.0
# 1                  40588         35865.0         39653.0
# 2                  47365         41980.0         46619.0
# 3                  53590         48008.0         53790.0
# 4                  59288         54221.0         59344.0
# ...                  ...             ...             ...
# 2182632            78677         75659.0         79491.0
# 2182633            42098         38607.0         42454.0
# 2182634            48149         43990.0         48039.0
# 2182635            52723         49622.0         54138.0
# 2182636            58565         54905.0         59262.0
#
# [2182637 rows x 9 columns]

# %%
df_trips_simple=df_trips[['DayOfService','TripID','LineID','RouteID']]
df_trips_simple
# Out:
#         DayOfService   TripID LineID RouteID
# 0         2018-01-01  5955277     16   16_20
# 1         2018-01-01  5955278     16   16_24
# 2         2018-01-01  5955279     16   16_20
# 3         2018-01-01  5955280     16   16_24
# 4         2018-01-01  5955281     16   16_20
# ...              ...      ...    ...     ...
# 2182632   2018-12-31  8592110     11   11_42
# 2182633   2018-12-31  8592113     7A   7A_85
# 2182634   2018-12-31  8592114     7A   7A_87
# 2182635   2018-12-31  8592115     7A   7A_85
# 2182636   2018-12-31  8592116     7A   7A_87
#
# [2182637 rows x 4 columns]

# %% [markdown]
# ### merge two dataset

# %%
section=pd.merge(df_leaveTime,df_trips_simple,how='left',on=['DayOfService','TripID'])
section
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-04-01  6578855            1         4392            84600
# 1         2018-04-01  6578855            2         2458            84631
# 2         2018-04-01  6578855            3         2446            84662
# 3         2018-04-01  6578855            4         2459            84693
# 4         2018-04-01  6578855            5         2460            84729
# ...              ...      ...          ...          ...              ...
# 9378389   2018-04-30  6665601           70          618            75791
# 9378390   2018-04-30  6665601           71          619            75825
# 9378391   2018-04-30  6665601           72          675            75843
# 9378392   2018-04-30  6665601           73          620            75960
# 9378393   2018-04-30  6665601           74         7569            76030
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID
# 0                 84590           84590    2693269      9     9_8
# 1                 84633           84633    2693269      9     9_8
# 2                 84663           84663    2693269      9     9_8
# 3                 84687           84687    2693269      9     9_8
# 4                 84716           84716    2693269      9     9_8
# ...                 ...             ...        ...    ...     ...
# 9378389           75786           75786    1001074    31A  31A_26
# 9378390           75863           75876    1001074    31A  31A_26
# 9378391           75892           75892    1001074    31A  31A_26
# 9378392           75966           75966    1001074    31A  31A_26
# 9378393           76160           76160    1001074    31A  31A_26
#
# [9378394 rows x 10 columns]

# %% [markdown]
# ### add previous stops

# %%
section_copy=section[['TripID','StopPointID','ActualTime_Arr']]
section_copy.columns=['TripID_2','StopPoint_2','ActualTime_Arr_2']
section_copy
# Out:
#          TripID_2  StopPoint_2  ActualTime_Arr_2
# 0         6578855         4392             84590
# 1         6578855         2458             84633
# 2         6578855         2446             84663
# 3         6578855         2459             84687
# 4         6578855         2460             84716
# ...           ...          ...               ...
# 9378389   6665601          618             75786
# 9378390   6665601          619             75863
# 9378391   6665601          675             75892
# 9378392   6665601          620             75966
# 9378393   6665601         7569             76160
#
# [9378394 rows x 3 columns]

# %%
section_copy.drop(axis=0, index=0,inplace=True)
section_copy
# Out:
# D:\Software\Anaconda\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#          TripID_2  StopPoint_2  ActualTime_Arr_2
# 1         6578855         2458             84633
# 2         6578855         2446             84663
# 3         6578855         2459             84687
# 4         6578855         2460             84716
# 5         6578855         2461             84747
# ...           ...          ...               ...
# 9378389   6665601          618             75786
# 9378390   6665601          619             75863
# 9378391   6665601          675             75892
# 9378392   6665601          620             75966
# 9378393   6665601         7569             76160
#
# [9378393 rows x 3 columns]

# %%
# add new rows
section_copy.loc['new_raw'] = '3'
section_copy
# Out:
# D:\Software\Anaconda\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#         TripID_2 StopPoint_2 ActualTime_Arr_2
# 1        6578855        2458            84633
# 2        6578855        2446            84663
# 3        6578855        2459            84687
# 4        6578855        2460            84716
# 5        6578855        2461            84747
# ...          ...         ...              ...
# 9378390  6665601         619            75863
# 9378391  6665601         675            75892
# 9378392  6665601         620            75966
# 9378393  6665601        7569            76160
# new_raw        3           3                3
#
# [9378394 rows x 3 columns]

# %%
# adject the index
section_copy.index=np.arange(0,9378394)
section_copy
# Out:
#         TripID_2 StopPoint_2 ActualTime_Arr_2
# 0        6578855        2458            84633
# 1        6578855        2446            84663
# 2        6578855        2459            84687
# 3        6578855        2460            84716
# 4        6578855        2461            84747
# ...          ...         ...              ...
# 9378389  6665601         619            75863
# 9378390  6665601         675            75892
# 9378391  6665601         620            75966
# 9378392  6665601        7569            76160
# 9378393        3           3                3
#
# [9378394 rows x 3 columns]

# %%
section_combine = pd.concat([section, section_copy], axis=1,ignore_index=True)

# %%
col_name=[]
for col in section.columns:
    col_name.append(col)
col_name.append('TripID_2')
col_name.append('StopPoint_2')
col_name.append('ActualTime_Arr_2')
col_name
# Out:
# ['DayOfService',
#  'TripID',
#  'ProgrNumber',
#  'StopPointID',
#  'PlannedTime_Arr',
#  'ActualTime_Arr',
#  'ActualTime_Dep',
#  'VehicleID',
#  'LineID',
#  'RouteID',
#  'TripID_2',
#  'StopPoint_2',
#  'ActualTime_Arr_2']

# %%
section_combine.columns=col_name
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-04-01  6578855            1         4392            84600
# 1         2018-04-01  6578855            2         2458            84631
# 2         2018-04-01  6578855            3         2446            84662
# 3         2018-04-01  6578855            4         2459            84693
# 4         2018-04-01  6578855            5         2460            84729
# ...              ...      ...          ...          ...              ...
# 9378389   2018-04-30  6665601           70          618            75791
# 9378390   2018-04-30  6665601           71          619            75825
# 9378391   2018-04-30  6665601           72          675            75843
# 9378392   2018-04-30  6665601           73          620            75960
# 9378393   2018-04-30  6665601           74         7569            76030
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 84590           84590    2693269      9     9_8  6578855
# 1                 84633           84633    2693269      9     9_8  6578855
# 2                 84663           84663    2693269      9     9_8  6578855
# 3                 84687           84687    2693269      9     9_8  6578855
# 4                 84716           84716    2693269      9     9_8  6578855
# ...                 ...             ...        ...    ...     ...      ...
# 9378389           75786           75786    1001074    31A  31A_26  6665601
# 9378390           75863           75876    1001074    31A  31A_26  6665601
# 9378391           75892           75892    1001074    31A  31A_26  6665601
# 9378392           75966           75966    1001074    31A  31A_26  6665601
# 9378393           76160           76160    1001074    31A  31A_26        3
#
#         StopPoint_2 ActualTime_Arr_2
# 0              2458            84633
# 1              2446            84663
# 2              2459            84687
# 3              2460            84716
# 4              2461            84747
# ...             ...              ...
# 9378389         619            75863
# 9378390         675            75892
# 9378391         620            75966
# 9378392        7569            76160
# 9378393           3                3
#
# [9378394 rows x 13 columns]

# %%
#drop the last rows
section_combine.drop(axis=0, index=9378393,inplace=True)
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-04-01  6578855            1         4392            84600
# 1         2018-04-01  6578855            2         2458            84631
# 2         2018-04-01  6578855            3         2446            84662
# 3         2018-04-01  6578855            4         2459            84693
# 4         2018-04-01  6578855            5         2460            84729
# ...              ...      ...          ...          ...              ...
# 9378388   2018-04-30  6665601           69          617            75752
# 9378389   2018-04-30  6665601           70          618            75791
# 9378390   2018-04-30  6665601           71          619            75825
# 9378391   2018-04-30  6665601           72          675            75843
# 9378392   2018-04-30  6665601           73          620            75960
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 84590           84590    2693269      9     9_8  6578855
# 1                 84633           84633    2693269      9     9_8  6578855
# 2                 84663           84663    2693269      9     9_8  6578855
# 3                 84687           84687    2693269      9     9_8  6578855
# 4                 84716           84716    2693269      9     9_8  6578855
# ...                 ...             ...        ...    ...     ...      ...
# 9378388           75762           75762    1001074    31A  31A_26  6665601
# 9378389           75786           75786    1001074    31A  31A_26  6665601
# 9378390           75863           75876    1001074    31A  31A_26  6665601
# 9378391           75892           75892    1001074    31A  31A_26  6665601
# 9378392           75966           75966    1001074    31A  31A_26  6665601
#
#         StopPoint_2 ActualTime_Arr_2
# 0              2458            84633
# 1              2446            84663
# 2              2459            84687
# 3              2460            84716
# 4              2461            84747
# ...             ...              ...
# 9378388         618            75786
# 9378389         619            75863
# 9378390         675            75892
# 9378391         620            75966
# 9378392        7569            76160
#
# [9378393 rows x 13 columns]

# %%
section_combine['trip_q']=section_combine['TripID_2']-section_combine['TripID']

# %%
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-04-01  6578855            1         4392            84600
# 1         2018-04-01  6578855            2         2458            84631
# 2         2018-04-01  6578855            3         2446            84662
# 3         2018-04-01  6578855            4         2459            84693
# 4         2018-04-01  6578855            5         2460            84729
# ...              ...      ...          ...          ...              ...
# 9378388   2018-04-30  6665601           69          617            75752
# 9378389   2018-04-30  6665601           70          618            75791
# 9378390   2018-04-30  6665601           71          619            75825
# 9378391   2018-04-30  6665601           72          675            75843
# 9378392   2018-04-30  6665601           73          620            75960
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 84590           84590    2693269      9     9_8  6578855
# 1                 84633           84633    2693269      9     9_8  6578855
# 2                 84663           84663    2693269      9     9_8  6578855
# 3                 84687           84687    2693269      9     9_8  6578855
# 4                 84716           84716    2693269      9     9_8  6578855
# ...                 ...             ...        ...    ...     ...      ...
# 9378388           75762           75762    1001074    31A  31A_26  6665601
# 9378389           75786           75786    1001074    31A  31A_26  6665601
# 9378390           75863           75876    1001074    31A  31A_26  6665601
# 9378391           75892           75892    1001074    31A  31A_26  6665601
# 9378392           75966           75966    1001074    31A  31A_26  6665601
#
#         StopPoint_2 ActualTime_Arr_2 trip_q
# 0              2458            84633      0
# 1              2446            84663      0
# 2              2459            84687      0
# 3              2460            84716      0
# 4              2461            84747      0
# ...             ...              ...    ...
# 9378388         618            75786      0
# 9378389         619            75863      0
# 9378390         675            75892      0
# 9378391         620            75966      0
# 9378392        7569            76160      0
#
# [9378393 rows x 14 columns]

# %%
section_combine['trip_q'].value_counts()
# Out:
#  0        9194722
#  1         165776
#  2           2688
#  3            891
#  11           712
#            ...
#  149            1
#  152            1
#  156            1
#  162            1
# -17278          1
# Name: trip_q, Length: 175, dtype: int64

# %%
# if trip_q !=0, we do not need it 
x=section_combine[section_combine['trip_q']==0]

# %%
x['TravelTime']=x['ActualTime_Arr_2']-x['ActualTime_Dep']
x
# Out:
# D:\Software\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-04-01  6578855            1         4392            84600
# 1         2018-04-01  6578855            2         2458            84631
# 2         2018-04-01  6578855            3         2446            84662
# 3         2018-04-01  6578855            4         2459            84693
# 4         2018-04-01  6578855            5         2460            84729
# ...              ...      ...          ...          ...              ...
# 9378388   2018-04-30  6665601           69          617            75752
# 9378389   2018-04-30  6665601           70          618            75791
# 9378390   2018-04-30  6665601           71          619            75825
# 9378391   2018-04-30  6665601           72          675            75843
# 9378392   2018-04-30  6665601           73          620            75960
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 84590           84590    2693269      9     9_8  6578855
# 1                 84633           84633    2693269      9     9_8  6578855
# 2                 84663           84663    2693269      9     9_8  6578855
# 3                 84687           84687    2693269      9     9_8  6578855
# 4                 84716           84716    2693269      9     9_8  6578855
# ...                 ...             ...        ...    ...     ...      ...
# 9378388           75762           75762    1001074    31A  31A_26  6665601
# 9378389           75786           75786    1001074    31A  31A_26  6665601
# 9378390           75863           75876    1001074    31A  31A_26  6665601
# 9378391           75892           75892    1001074    31A  31A_26  6665601
# 9378392           75966           75966    1001074    31A  31A_26  6665601
#
#         StopPoint_2 ActualTime_Arr_2 trip_q TravelTime
# 0              2458            84633      0         43
# 1              2446            84663      0         30
# 2              2459            84687      0         24
# 3              2460            84716      0         29
# 4              2461            84747      0         31
# ...             ...              ...    ...        ...
# 9378388         618            75786      0         24
# 9378389         619            75863      0         77
# 9378390         675            75892      0         16
# 9378391         620            75966      0         74
# 9378392        7569            76160      0        194
#
# [9194722 rows x 15 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %% [markdown]
# ### there are a lot of unmormal value, drop traveltime which is smaller than 0 first

# %%
x=x[x['TravelTime']>0]

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %%
#drop traveltime >=3000
x=x[x['TravelTime']<3000]

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %%
x.to_csv("../clean_data/apr_section.csv",index=None)
