# %% [markdown]
# # 1. Introduction

# %% [markdown]
# The purpose of this notebook is to create initial cleaning of the section data, and to export the cleaned data to a csv file.

# %% [markdown]
# # 2. Setup & Data Load

# %% [markdown]
# Import required modules and packages:

# %%
# import pandas for data analysis
import pandas as pd

#import numpy
import numpy as np

# %%
import gc
gc.collect()
# Out:
# 22

# %% [markdown]
# ### load leavetime

# %%
df_leaveTime=pd.read_csv("../clean_data/leavetime_AUG.csv",index_col=0)
df_leaveTime
# Out:
#          DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0          2018-08-01  7315261            1         6004            25800
# 1          2018-08-01  7315261            2            3            25861
# 2          2018-08-01  7315261            3          192            26016
# 3          2018-08-01  7315261            4          795            26041
# 4          2018-08-01  7315261            5          796            26069
# ...               ...      ...          ...          ...              ...
# 10019221   2018-08-31  7515232           67          760            61083
# 10019222   2018-08-31  7515232           68          761            61114
# 10019223   2018-08-31  7515232           69          762            61141
# 10019224   2018-08-31  7515232           70          763            61203
# 10019225   2018-08-31  7515232           71          767            61399
#
#           ActualTime_Arr  ActualTime_Dep  VehicleID
# 0                  25849           25849    1000900
# 1                  25957           25971    1000900
# 2                  26210           26210    1000900
# 3                  26236           26236    1000900
# 4                  26253           26269    1000900
# ...                  ...             ...        ...
# 10019221           62245           62262    1000938
# 10019222           62301           62307    1000938
# 10019223           62333           62333    1000938
# 10019224           62416           62416    1000938
# 10019225           62653           62653    1000938
#
# [9515653 rows x 8 columns]

# %%
df_leaveTime.sort_values(by=['DayOfService','TripID','ProgrNumber'],ascending=[True,True,True])
# Out:
#          DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0          2018-08-01  7315261            1         6004            25800
# 1          2018-08-01  7315261            2            3            25861
# 2          2018-08-01  7315261            3          192            26016
# 3          2018-08-01  7315261            4          795            26041
# 4          2018-08-01  7315261            5          796            26069
# ...               ...      ...          ...          ...              ...
# 10019221   2018-08-31  7515232           67          760            61083
# 10019222   2018-08-31  7515232           68          761            61114
# 10019223   2018-08-31  7515232           69          762            61141
# 10019224   2018-08-31  7515232           70          763            61203
# 10019225   2018-08-31  7515232           71          767            61399
#
#           ActualTime_Arr  ActualTime_Dep  VehicleID
# 0                  25849           25849    1000900
# 1                  25957           25971    1000900
# 2                  26210           26210    1000900
# 3                  26236           26236    1000900
# 4                  26253           26269    1000900
# ...                  ...             ...        ...
# 10019221           62245           62262    1000938
# 10019222           62301           62307    1000938
# 10019223           62333           62333    1000938
# 10019224           62416           62416    1000938
# 10019225           62653           62653    1000938
#
# [9515653 rows x 8 columns]

# %%
df_leaveTime.columns
# Out:
# Index(['DayOfService', 'TripID', 'ProgrNumber', 'StopPointID',
#        'PlannedTime_Arr', 'ActualTime_Arr', 'ActualTime_Dep', 'VehicleID'],
#       dtype='object')

# %% [markdown]
# ### load trips

# %%
df_trips=pd.read_csv("../initial_data/RT_Trips.csv",index_col=0)
df_trips
# Out:
# D:\Software\Anaconda\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#         ActualTime_Arr  ActualTime_Dep DayOfService Direction  LineID  \
# 0           2018-01-01         5955277           16     16_20       1
# 1           2018-01-01         5955278           16     16_24       2
# 2           2018-01-01         5955279           16     16_20       1
# 3           2018-01-01         5955280           16     16_24       2
# 4           2018-01-01         5955281           16     16_20       1
# ...                ...             ...          ...       ...     ...
# 2182632     2018-12-31         8592110           11     11_42       2
# 2182633     2018-12-31         8592113           7A     7A_85       1
# 2182634     2018-12-31         8592114           7A     7A_87       2
# 2182635     2018-12-31         8592115           7A     7A_85       1
# 2182636     2018-12-31         8592116           7A     7A_87       2
#
#          PlannedTime_Arr  PlannedTime_Dep  RouteID   TripID
# 0                  30000            33932  30029.0  33184.0
# 1                  36000            40588  35865.0  39653.0
# 2                  42000            47365  41980.0  46619.0
# 3                  48000            53590  48008.0  53790.0
# 4                  54000            59288  54221.0  59344.0
# ...                  ...              ...      ...      ...
# 2182632            75600            78677  75659.0  79491.0
# 2182633            38700            42098  38607.0  42454.0
# 2182634            44100            48149  43990.0  48039.0
# 2182635            49500            52723  49622.0  54138.0
# 2182636            54900            58565  54905.0  59262.0
#
# [2182637 rows x 9 columns]

# %%
df_trips.columns=['DayOfService','TripID','LineID','RouteID','Direction','PlannedTime_Dep','PlannedTime_Arr','ActualTime_Dep','ActualTime_Arr']
df_trips
# Out:
#         DayOfService   TripID LineID RouteID  Direction  PlannedTime_Dep  \
# 0         2018-01-01  5955277     16   16_20          1            30000
# 1         2018-01-01  5955278     16   16_24          2            36000
# 2         2018-01-01  5955279     16   16_20          1            42000
# 3         2018-01-01  5955280     16   16_24          2            48000
# 4         2018-01-01  5955281     16   16_20          1            54000
# ...              ...      ...    ...     ...        ...              ...
# 2182632   2018-12-31  8592110     11   11_42          2            75600
# 2182633   2018-12-31  8592113     7A   7A_85          1            38700
# 2182634   2018-12-31  8592114     7A   7A_87          2            44100
# 2182635   2018-12-31  8592115     7A   7A_85          1            49500
# 2182636   2018-12-31  8592116     7A   7A_87          2            54900
#
#          PlannedTime_Arr  ActualTime_Dep  ActualTime_Arr
# 0                  33932         30029.0         33184.0
# 1                  40588         35865.0         39653.0
# 2                  47365         41980.0         46619.0
# 3                  53590         48008.0         53790.0
# 4                  59288         54221.0         59344.0
# ...                  ...             ...             ...
# 2182632            78677         75659.0         79491.0
# 2182633            42098         38607.0         42454.0
# 2182634            48149         43990.0         48039.0
# 2182635            52723         49622.0         54138.0
# 2182636            58565         54905.0         59262.0
#
# [2182637 rows x 9 columns]

# %%
df_trips_simple=df_trips[['DayOfService','TripID','LineID','RouteID']]
df_trips_simple
# Out:
#         DayOfService   TripID LineID RouteID
# 0         2018-01-01  5955277     16   16_20
# 1         2018-01-01  5955278     16   16_24
# 2         2018-01-01  5955279     16   16_20
# 3         2018-01-01  5955280     16   16_24
# 4         2018-01-01  5955281     16   16_20
# ...              ...      ...    ...     ...
# 2182632   2018-12-31  8592110     11   11_42
# 2182633   2018-12-31  8592113     7A   7A_85
# 2182634   2018-12-31  8592114     7A   7A_87
# 2182635   2018-12-31  8592115     7A   7A_85
# 2182636   2018-12-31  8592116     7A   7A_87
#
# [2182637 rows x 4 columns]

# %% [markdown]
# ### merge two dataset

# %%
section=pd.merge(df_leaveTime,df_trips_simple,how='left',on=['DayOfService','TripID'])
section
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-08-01  7315261            1         6004            25800
# 1         2018-08-01  7315261            2            3            25861
# 2         2018-08-01  7315261            3          192            26016
# 3         2018-08-01  7315261            4          795            26041
# 4         2018-08-01  7315261            5          796            26069
# ...              ...      ...          ...          ...              ...
# 9515648   2018-08-31  7515232           67          760            61083
# 9515649   2018-08-31  7515232           68          761            61114
# 9515650   2018-08-31  7515232           69          762            61141
# 9515651   2018-08-31  7515232           70          763            61203
# 9515652   2018-08-31  7515232           71          767            61399
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID
# 0                 25849           25849    1000900    120   120_7
# 1                 25957           25971    1000900    120   120_7
# 2                 26210           26210    1000900    120   120_7
# 3                 26236           26236    1000900    120   120_7
# 4                 26253           26269    1000900    120   120_7
# ...                 ...             ...        ...    ...     ...
# 9515648           62245           62262    1000938    39A  39A_43
# 9515649           62301           62307    1000938    39A  39A_43
# 9515650           62333           62333    1000938    39A  39A_43
# 9515651           62416           62416    1000938    39A  39A_43
# 9515652           62653           62653    1000938    39A  39A_43
#
# [9515653 rows x 10 columns]

# %% [markdown]
# ### add previous stops

# %%
section_copy=section[['TripID','StopPointID','ActualTime_Arr']]
section_copy.columns=['TripID_2','StopPoint_2','ActualTime_Arr_2']
section_copy
# Out:
#          TripID_2  StopPoint_2  ActualTime_Arr_2
# 0         7315261         6004             25849
# 1         7315261            3             25957
# 2         7315261          192             26210
# 3         7315261          795             26236
# 4         7315261          796             26253
# ...           ...          ...               ...
# 9515648   7515232          760             62245
# 9515649   7515232          761             62301
# 9515650   7515232          762             62333
# 9515651   7515232          763             62416
# 9515652   7515232          767             62653
#
# [9515653 rows x 3 columns]

# %%
section_copy.drop(axis=0, index=0,inplace=True)
section_copy
# Out:
# D:\Software\Anaconda\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#          TripID_2  StopPoint_2  ActualTime_Arr_2
# 1         7315261            3             25957
# 2         7315261          192             26210
# 3         7315261          795             26236
# 4         7315261          796             26253
# 5         7315261           56             26418
# ...           ...          ...               ...
# 9515648   7515232          760             62245
# 9515649   7515232          761             62301
# 9515650   7515232          762             62333
# 9515651   7515232          763             62416
# 9515652   7515232          767             62653
#
# [9515652 rows x 3 columns]

# %%
# add new rows
section_copy.loc['new_raw'] = '3'
section_copy
# Out:
# D:\Software\Anaconda\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#         TripID_2 StopPoint_2 ActualTime_Arr_2
# 1        7315261           3            25957
# 2        7315261         192            26210
# 3        7315261         795            26236
# 4        7315261         796            26253
# 5        7315261          56            26418
# ...          ...         ...              ...
# 9515649  7515232         761            62301
# 9515650  7515232         762            62333
# 9515651  7515232         763            62416
# 9515652  7515232         767            62653
# new_raw        3           3                3
#
# [9515653 rows x 3 columns]

# %%
# adject the index
section_copy.index=np.arange(0,9515653)
section_copy
# Out:
#         TripID_2 StopPoint_2 ActualTime_Arr_2
# 0        7315261           3            25957
# 1        7315261         192            26210
# 2        7315261         795            26236
# 3        7315261         796            26253
# 4        7315261          56            26418
# ...          ...         ...              ...
# 9515648  7515232         761            62301
# 9515649  7515232         762            62333
# 9515650  7515232         763            62416
# 9515651  7515232         767            62653
# 9515652        3           3                3
#
# [9515653 rows x 3 columns]

# %%
section_combine = pd.concat([section, section_copy], axis=1,ignore_index=True)

# %%
col_name=[]
for col in section.columns:
    col_name.append(col)
col_name.append('TripID_2')
col_name.append('StopPoint_2')
col_name.append('ActualTime_Arr_2')
col_name
# Out:
# ['DayOfService',
#  'TripID',
#  'ProgrNumber',
#  'StopPointID',
#  'PlannedTime_Arr',
#  'ActualTime_Arr',
#  'ActualTime_Dep',
#  'VehicleID',
#  'LineID',
#  'RouteID',
#  'TripID_2',
#  'StopPoint_2',
#  'ActualTime_Arr_2']

# %%
section_combine.columns=col_name
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-08-01  7315261            1         6004            25800
# 1         2018-08-01  7315261            2            3            25861
# 2         2018-08-01  7315261            3          192            26016
# 3         2018-08-01  7315261            4          795            26041
# 4         2018-08-01  7315261            5          796            26069
# ...              ...      ...          ...          ...              ...
# 9515648   2018-08-31  7515232           67          760            61083
# 9515649   2018-08-31  7515232           68          761            61114
# 9515650   2018-08-31  7515232           69          762            61141
# 9515651   2018-08-31  7515232           70          763            61203
# 9515652   2018-08-31  7515232           71          767            61399
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 25849           25849    1000900    120   120_7  7315261
# 1                 25957           25971    1000900    120   120_7  7315261
# 2                 26210           26210    1000900    120   120_7  7315261
# 3                 26236           26236    1000900    120   120_7  7315261
# 4                 26253           26269    1000900    120   120_7  7315261
# ...                 ...             ...        ...    ...     ...      ...
# 9515648           62245           62262    1000938    39A  39A_43  7515232
# 9515649           62301           62307    1000938    39A  39A_43  7515232
# 9515650           62333           62333    1000938    39A  39A_43  7515232
# 9515651           62416           62416    1000938    39A  39A_43  7515232
# 9515652           62653           62653    1000938    39A  39A_43        3
#
#         StopPoint_2 ActualTime_Arr_2
# 0                 3            25957
# 1               192            26210
# 2               795            26236
# 3               796            26253
# 4                56            26418
# ...             ...              ...
# 9515648         761            62301
# 9515649         762            62333
# 9515650         763            62416
# 9515651         767            62653
# 9515652           3                3
#
# [9515653 rows x 13 columns]

# %%
#drop the last rows
section_combine.drop(axis=0, index=9515652,inplace=True)
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-08-01  7315261            1         6004            25800
# 1         2018-08-01  7315261            2            3            25861
# 2         2018-08-01  7315261            3          192            26016
# 3         2018-08-01  7315261            4          795            26041
# 4         2018-08-01  7315261            5          796            26069
# ...              ...      ...          ...          ...              ...
# 9515647   2018-08-31  7515232           66          759            61029
# 9515648   2018-08-31  7515232           67          760            61083
# 9515649   2018-08-31  7515232           68          761            61114
# 9515650   2018-08-31  7515232           69          762            61141
# 9515651   2018-08-31  7515232           70          763            61203
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 25849           25849    1000900    120   120_7  7315261
# 1                 25957           25971    1000900    120   120_7  7315261
# 2                 26210           26210    1000900    120   120_7  7315261
# 3                 26236           26236    1000900    120   120_7  7315261
# 4                 26253           26269    1000900    120   120_7  7315261
# ...                 ...             ...        ...    ...     ...      ...
# 9515647           62133           62142    1000938    39A  39A_43  7515232
# 9515648           62245           62262    1000938    39A  39A_43  7515232
# 9515649           62301           62307    1000938    39A  39A_43  7515232
# 9515650           62333           62333    1000938    39A  39A_43  7515232
# 9515651           62416           62416    1000938    39A  39A_43  7515232
#
#         StopPoint_2 ActualTime_Arr_2
# 0                 3            25957
# 1               192            26210
# 2               795            26236
# 3               796            26253
# 4                56            26418
# ...             ...              ...
# 9515647         760            62245
# 9515648         761            62301
# 9515649         762            62333
# 9515650         763            62416
# 9515651         767            62653
#
# [9515652 rows x 13 columns]

# %%
section_combine['trip_q']=section_combine['TripID_2']-section_combine['TripID']

# %%
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-08-01  7315261            1         6004            25800
# 1         2018-08-01  7315261            2            3            25861
# 2         2018-08-01  7315261            3          192            26016
# 3         2018-08-01  7315261            4          795            26041
# 4         2018-08-01  7315261            5          796            26069
# ...              ...      ...          ...          ...              ...
# 9515647   2018-08-31  7515232           66          759            61029
# 9515648   2018-08-31  7515232           67          760            61083
# 9515649   2018-08-31  7515232           68          761            61114
# 9515650   2018-08-31  7515232           69          762            61141
# 9515651   2018-08-31  7515232           70          763            61203
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 25849           25849    1000900    120   120_7  7315261
# 1                 25957           25971    1000900    120   120_7  7315261
# 2                 26210           26210    1000900    120   120_7  7315261
# 3                 26236           26236    1000900    120   120_7  7315261
# 4                 26253           26269    1000900    120   120_7  7315261
# ...                 ...             ...        ...    ...     ...      ...
# 9515647           62133           62142    1000938    39A  39A_43  7515232
# 9515648           62245           62262    1000938    39A  39A_43  7515232
# 9515649           62301           62307    1000938    39A  39A_43  7515232
# 9515650           62333           62333    1000938    39A  39A_43  7515232
# 9515651           62416           62416    1000938    39A  39A_43  7515232
#
#         StopPoint_2 ActualTime_Arr_2 trip_q
# 0                 3            25957      0
# 1               192            26210      0
# 2               795            26236      0
# 3               796            26253      0
# 4                56            26418      0
# ...             ...              ...    ...
# 9515647         760            62245      0
# 9515648         761            62301      0
# 9515649         762            62333      0
# 9515650         763            62416      0
# 9515651         767            62653      0
#
# [9515652 rows x 14 columns]

# %%
section_combine['trip_q'].value_counts()
# Out:
#  0        9328365
#  1         169359
#  2           2493
#  3           1264
#  9            705
#            ...
#  121            1
#  119            1
#  112            1
#  111            1
# -17171          1
# Name: trip_q, Length: 165, dtype: int64

# %%
# if trip_q !=0, we do not need it 
x=section_combine[section_combine['trip_q']==0]

# %%
x['TravelTime']=x['ActualTime_Arr_2']-x['ActualTime_Dep']
x
# Out:
# D:\Software\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-08-01  7315261            1         6004            25800
# 1         2018-08-01  7315261            2            3            25861
# 2         2018-08-01  7315261            3          192            26016
# 3         2018-08-01  7315261            4          795            26041
# 4         2018-08-01  7315261            5          796            26069
# ...              ...      ...          ...          ...              ...
# 9515647   2018-08-31  7515232           66          759            61029
# 9515648   2018-08-31  7515232           67          760            61083
# 9515649   2018-08-31  7515232           68          761            61114
# 9515650   2018-08-31  7515232           69          762            61141
# 9515651   2018-08-31  7515232           70          763            61203
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 25849           25849    1000900    120   120_7  7315261
# 1                 25957           25971    1000900    120   120_7  7315261
# 2                 26210           26210    1000900    120   120_7  7315261
# 3                 26236           26236    1000900    120   120_7  7315261
# 4                 26253           26269    1000900    120   120_7  7315261
# ...                 ...             ...        ...    ...     ...      ...
# 9515647           62133           62142    1000938    39A  39A_43  7515232
# 9515648           62245           62262    1000938    39A  39A_43  7515232
# 9515649           62301           62307    1000938    39A  39A_43  7515232
# 9515650           62333           62333    1000938    39A  39A_43  7515232
# 9515651           62416           62416    1000938    39A  39A_43  7515232
#
#         StopPoint_2 ActualTime_Arr_2 trip_q TravelTime
# 0                 3            25957      0        108
# 1               192            26210      0        239
# 2               795            26236      0         26
# 3               796            26253      0         17
# 4                56            26418      0        149
# ...             ...              ...    ...        ...
# 9515647         760            62245      0        103
# 9515648         761            62301      0         39
# 9515649         762            62333      0         26
# 9515650         763            62416      0         83
# 9515651         767            62653      0        237
#
# [9328365 rows x 15 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %% [markdown]
# ### there are a lot of unmormal value, drop traveltime which is smaller than 0 first

# %%
x=x[x['TravelTime']>0]

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %%
#drop traveltime >=3000
x=x[x['TravelTime']<3000]

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %%
x.to_csv("../clean_data/aug_section.csv",index=None)
