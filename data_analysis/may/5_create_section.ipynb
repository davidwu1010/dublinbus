# %% [markdown]
# # 1. Introduction

# %% [markdown]
# The purpose of this notebook is to create initial cleaning of the section data, and to export the cleaned data to a csv file.

# %% [markdown]
# # 2. Setup & Data Load

# %% [markdown]
# Import required modules and packages:

# %%
# import pandas for data analysis
import pandas as pd

#import numpy
import numpy as np

# %%
import gc
gc.collect()
# Out:
# 22

# %% [markdown]
# ### load leavetime

# %%
df_leaveTime=pd.read_csv("../clean_data/leavetime_May.csv",index_col=0)
df_leaveTime
# Out:
# D:\Software\Anaconda\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#          DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0          2018-05-01  6648286            1         2353            21300
# 1          2018-05-01  6648286            2         4643            21338
# 2          2018-05-01  6648286            3         4644            21382
# 3          2018-05-01  6648286            4         4645            21410
# 4          2018-05-01  6648286            5         4440            21440
# ...               ...      ...          ...          ...              ...
# 10322090   2018-05-31  6847894           40         1478            83552
# 10322091   2018-05-31  6847894           41         1479            83580
# 10322092   2018-05-31  6847894           42          315            83700
# 10322093   2018-05-31  6847894           44          406            83940
# 10322094   2018-05-31  6847894           45         2810            84069
#
#           ActualTime_Arr  ActualTime_Dep  VehicleID
# 0                  21250           21250    1932333
# 1                  21299           21315    1932333
# 2                  21367           21382    1932333
# 3                  21411           21423    1932333
# 4                  21460           21474    1932333
# ...                  ...             ...        ...
# 10322090           83142           83151    2868366
# 10322091           83244           83255    2868366
# 10322092           83355           83374    2868366
# 10322093           83571           83598    2868366
# 10322094           83686           83686    2868366
#
# [9814186 rows x 8 columns]

# %%
df_leaveTime.sort_values(by=['DayOfService','TripID','ProgrNumber'],ascending=[True,True,True])
# Out:
#          DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0          2018-05-01  6648286            1         2353            21300
# 1          2018-05-01  6648286            2         4643            21338
# 2          2018-05-01  6648286            3         4644            21382
# 3          2018-05-01  6648286            4         4645            21410
# 4          2018-05-01  6648286            5         4440            21440
# ...               ...      ...          ...          ...              ...
# 10322090   2018-05-31  6847894           40         1478            83552
# 10322091   2018-05-31  6847894           41         1479            83580
# 10322092   2018-05-31  6847894           42          315            83700
# 10322093   2018-05-31  6847894           44          406            83940
# 10322094   2018-05-31  6847894           45         2810            84069
#
#           ActualTime_Arr  ActualTime_Dep  VehicleID
# 0                  21250           21250    1932333
# 1                  21299           21315    1932333
# 2                  21367           21382    1932333
# 3                  21411           21423    1932333
# 4                  21460           21474    1932333
# ...                  ...             ...        ...
# 10322090           83142           83151    2868366
# 10322091           83244           83255    2868366
# 10322092           83355           83374    2868366
# 10322093           83571           83598    2868366
# 10322094           83686           83686    2868366
#
# [9814186 rows x 8 columns]

# %%
df_leaveTime.columns
# Out:
# Index(['DayOfService', 'TripID', 'ProgrNumber', 'StopPointID',
#        'PlannedTime_Arr', 'ActualTime_Arr', 'ActualTime_Dep', 'VehicleID'],
#       dtype='object')

# %% [markdown]
# ### load trips

# %%
df_trips=pd.read_csv("../initial_data/RT_Trips.csv",index_col=0)
df_trips
# Out:
# D:\Software\Anaconda\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#         ActualTime_Arr  ActualTime_Dep DayOfService Direction  LineID  \
# 0           2018-01-01         5955277           16     16_20       1
# 1           2018-01-01         5955278           16     16_24       2
# 2           2018-01-01         5955279           16     16_20       1
# 3           2018-01-01         5955280           16     16_24       2
# 4           2018-01-01         5955281           16     16_20       1
# ...                ...             ...          ...       ...     ...
# 2182632     2018-12-31         8592110           11     11_42       2
# 2182633     2018-12-31         8592113           7A     7A_85       1
# 2182634     2018-12-31         8592114           7A     7A_87       2
# 2182635     2018-12-31         8592115           7A     7A_85       1
# 2182636     2018-12-31         8592116           7A     7A_87       2
#
#          PlannedTime_Arr  PlannedTime_Dep  RouteID   TripID
# 0                  30000            33932  30029.0  33184.0
# 1                  36000            40588  35865.0  39653.0
# 2                  42000            47365  41980.0  46619.0
# 3                  48000            53590  48008.0  53790.0
# 4                  54000            59288  54221.0  59344.0
# ...                  ...              ...      ...      ...
# 2182632            75600            78677  75659.0  79491.0
# 2182633            38700            42098  38607.0  42454.0
# 2182634            44100            48149  43990.0  48039.0
# 2182635            49500            52723  49622.0  54138.0
# 2182636            54900            58565  54905.0  59262.0
#
# [2182637 rows x 9 columns]

# %%
df_trips.columns=['DayOfService','TripID','LineID','RouteID','Direction','PlannedTime_Dep','PlannedTime_Arr','ActualTime_Dep','ActualTime_Arr']
df_trips
# Out:
#         DayOfService   TripID LineID RouteID  Direction  PlannedTime_Dep  \
# 0         2018-01-01  5955277     16   16_20          1            30000
# 1         2018-01-01  5955278     16   16_24          2            36000
# 2         2018-01-01  5955279     16   16_20          1            42000
# 3         2018-01-01  5955280     16   16_24          2            48000
# 4         2018-01-01  5955281     16   16_20          1            54000
# ...              ...      ...    ...     ...        ...              ...
# 2182632   2018-12-31  8592110     11   11_42          2            75600
# 2182633   2018-12-31  8592113     7A   7A_85          1            38700
# 2182634   2018-12-31  8592114     7A   7A_87          2            44100
# 2182635   2018-12-31  8592115     7A   7A_85          1            49500
# 2182636   2018-12-31  8592116     7A   7A_87          2            54900
#
#          PlannedTime_Arr  ActualTime_Dep  ActualTime_Arr
# 0                  33932         30029.0         33184.0
# 1                  40588         35865.0         39653.0
# 2                  47365         41980.0         46619.0
# 3                  53590         48008.0         53790.0
# 4                  59288         54221.0         59344.0
# ...                  ...             ...             ...
# 2182632            78677         75659.0         79491.0
# 2182633            42098         38607.0         42454.0
# 2182634            48149         43990.0         48039.0
# 2182635            52723         49622.0         54138.0
# 2182636            58565         54905.0         59262.0
#
# [2182637 rows x 9 columns]

# %%
df_trips_simple=df_trips[['DayOfService','TripID','LineID','RouteID']]
df_trips_simple
# Out:
#         DayOfService   TripID LineID RouteID
# 0         2018-01-01  5955277     16   16_20
# 1         2018-01-01  5955278     16   16_24
# 2         2018-01-01  5955279     16   16_20
# 3         2018-01-01  5955280     16   16_24
# 4         2018-01-01  5955281     16   16_20
# ...              ...      ...    ...     ...
# 2182632   2018-12-31  8592110     11   11_42
# 2182633   2018-12-31  8592113     7A   7A_85
# 2182634   2018-12-31  8592114     7A   7A_87
# 2182635   2018-12-31  8592115     7A   7A_85
# 2182636   2018-12-31  8592116     7A   7A_87
#
# [2182637 rows x 4 columns]

# %% [markdown]
# ### merge two dataset

# %%
section=pd.merge(df_leaveTime,df_trips_simple,how='left',on=['DayOfService','TripID'])
section
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-05-01  6648286            1         2353            21300
# 1         2018-05-01  6648286            2         4643            21338
# 2         2018-05-01  6648286            3         4644            21382
# 3         2018-05-01  6648286            4         4645            21410
# 4         2018-05-01  6648286            5         4440            21440
# ...              ...      ...          ...          ...              ...
# 9814181   2018-05-31  6847894           40         1478            83552
# 9814182   2018-05-31  6847894           41         1479            83580
# 9814183   2018-05-31  6847894           42          315            83700
# 9814184   2018-05-31  6847894           44          406            83940
# 9814185   2018-05-31  6847894           45         2810            84069
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID
# 0                 21250           21250    1932333     27    27_9
# 1                 21299           21315    1932333     27    27_9
# 2                 21367           21382    1932333     27    27_9
# 3                 21411           21423    1932333     27    27_9
# 4                 21460           21474    1932333     27    27_9
# ...                 ...             ...        ...    ...     ...
# 9814181           83142           83151    2868366    66A  66A_38
# 9814182           83244           83255    2868366    66A  66A_38
# 9814183           83355           83374    2868366    66A  66A_38
# 9814184           83571           83598    2868366    66A  66A_38
# 9814185           83686           83686    2868366    66A  66A_38
#
# [9814186 rows x 10 columns]

# %% [markdown]
# ### add previous stops

# %%
section_copy=section[['TripID','StopPointID','ActualTime_Arr']]
section_copy.columns=['TripID_2','StopPoint_2','ActualTime_Arr_2']
section_copy
# Out:
#          TripID_2  StopPoint_2  ActualTime_Arr_2
# 0         6648286         2353             21250
# 1         6648286         4643             21299
# 2         6648286         4644             21367
# 3         6648286         4645             21411
# 4         6648286         4440             21460
# ...           ...          ...               ...
# 9814181   6847894         1478             83142
# 9814182   6847894         1479             83244
# 9814183   6847894          315             83355
# 9814184   6847894          406             83571
# 9814185   6847894         2810             83686
#
# [9814186 rows x 3 columns]

# %%
section_copy.drop(axis=0, index=0,inplace=True)
section_copy
# Out:
# D:\Software\Anaconda\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#          TripID_2  StopPoint_2  ActualTime_Arr_2
# 1         6648286         4643             21299
# 2         6648286         4644             21367
# 3         6648286         4645             21411
# 4         6648286         4440             21460
# 5         6648286         2628             21505
# ...           ...          ...               ...
# 9814181   6847894         1478             83142
# 9814182   6847894         1479             83244
# 9814183   6847894          315             83355
# 9814184   6847894          406             83571
# 9814185   6847894         2810             83686
#
# [9814185 rows x 3 columns]

# %%
# add new rows
section_copy.loc['new_raw'] = '3'
section_copy
# Out:
# D:\Software\Anaconda\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#         TripID_2 StopPoint_2 ActualTime_Arr_2
# 1        6648286        4643            21299
# 2        6648286        4644            21367
# 3        6648286        4645            21411
# 4        6648286        4440            21460
# 5        6648286        2628            21505
# ...          ...         ...              ...
# 9814182  6847894        1479            83244
# 9814183  6847894         315            83355
# 9814184  6847894         406            83571
# 9814185  6847894        2810            83686
# new_raw        3           3                3
#
# [9814186 rows x 3 columns]

# %%
# adject the index
section_copy.index=np.arange(0,9814186)
section_copy
# Out:
#         TripID_2 StopPoint_2 ActualTime_Arr_2
# 0        6648286        4643            21299
# 1        6648286        4644            21367
# 2        6648286        4645            21411
# 3        6648286        4440            21460
# 4        6648286        2628            21505
# ...          ...         ...              ...
# 9814181  6847894        1479            83244
# 9814182  6847894         315            83355
# 9814183  6847894         406            83571
# 9814184  6847894        2810            83686
# 9814185        3           3                3
#
# [9814186 rows x 3 columns]

# %%
section_combine = pd.concat([section, section_copy], axis=1,ignore_index=True)

# %%
col_name=[]
for col in section.columns:
    col_name.append(col)
col_name.append('TripID_2')
col_name.append('StopPoint_2')
col_name.append('ActualTime_Arr_2')
col_name
# Out:
# ['DayOfService',
#  'TripID',
#  'ProgrNumber',
#  'StopPointID',
#  'PlannedTime_Arr',
#  'ActualTime_Arr',
#  'ActualTime_Dep',
#  'VehicleID',
#  'LineID',
#  'RouteID',
#  'TripID_2',
#  'StopPoint_2',
#  'ActualTime_Arr_2']

# %%
section_combine.columns=col_name
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-05-01  6648286            1         2353            21300
# 1         2018-05-01  6648286            2         4643            21338
# 2         2018-05-01  6648286            3         4644            21382
# 3         2018-05-01  6648286            4         4645            21410
# 4         2018-05-01  6648286            5         4440            21440
# ...              ...      ...          ...          ...              ...
# 9814181   2018-05-31  6847894           40         1478            83552
# 9814182   2018-05-31  6847894           41         1479            83580
# 9814183   2018-05-31  6847894           42          315            83700
# 9814184   2018-05-31  6847894           44          406            83940
# 9814185   2018-05-31  6847894           45         2810            84069
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 21250           21250    1932333     27    27_9  6648286
# 1                 21299           21315    1932333     27    27_9  6648286
# 2                 21367           21382    1932333     27    27_9  6648286
# 3                 21411           21423    1932333     27    27_9  6648286
# 4                 21460           21474    1932333     27    27_9  6648286
# ...                 ...             ...        ...    ...     ...      ...
# 9814181           83142           83151    2868366    66A  66A_38  6847894
# 9814182           83244           83255    2868366    66A  66A_38  6847894
# 9814183           83355           83374    2868366    66A  66A_38  6847894
# 9814184           83571           83598    2868366    66A  66A_38  6847894
# 9814185           83686           83686    2868366    66A  66A_38        3
#
#         StopPoint_2 ActualTime_Arr_2
# 0              4643            21299
# 1              4644            21367
# 2              4645            21411
# 3              4440            21460
# 4              2628            21505
# ...             ...              ...
# 9814181        1479            83244
# 9814182         315            83355
# 9814183         406            83571
# 9814184        2810            83686
# 9814185           3                3
#
# [9814186 rows x 13 columns]

# %%
#drop the last rows
section_combine.drop(axis=0, index=9814185,inplace=True)
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-05-01  6648286            1         2353            21300
# 1         2018-05-01  6648286            2         4643            21338
# 2         2018-05-01  6648286            3         4644            21382
# 3         2018-05-01  6648286            4         4645            21410
# 4         2018-05-01  6648286            5         4440            21440
# ...              ...      ...          ...          ...              ...
# 9814180   2018-05-31  6847894           39         7453            83510
# 9814181   2018-05-31  6847894           40         1478            83552
# 9814182   2018-05-31  6847894           41         1479            83580
# 9814183   2018-05-31  6847894           42          315            83700
# 9814184   2018-05-31  6847894           44          406            83940
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 21250           21250    1932333     27    27_9  6648286
# 1                 21299           21315    1932333     27    27_9  6648286
# 2                 21367           21382    1932333     27    27_9  6648286
# 3                 21411           21423    1932333     27    27_9  6648286
# 4                 21460           21474    1932333     27    27_9  6648286
# ...                 ...             ...        ...    ...     ...      ...
# 9814180           83112           83112    2868366    66A  66A_38  6847894
# 9814181           83142           83151    2868366    66A  66A_38  6847894
# 9814182           83244           83255    2868366    66A  66A_38  6847894
# 9814183           83355           83374    2868366    66A  66A_38  6847894
# 9814184           83571           83598    2868366    66A  66A_38  6847894
#
#         StopPoint_2 ActualTime_Arr_2
# 0              4643            21299
# 1              4644            21367
# 2              4645            21411
# 3              4440            21460
# 4              2628            21505
# ...             ...              ...
# 9814180        1478            83142
# 9814181        1479            83244
# 9814182         315            83355
# 9814183         406            83571
# 9814184        2810            83686
#
# [9814184 rows x 13 columns]

# %%
section_combine['trip_q']=section_combine['TripID_2']-section_combine['TripID']

# %%
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-05-01  6648286            1         2353            21300
# 1         2018-05-01  6648286            2         4643            21338
# 2         2018-05-01  6648286            3         4644            21382
# 3         2018-05-01  6648286            4         4645            21410
# 4         2018-05-01  6648286            5         4440            21440
# ...              ...      ...          ...          ...              ...
# 9814180   2018-05-31  6847894           39         7453            83510
# 9814181   2018-05-31  6847894           40         1478            83552
# 9814182   2018-05-31  6847894           41         1479            83580
# 9814183   2018-05-31  6847894           42          315            83700
# 9814184   2018-05-31  6847894           44          406            83940
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 21250           21250    1932333     27    27_9  6648286
# 1                 21299           21315    1932333     27    27_9  6648286
# 2                 21367           21382    1932333     27    27_9  6648286
# 3                 21411           21423    1932333     27    27_9  6648286
# 4                 21460           21474    1932333     27    27_9  6648286
# ...                 ...             ...        ...    ...     ...      ...
# 9814180           83112           83112    2868366    66A  66A_38  6847894
# 9814181           83142           83151    2868366    66A  66A_38  6847894
# 9814182           83244           83255    2868366    66A  66A_38  6847894
# 9814183           83355           83374    2868366    66A  66A_38  6847894
# 9814184           83571           83598    2868366    66A  66A_38  6847894
#
#         StopPoint_2 ActualTime_Arr_2 trip_q
# 0              4643            21299      0
# 1              4644            21367      0
# 2              4645            21411      0
# 3              4440            21460      0
# 4              2628            21505      0
# ...             ...              ...    ...
# 9814180        1478            83142      0
# 9814181        1479            83244      0
# 9814182         315            83355      0
# 9814183         406            83571      0
# 9814184        2810            83686      0
#
# [9814184 rows x 14 columns]

# %%
section_combine['trip_q'].value_counts()
# Out:
#  0        9621433
#  1         174519
#  2           3028
#  3            967
#  11           717
#            ...
#  177            1
#  181            1
#  186            1
#  187            1
# -17274          1
# Name: trip_q, Length: 179, dtype: int64

# %%
# if trip_q !=0, we do not need it 
x=section_combine[section_combine['trip_q']==0]

# %%
x['TravelTime']=x['ActualTime_Arr_2']-x['ActualTime_Dep']
x
# Out:
# D:\Software\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-05-01  6648286            1         2353            21300
# 1         2018-05-01  6648286            2         4643            21338
# 2         2018-05-01  6648286            3         4644            21382
# 3         2018-05-01  6648286            4         4645            21410
# 4         2018-05-01  6648286            5         4440            21440
# ...              ...      ...          ...          ...              ...
# 9814180   2018-05-31  6847894           39         7453            83510
# 9814181   2018-05-31  6847894           40         1478            83552
# 9814182   2018-05-31  6847894           41         1479            83580
# 9814183   2018-05-31  6847894           42          315            83700
# 9814184   2018-05-31  6847894           44          406            83940
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 21250           21250    1932333     27    27_9  6648286
# 1                 21299           21315    1932333     27    27_9  6648286
# 2                 21367           21382    1932333     27    27_9  6648286
# 3                 21411           21423    1932333     27    27_9  6648286
# 4                 21460           21474    1932333     27    27_9  6648286
# ...                 ...             ...        ...    ...     ...      ...
# 9814180           83112           83112    2868366    66A  66A_38  6847894
# 9814181           83142           83151    2868366    66A  66A_38  6847894
# 9814182           83244           83255    2868366    66A  66A_38  6847894
# 9814183           83355           83374    2868366    66A  66A_38  6847894
# 9814184           83571           83598    2868366    66A  66A_38  6847894
#
#         StopPoint_2 ActualTime_Arr_2 trip_q TravelTime
# 0              4643            21299      0         49
# 1              4644            21367      0         52
# 2              4645            21411      0         29
# 3              4440            21460      0         37
# 4              2628            21505      0         31
# ...             ...              ...    ...        ...
# 9814180        1478            83142      0         30
# 9814181        1479            83244      0         93
# 9814182         315            83355      0        100
# 9814183         406            83571      0        197
# 9814184        2810            83686      0         88
#
# [9621433 rows x 15 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %% [markdown]
# ### there are a lot of unmormal value, drop traveltime which is smaller than 0 first

# %%
x=x[x['TravelTime']>0]

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %%
#drop traveltime >=3000
x=x[x['TravelTime']<3000]

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %%
x.to_csv("../clean_data/may_section.csv",index=None)
