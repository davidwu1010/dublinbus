# %% [markdown]
# # 1. Introduction

# %% [markdown]
# The purpose of this notebook is to create initial cleaning of the section data, and to export the cleaned data to a csv file.

# %% [markdown]
# # 2. Setup & Data Load

# %% [markdown]
# Import required modules and packages:

# %%
# import pandas for data analysis
import pandas as pd

#import numpy
import numpy as np

# %%
import gc
gc.collect()
# Out:
# 22

# %% [markdown]
# ### load leavetime

# %%
df_leaveTime=pd.read_csv("../clean_data/leavetime_Sep.csv",index_col=0)
df_leaveTime
# Out:
# D:\Software\Anaconda\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-09-01  7497941            1          248            82200
# 1         2018-09-01  7497941            2          249            82231
# 2         2018-09-01  7497941            3          250            82287
# 3         2018-09-01  7497941            4          251            82320
# 4         2018-09-01  7497941            5          252            82378
# ...              ...      ...          ...          ...              ...
# 9638158   2018-09-30  7792079           23         3126            85273
# 9638174   2018-09-30  7792079           39         3478            86237
# 9638175   2018-09-30  7792079           40         3280            86263
# 9638176   2018-09-30  7792079           41         3282            86307
# 9638177   2018-09-30  7792079           42         3283            86312
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID
# 0                 82232           82232    2172280
# 1                 82263           82263    2172280
# 2                 82279           82279    2172280
# 3                 82294           82294    2172280
# 4                 82325           82325    2172280
# ...                 ...             ...        ...
# 9638158           85485           85485    1000375
# 9638174           86597           86597    1000375
# 9638175           86611           86611    1000375
# 9638176           86651           86651    1000375
# 9638177           86656           86656    1000375
#
# [9158437 rows x 8 columns]

# %%
df_leaveTime.sort_values(by=['DayOfService','TripID','ProgrNumber'],ascending=[True,True,True])
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-09-01  7497941            1          248            82200
# 1         2018-09-01  7497941            2          249            82231
# 2         2018-09-01  7497941            3          250            82287
# 3         2018-09-01  7497941            4          251            82320
# 4         2018-09-01  7497941            5          252            82378
# ...              ...      ...          ...          ...              ...
# 9638158   2018-09-30  7792079           23         3126            85273
# 9638174   2018-09-30  7792079           39         3478            86237
# 9638175   2018-09-30  7792079           40         3280            86263
# 9638176   2018-09-30  7792079           41         3282            86307
# 9638177   2018-09-30  7792079           42         3283            86312
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID
# 0                 82232           82232    2172280
# 1                 82263           82263    2172280
# 2                 82279           82279    2172280
# 3                 82294           82294    2172280
# 4                 82325           82325    2172280
# ...                 ...             ...        ...
# 9638158           85485           85485    1000375
# 9638174           86597           86597    1000375
# 9638175           86611           86611    1000375
# 9638176           86651           86651    1000375
# 9638177           86656           86656    1000375
#
# [9158437 rows x 8 columns]

# %%
df_leaveTime.columns
# Out:
# Index(['DayOfService', 'TripID', 'ProgrNumber', 'StopPointID',
#        'PlannedTime_Arr', 'ActualTime_Arr', 'ActualTime_Dep', 'VehicleID'],
#       dtype='object')

# %% [markdown]
# ### load trips

# %%
df_trips=pd.read_csv("../initial_data/RT_Trips.csv",index_col=0)
df_trips
# Out:
# D:\Software\Anaconda\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#         ActualTime_Arr  ActualTime_Dep DayOfService Direction  LineID  \
# 0           2018-01-01         5955277           16     16_20       1
# 1           2018-01-01         5955278           16     16_24       2
# 2           2018-01-01         5955279           16     16_20       1
# 3           2018-01-01         5955280           16     16_24       2
# 4           2018-01-01         5955281           16     16_20       1
# ...                ...             ...          ...       ...     ...
# 2182632     2018-12-31         8592110           11     11_42       2
# 2182633     2018-12-31         8592113           7A     7A_85       1
# 2182634     2018-12-31         8592114           7A     7A_87       2
# 2182635     2018-12-31         8592115           7A     7A_85       1
# 2182636     2018-12-31         8592116           7A     7A_87       2
#
#          PlannedTime_Arr  PlannedTime_Dep  RouteID   TripID
# 0                  30000            33932  30029.0  33184.0
# 1                  36000            40588  35865.0  39653.0
# 2                  42000            47365  41980.0  46619.0
# 3                  48000            53590  48008.0  53790.0
# 4                  54000            59288  54221.0  59344.0
# ...                  ...              ...      ...      ...
# 2182632            75600            78677  75659.0  79491.0
# 2182633            38700            42098  38607.0  42454.0
# 2182634            44100            48149  43990.0  48039.0
# 2182635            49500            52723  49622.0  54138.0
# 2182636            54900            58565  54905.0  59262.0
#
# [2182637 rows x 9 columns]

# %%
df_trips.columns=['DayOfService','TripID','LineID','RouteID','Direction','PlannedTime_Dep','PlannedTime_Arr','ActualTime_Dep','ActualTime_Arr']
df_trips
# Out:
#         DayOfService   TripID LineID RouteID  Direction  PlannedTime_Dep  \
# 0         2018-01-01  5955277     16   16_20          1            30000
# 1         2018-01-01  5955278     16   16_24          2            36000
# 2         2018-01-01  5955279     16   16_20          1            42000
# 3         2018-01-01  5955280     16   16_24          2            48000
# 4         2018-01-01  5955281     16   16_20          1            54000
# ...              ...      ...    ...     ...        ...              ...
# 2182632   2018-12-31  8592110     11   11_42          2            75600
# 2182633   2018-12-31  8592113     7A   7A_85          1            38700
# 2182634   2018-12-31  8592114     7A   7A_87          2            44100
# 2182635   2018-12-31  8592115     7A   7A_85          1            49500
# 2182636   2018-12-31  8592116     7A   7A_87          2            54900
#
#          PlannedTime_Arr  ActualTime_Dep  ActualTime_Arr
# 0                  33932         30029.0         33184.0
# 1                  40588         35865.0         39653.0
# 2                  47365         41980.0         46619.0
# 3                  53590         48008.0         53790.0
# 4                  59288         54221.0         59344.0
# ...                  ...             ...             ...
# 2182632            78677         75659.0         79491.0
# 2182633            42098         38607.0         42454.0
# 2182634            48149         43990.0         48039.0
# 2182635            52723         49622.0         54138.0
# 2182636            58565         54905.0         59262.0
#
# [2182637 rows x 9 columns]

# %%
df_trips_simple=df_trips[['DayOfService','TripID','LineID','RouteID']]
df_trips_simple
# Out:
#         DayOfService   TripID LineID RouteID
# 0         2018-01-01  5955277     16   16_20
# 1         2018-01-01  5955278     16   16_24
# 2         2018-01-01  5955279     16   16_20
# 3         2018-01-01  5955280     16   16_24
# 4         2018-01-01  5955281     16   16_20
# ...              ...      ...    ...     ...
# 2182632   2018-12-31  8592110     11   11_42
# 2182633   2018-12-31  8592113     7A   7A_85
# 2182634   2018-12-31  8592114     7A   7A_87
# 2182635   2018-12-31  8592115     7A   7A_85
# 2182636   2018-12-31  8592116     7A   7A_87
#
# [2182637 rows x 4 columns]

# %% [markdown]
# ### merge two dataset

# %%
section=pd.merge(df_leaveTime,df_trips_simple,how='left',on=['DayOfService','TripID'])
section
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-09-01  7497941            1          248            82200
# 1         2018-09-01  7497941            2          249            82231
# 2         2018-09-01  7497941            3          250            82287
# 3         2018-09-01  7497941            4          251            82320
# 4         2018-09-01  7497941            5          252            82378
# ...              ...      ...          ...          ...              ...
# 9158432   2018-09-30  7792079           23         3126            85273
# 9158433   2018-09-30  7792079           39         3478            86237
# 9158434   2018-09-30  7792079           40         3280            86263
# 9158435   2018-09-30  7792079           41         3282            86307
# 9158436   2018-09-30  7792079           42         3283            86312
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID
# 0                 82232           82232    2172280     14   14_15
# 1                 82263           82263    2172280     14   14_15
# 2                 82279           82279    2172280     14   14_15
# 3                 82294           82294    2172280     14   14_15
# 4                 82325           82325    2172280     14   14_15
# ...                 ...             ...        ...    ...     ...
# 9158432           85485           85485    1000375     63   63_25
# 9158433           86597           86597    1000375     63   63_25
# 9158434           86611           86611    1000375     63   63_25
# 9158435           86651           86651    1000375     63   63_25
# 9158436           86656           86656    1000375     63   63_25
#
# [9158437 rows x 10 columns]

# %% [markdown]
# ### add previous stops

# %%
section_copy=section[['TripID','StopPointID','ActualTime_Arr']]
section_copy.columns=['TripID_2','StopPoint_2','ActualTime_Arr_2']
section_copy
# Out:
#          TripID_2  StopPoint_2  ActualTime_Arr_2
# 0         7497941          248             82232
# 1         7497941          249             82263
# 2         7497941          250             82279
# 3         7497941          251             82294
# 4         7497941          252             82325
# ...           ...          ...               ...
# 9158432   7792079         3126             85485
# 9158433   7792079         3478             86597
# 9158434   7792079         3280             86611
# 9158435   7792079         3282             86651
# 9158436   7792079         3283             86656
#
# [9158437 rows x 3 columns]

# %%
section_copy.drop(axis=0, index=0,inplace=True)
section_copy
# Out:
# D:\Software\Anaconda\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#          TripID_2  StopPoint_2  ActualTime_Arr_2
# 1         7497941          249             82263
# 2         7497941          250             82279
# 3         7497941          251             82294
# 4         7497941          252             82325
# 5         7497941          255             82368
# ...           ...          ...               ...
# 9158432   7792079         3126             85485
# 9158433   7792079         3478             86597
# 9158434   7792079         3280             86611
# 9158435   7792079         3282             86651
# 9158436   7792079         3283             86656
#
# [9158436 rows x 3 columns]

# %%
# add new rows
section_copy.loc['new_raw'] = '3'
section_copy
# Out:
# D:\Software\Anaconda\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#         TripID_2 StopPoint_2 ActualTime_Arr_2
# 1        7497941         249            82263
# 2        7497941         250            82279
# 3        7497941         251            82294
# 4        7497941         252            82325
# 5        7497941         255            82368
# ...          ...         ...              ...
# 9158433  7792079        3478            86597
# 9158434  7792079        3280            86611
# 9158435  7792079        3282            86651
# 9158436  7792079        3283            86656
# new_raw        3           3                3
#
# [9158437 rows x 3 columns]

# %%
# adject the index
section_copy.index=np.arange(0,9158437)
section_copy
# Out:
#         TripID_2 StopPoint_2 ActualTime_Arr_2
# 0        7497941         249            82263
# 1        7497941         250            82279
# 2        7497941         251            82294
# 3        7497941         252            82325
# 4        7497941         255            82368
# ...          ...         ...              ...
# 9158432  7792079        3478            86597
# 9158433  7792079        3280            86611
# 9158434  7792079        3282            86651
# 9158435  7792079        3283            86656
# 9158436        3           3                3
#
# [9158437 rows x 3 columns]

# %%
section_combine = pd.concat([section, section_copy], axis=1,ignore_index=True)

# %%
col_name=[]
for col in section.columns:
    col_name.append(col)
col_name.append('TripID_2')
col_name.append('StopPoint_2')
col_name.append('ActualTime_Arr_2')
col_name
# Out:
# ['DayOfService',
#  'TripID',
#  'ProgrNumber',
#  'StopPointID',
#  'PlannedTime_Arr',
#  'ActualTime_Arr',
#  'ActualTime_Dep',
#  'VehicleID',
#  'LineID',
#  'RouteID',
#  'TripID_2',
#  'StopPoint_2',
#  'ActualTime_Arr_2']

# %%
section_combine.columns=col_name
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-09-01  7497941            1          248            82200
# 1         2018-09-01  7497941            2          249            82231
# 2         2018-09-01  7497941            3          250            82287
# 3         2018-09-01  7497941            4          251            82320
# 4         2018-09-01  7497941            5          252            82378
# ...              ...      ...          ...          ...              ...
# 9158432   2018-09-30  7792079           23         3126            85273
# 9158433   2018-09-30  7792079           39         3478            86237
# 9158434   2018-09-30  7792079           40         3280            86263
# 9158435   2018-09-30  7792079           41         3282            86307
# 9158436   2018-09-30  7792079           42         3283            86312
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 82232           82232    2172280     14   14_15  7497941
# 1                 82263           82263    2172280     14   14_15  7497941
# 2                 82279           82279    2172280     14   14_15  7497941
# 3                 82294           82294    2172280     14   14_15  7497941
# 4                 82325           82325    2172280     14   14_15  7497941
# ...                 ...             ...        ...    ...     ...      ...
# 9158432           85485           85485    1000375     63   63_25  7792079
# 9158433           86597           86597    1000375     63   63_25  7792079
# 9158434           86611           86611    1000375     63   63_25  7792079
# 9158435           86651           86651    1000375     63   63_25  7792079
# 9158436           86656           86656    1000375     63   63_25        3
#
#         StopPoint_2 ActualTime_Arr_2
# 0               249            82263
# 1               250            82279
# 2               251            82294
# 3               252            82325
# 4               255            82368
# ...             ...              ...
# 9158432        3478            86597
# 9158433        3280            86611
# 9158434        3282            86651
# 9158435        3283            86656
# 9158436           3                3
#
# [9158437 rows x 13 columns]

# %%
#drop the last rows
section_combine.drop(axis=0, index=9158436,inplace=True)
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-09-01  7497941            1          248            82200
# 1         2018-09-01  7497941            2          249            82231
# 2         2018-09-01  7497941            3          250            82287
# 3         2018-09-01  7497941            4          251            82320
# 4         2018-09-01  7497941            5          252            82378
# ...              ...      ...          ...          ...              ...
# 9158431   2018-09-30  7792079           22         5128            85257
# 9158432   2018-09-30  7792079           23         3126            85273
# 9158433   2018-09-30  7792079           39         3478            86237
# 9158434   2018-09-30  7792079           40         3280            86263
# 9158435   2018-09-30  7792079           41         3282            86307
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 82232           82232    2172280     14   14_15  7497941
# 1                 82263           82263    2172280     14   14_15  7497941
# 2                 82279           82279    2172280     14   14_15  7497941
# 3                 82294           82294    2172280     14   14_15  7497941
# 4                 82325           82325    2172280     14   14_15  7497941
# ...                 ...             ...        ...    ...     ...      ...
# 9158431           85444           85455    1000375     63   63_25  7792079
# 9158432           85485           85485    1000375     63   63_25  7792079
# 9158433           86597           86597    1000375     63   63_25  7792079
# 9158434           86611           86611    1000375     63   63_25  7792079
# 9158435           86651           86651    1000375     63   63_25  7792079
#
#         StopPoint_2 ActualTime_Arr_2
# 0               249            82263
# 1               250            82279
# 2               251            82294
# 3               252            82325
# 4               255            82368
# ...             ...              ...
# 9158431        3126            85485
# 9158432        3478            86597
# 9158433        3280            86611
# 9158434        3282            86651
# 9158435        3283            86656
#
# [9158436 rows x 13 columns]

# %%
section_combine['trip_q']=section_combine['TripID_2']-section_combine['TripID']

# %%
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-09-01  7497941            1          248            82200
# 1         2018-09-01  7497941            2          249            82231
# 2         2018-09-01  7497941            3          250            82287
# 3         2018-09-01  7497941            4          251            82320
# 4         2018-09-01  7497941            5          252            82378
# ...              ...      ...          ...          ...              ...
# 9158431   2018-09-30  7792079           22         5128            85257
# 9158432   2018-09-30  7792079           23         3126            85273
# 9158433   2018-09-30  7792079           39         3478            86237
# 9158434   2018-09-30  7792079           40         3280            86263
# 9158435   2018-09-30  7792079           41         3282            86307
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 82232           82232    2172280     14   14_15  7497941
# 1                 82263           82263    2172280     14   14_15  7497941
# 2                 82279           82279    2172280     14   14_15  7497941
# 3                 82294           82294    2172280     14   14_15  7497941
# 4                 82325           82325    2172280     14   14_15  7497941
# ...                 ...             ...        ...    ...     ...      ...
# 9158431           85444           85455    1000375     63   63_25  7792079
# 9158432           85485           85485    1000375     63   63_25  7792079
# 9158433           86597           86597    1000375     63   63_25  7792079
# 9158434           86611           86611    1000375     63   63_25  7792079
# 9158435           86651           86651    1000375     63   63_25  7792079
#
#         StopPoint_2 ActualTime_Arr_2 trip_q
# 0               249            82263      0
# 1               250            82279      0
# 2               251            82294      0
# 3               252            82325      0
# 4               255            82368      0
# ...             ...              ...    ...
# 9158431        3126            85485      0
# 9158432        3478            86597      0
# 9158433        3280            86611      0
# 9158434        3282            86651      0
# 9158435        3283            86656      0
#
# [9158436 rows x 14 columns]

# %%
section_combine['trip_q'].value_counts()
# Out:
#  0        8977713
#  1         162603
#  2           3019
#  3           1191
#  11           613
#            ...
#  156            1
#  136            1
#  138            1
#  141            1
# -17276          1
# Name: trip_q, Length: 177, dtype: int64

# %%
# if trip_q !=0, we do not need it 
x=section_combine[section_combine['trip_q']==0]

# %%
x['TravelTime']=x['ActualTime_Arr_2']-x['ActualTime_Dep']
x
# Out:
# D:\Software\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-09-01  7497941            1          248            82200
# 1         2018-09-01  7497941            2          249            82231
# 2         2018-09-01  7497941            3          250            82287
# 3         2018-09-01  7497941            4          251            82320
# 4         2018-09-01  7497941            5          252            82378
# ...              ...      ...          ...          ...              ...
# 9158431   2018-09-30  7792079           22         5128            85257
# 9158432   2018-09-30  7792079           23         3126            85273
# 9158433   2018-09-30  7792079           39         3478            86237
# 9158434   2018-09-30  7792079           40         3280            86263
# 9158435   2018-09-30  7792079           41         3282            86307
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 82232           82232    2172280     14   14_15  7497941
# 1                 82263           82263    2172280     14   14_15  7497941
# 2                 82279           82279    2172280     14   14_15  7497941
# 3                 82294           82294    2172280     14   14_15  7497941
# 4                 82325           82325    2172280     14   14_15  7497941
# ...                 ...             ...        ...    ...     ...      ...
# 9158431           85444           85455    1000375     63   63_25  7792079
# 9158432           85485           85485    1000375     63   63_25  7792079
# 9158433           86597           86597    1000375     63   63_25  7792079
# 9158434           86611           86611    1000375     63   63_25  7792079
# 9158435           86651           86651    1000375     63   63_25  7792079
#
#         StopPoint_2 ActualTime_Arr_2 trip_q TravelTime
# 0               249            82263      0         31
# 1               250            82279      0         16
# 2               251            82294      0         15
# 3               252            82325      0         31
# 4               255            82368      0         43
# ...             ...              ...    ...        ...
# 9158431        3126            85485      0         30
# 9158432        3478            86597      0       1112
# 9158433        3280            86611      0         14
# 9158434        3282            86651      0         40
# 9158435        3283            86656      0          5
#
# [8977713 rows x 15 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %% [markdown]
# ### there are a lot of unmormal value, drop traveltime which is smaller than 0 first

# %%
x=x[x['TravelTime']>0]

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %%
#drop traveltime >=3000
x=x[x['TravelTime']<3000]

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %%
x.to_csv("../clean_data/sep_section.csv",index=None)
