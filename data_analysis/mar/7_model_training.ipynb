# %% [markdown]
# # 1. Introduction

# %% [markdown]
# The purpose of this notebook is to perform cleaning of the Dublin Bus historical data, merge it with weather data, and train a machine learning model.

# %% [markdown]
# # 2. Setup & Data Load

# %% [markdown]
# Import required modules and packages.

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score 
from sklearn.model_selection import cross_validate
from tqdm import tnrange, tqdm_notebook, tqdm
from datetime import timedelta
from datetime import datetime
from sklearn import metrics

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import scipy.stats as stats
import xgboost as xgb
import requests as r
import pandas as pd
import seaborn as s
import numpy as np
import googlemaps
import postgres
import holidays
import json
import math

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Set the max number of columns & rows to display.

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 500)

# %% [markdown]
# Load the bus data from file.

# %%
#read section csv
section=pd.read_csv('../clean_data/mar_section.csv')

# %%
section.head(10)
# Out:
#   DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0   2018-03-03  6280480            1         7391            45420
# 1   2018-03-03  6280480            2          493            45523
# 2   2018-03-03  6280480            3          494            45603
# 3   2018-03-03  6280480            4          495            45699
# 4   2018-03-03  6280480            5          400            45777
# 5   2018-03-03  6280480            6          346            45833
# 6   2018-03-03  6280480            7          317            45932
# 7   2018-03-03  6280480            8          312            46141
# 8   2018-03-03  6280480            9         1444            46242
# 9   2018-03-03  6280480           10         1445            46305
#
#    ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID  TripID_2  \
# 0           45441           45441    2693231     26   26_24   6280480
# 1           45646           45646    2693231     26   26_24   6280480
# 2           45798           45798    2693231     26   26_24   6280480
# 3           45875           45875    2693231     26   26_24   6280480
# 4           45911           45911    2693231     26   26_24   6280480
# 5           45939           45939    2693231     26   26_24   6280480
# 6           46079           46171    2693231     26   26_24   6280480
# 7           46304           46337    2693231     26   26_24   6280480
# 8           46417           46442    2693231     26   26_24   6280480
# 9           46540           46573    2693231     26   26_24   6280480
#
#    StopPoint_2  ActualTime_Arr_2  trip_q  TravelTime
# 0          493             45646       0         205
# 1          494             45798       0         152
# 2          495             45875       0          77
# 3          400             45911       0          36
# 4          346             45939       0          28
# 5          317             46079       0         140
# 6          312             46304       0         133
# 7         1444             46417       0          80
# 8         1445             46540       0          98
# 9         7078             46717       0         144

# %%
rows = section.shape[0]
cols = section.shape[1]
print()
print("Before any data cleaning, the dataframe contains", rows, "rows and", cols, "columns.")
print()
# Out:
# Before any data cleaning, the dataframe contains 5217044 rows and 15 columns.

# %%
section.dtypes
# Out:
# DayOfService        object
# TripID               int64
# ProgrNumber          int64
# StopPointID          int64
# PlannedTime_Arr      int64
# ActualTime_Arr       int64
# ActualTime_Dep       int64
# VehicleID            int64
# LineID              object
# RouteID             object
# TripID_2             int64
# StopPoint_2          int64
# ActualTime_Arr_2     int64
# trip_q               int64
# TravelTime           int64
# dtype: object

# %% [markdown]
# ### drop useless features

# %%
section.drop(columns=['RouteID','PlannedTime_Arr','VehicleID','RouteID','trip_q'], inplace=True)

# %% [markdown]
# ### add weekday feature, the format of 'DayOfWeek' is that Sunday=1,Monday=2 ... it is more clear to change into Sunday=7, Monday=1 ...

# %%
section['DayOfService']=section['DayOfService'].astype('datetime64[ns]')
section['dayOfWeek']=section['DayOfService'].dt.dayofweek
section
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  ActualTime_Arr  \
# 0         2018-03-03  6280480            1         7391           45441
# 1         2018-03-03  6280480            2          493           45646
# 2         2018-03-03  6280480            3          494           45798
# 3         2018-03-03  6280480            4          495           45875
# 4         2018-03-03  6280480            5          400           45911
# ...              ...      ...          ...          ...             ...
# 5217039   2018-03-21  6390254           36         1019           32356
# 5217040   2018-03-21  6390254           37         1020           32402
# 5217041   2018-03-21  6390254           38         1076           32452
# 5217042   2018-03-21  6390254           39         1021           32486
# 5217043   2018-03-21  6390254           40         6042           32498
#
#          ActualTime_Dep LineID  TripID_2  StopPoint_2  ActualTime_Arr_2  \
# 0                 45441     26   6280480          493             45646
# 1                 45646     26   6280480          494             45798
# 2                 45798     26   6280480          495             45875
# 3                 45875     26   6280480          400             45911
# 4                 45911     26   6280480          346             45939
# ...                 ...    ...       ...          ...               ...
# 5217039           32356    140   6390254         1020             32402
# 5217040           32409    140   6390254         1076             32452
# 5217041           32452    140   6390254         1021             32486
# 5217042           32486    140   6390254         6042             32498
# 5217043           32498    140   6390254         1022             32504
#
#          TravelTime  dayOfWeek
# 0               205          5
# 1               152          5
# 2                77          5
# 3                36          5
# 4                28          5
# ...             ...        ...
# 5217039          46          2
# 5217040          43          2
# 5217041          34          2
# 5217042          12          2
# 5217043           6          2
#
# [5217044 rows x 12 columns]

# %%
section['dayOfWeek']=section['dayOfWeek'].map(lambda day: day+1)

# %%
section['dayOfWeek'].value_counts()
# Out:
# 2    1052776
# 1    1021888
# 3     773459
# 5     679599
# 4     678501
# 7     533120
# 6     477701
# Name: dayOfWeek, dtype: int64

# %% [markdown]
# ### holidays

# %%
ie_holidays = holidays.Ireland()
section['holiday'] = section["DayOfService"].map(lambda x: x in ie_holidays)

# %%
section
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  ActualTime_Arr  \
# 0         2018-03-03  6280480            1         7391           45441
# 1         2018-03-03  6280480            2          493           45646
# 2         2018-03-03  6280480            3          494           45798
# 3         2018-03-03  6280480            4          495           45875
# 4         2018-03-03  6280480            5          400           45911
# ...              ...      ...          ...          ...             ...
# 5217039   2018-03-21  6390254           36         1019           32356
# 5217040   2018-03-21  6390254           37         1020           32402
# 5217041   2018-03-21  6390254           38         1076           32452
# 5217042   2018-03-21  6390254           39         1021           32486
# 5217043   2018-03-21  6390254           40         6042           32498
#
#          ActualTime_Dep LineID  TripID_2  StopPoint_2  ActualTime_Arr_2  \
# 0                 45441     26   6280480          493             45646
# 1                 45646     26   6280480          494             45798
# 2                 45798     26   6280480          495             45875
# 3                 45875     26   6280480          400             45911
# 4                 45911     26   6280480          346             45939
# ...                 ...    ...       ...          ...               ...
# 5217039           32356    140   6390254         1020             32402
# 5217040           32409    140   6390254         1076             32452
# 5217041           32452    140   6390254         1021             32486
# 5217042           32486    140   6390254         6042             32498
# 5217043           32498    140   6390254         1022             32504
#
#          TravelTime  dayOfWeek  holiday
# 0               205          6    False
# 1               152          6    False
# 2                77          6    False
# 3                36          6    False
# 4                28          6    False
# ...             ...        ...      ...
# 5217039          46          3    False
# 5217040          43          3    False
# 5217041          34          3    False
# 5217042          12          3    False
# 5217043           6          3    False
#
# [5217044 rows x 13 columns]

# %% [markdown]
# ## stop information

# %%
stops=pd.read_csv("../clean_data/stop_info.csv",index_col=0)

# %%
stops.head(5)
# Out:
#               StopName        Lat       Lon  StopNumber  \
# 0  Parnell Square West  53.352244 -6.263723           2
# 1  Parnell Square West  53.352309 -6.263811           3
# 2  Parnell Square West  53.352575 -6.264175           4
# 3  Parnell Square West  53.352749 -6.264454           6
# 4  Parnell Square West  53.352841 -6.264570           7
#
#                                routes
# 0  ['38', '38a', '38b', '46a', '46e']
# 1                      ['120', '122']
# 2        ['7', '7a', '7b', '7d', '9']
# 3                        ['155', '4']
# 4   ['13', '140', '40', '40b', '40d']

# %% [markdown]
# ## weather information

# %%
weather=pd.read_csv('../clean_data/his_weather_data.csv')

# %%
weather
# Out:
#               dt  temp  humidity   wind_speed   clouds  weather_main  \
# 0     1514764800  4.15         87        12.86       40         Rain
# 1     1514768400  4.14         87        11.83       75         Rain
# 2     1514772000  4.61         81        12.35       40       Clouds
# 3     1514775600  4.64         81        12.35       40       Clouds
# 4     1514779200  5.04         81        11.83       40       Clouds
# ...          ...   ...        ...          ...      ...          ...
# 8755  1546282800  9.65         76         4.10       75       Clouds
# 8756  1546286400  9.27         81         4.10       75       Clouds
# 8757  1546290000  9.31         81         5.10       75       Clouds
# 8758  1546293600  9.19         81         5.70       75       Clouds
# 8759  1546297200  8.91         81         5.10       75       Clouds
#
#       extre_weather          datetime
# 0                 0     2018/1/1 0:00
# 1                 0     2018/1/1 1:00
# 2                 0     2018/1/1 2:00
# 3                 0     2018/1/1 3:00
# 4                 0     2018/1/1 4:00
# ...             ...               ...
# 8755              0  2018/12/31 19:00
# 8756              0  2018/12/31 20:00
# 8757              0  2018/12/31 21:00
# 8758              0  2018/12/31 22:00
# 8759              0  2018/12/31 23:00
#
# [8760 rows x 8 columns]

# %%
weather.count()
# Out:
# dt               8760
# temp             8760
# humidity         8760
# wind_speed       8760
# clouds           8760
# weather_main     8760
# extre_weather    8760
# datetime         8760
# dtype: int64

# %% [markdown]
# ### load distance

# %%
distance=pd.read_csv("../clean_data/stops_with_distance.csv",index_col=0)

# %%
distance.head(5)
# Out:
#    StopPointID  StopPoint_2  distance
# 0         7347         3669     720.0
# 1         3669         7349     651.0
# 2         7349         1631     533.0
# 3         1631         1632     265.0
# 4         1632         5053     138.0

# %% [markdown]
# ### merge section and distance

# %%
section=pd.merge(section,distance,how='left',on=['StopPointID','StopPoint_2'])
section
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  ActualTime_Arr  \
# 0         2018-03-03  6280480            1         7391           45441
# 1         2018-03-03  6280480            2          493           45646
# 2         2018-03-03  6280480            3          494           45798
# 3         2018-03-03  6280480            4          495           45875
# 4         2018-03-03  6280480            5          400           45911
# ...              ...      ...          ...          ...             ...
# 5217039   2018-03-21  6390254           36         1019           32356
# 5217040   2018-03-21  6390254           37         1020           32402
# 5217041   2018-03-21  6390254           38         1076           32452
# 5217042   2018-03-21  6390254           39         1021           32486
# 5217043   2018-03-21  6390254           40         6042           32498
#
#          ActualTime_Dep LineID  TripID_2  StopPoint_2  ActualTime_Arr_2  \
# 0                 45441     26   6280480          493             45646
# 1                 45646     26   6280480          494             45798
# 2                 45798     26   6280480          495             45875
# 3                 45875     26   6280480          400             45911
# 4                 45911     26   6280480          346             45939
# ...                 ...    ...       ...          ...               ...
# 5217039           32356    140   6390254         1020             32402
# 5217040           32409    140   6390254         1076             32452
# 5217041           32452    140   6390254         1021             32486
# 5217042           32486    140   6390254         6042             32498
# 5217043           32498    140   6390254         1022             32504
#
#          TravelTime  dayOfWeek  holiday  distance
# 0               205          6    False     352.0
# 1               152          6    False     332.0
# 2                77          6    False     395.0
# 3                36          6    False     321.0
# 4                28          6    False     244.0
# ...             ...        ...      ...       ...
# 5217039          46          3    False     154.0
# 5217040          43          3    False     220.0
# 5217041          34          3    False     202.0
# 5217042          12          3    False     142.0
# 5217043           6          3    False      71.0
#
# [5217044 rows x 14 columns]

# %% [markdown]
# ### merge weather and section

# %%
# leavetimes data
# data.plannedARR = data.dayofservice + pd.to_timedelta(data.plannedARR, unit = 'seconds') # in nanoseconds
# data.plannedDEP = data.dayofservice + pd.to_timedelta(data.plannedDEP, unit = 'seconds') # in nanoseconds
section['actualARR'] = section.DayOfService + pd.to_timedelta(section.ActualTime_Arr_2, unit = 'seconds') # in nanoseconds
# data.actualDEP = data.dayofservice + pd.to_timedelta(data.actualDEP, unit = 'seconds') # in nanoseconds

# new columns for combining
# data['time_at_stop'] = data.actualDEP - data.actualARR
section['weather_merge_time'] = section.actualARR.dt.round('H') #  .dt useful
section
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  ActualTime_Arr  \
# 0         2018-03-03  6280480            1         7391           45441
# 1         2018-03-03  6280480            2          493           45646
# 2         2018-03-03  6280480            3          494           45798
# 3         2018-03-03  6280480            4          495           45875
# 4         2018-03-03  6280480            5          400           45911
# ...              ...      ...          ...          ...             ...
# 5217039   2018-03-21  6390254           36         1019           32356
# 5217040   2018-03-21  6390254           37         1020           32402
# 5217041   2018-03-21  6390254           38         1076           32452
# 5217042   2018-03-21  6390254           39         1021           32486
# 5217043   2018-03-21  6390254           40         6042           32498
#
#          ActualTime_Dep LineID  TripID_2  StopPoint_2  ActualTime_Arr_2  \
# 0                 45441     26   6280480          493             45646
# 1                 45646     26   6280480          494             45798
# 2                 45798     26   6280480          495             45875
# 3                 45875     26   6280480          400             45911
# 4                 45911     26   6280480          346             45939
# ...                 ...    ...       ...          ...               ...
# 5217039           32356    140   6390254         1020             32402
# 5217040           32409    140   6390254         1076             32452
# 5217041           32452    140   6390254         1021             32486
# 5217042           32486    140   6390254         6042             32498
# 5217043           32498    140   6390254         1022             32504
#
#          TravelTime  dayOfWeek  holiday  distance           actualARR  \
# 0               205          6    False     352.0 2018-03-03 12:40:46
# 1               152          6    False     332.0 2018-03-03 12:43:18
# 2                77          6    False     395.0 2018-03-03 12:44:35
# 3                36          6    False     321.0 2018-03-03 12:45:11
# 4                28          6    False     244.0 2018-03-03 12:45:39
# ...             ...        ...      ...       ...                 ...
# 5217039          46          3    False     154.0 2018-03-21 09:00:02
# 5217040          43          3    False     220.0 2018-03-21 09:00:52
# 5217041          34          3    False     202.0 2018-03-21 09:01:26
# 5217042          12          3    False     142.0 2018-03-21 09:01:38
# 5217043           6          3    False      71.0 2018-03-21 09:01:44
#
#          weather_merge_time
# 0       2018-03-03 13:00:00
# 1       2018-03-03 13:00:00
# 2       2018-03-03 13:00:00
# 3       2018-03-03 13:00:00
# 4       2018-03-03 13:00:00
# ...                     ...
# 5217039 2018-03-21 09:00:00
# 5217040 2018-03-21 09:00:00
# 5217041 2018-03-21 09:00:00
# 5217042 2018-03-21 09:00:00
# 5217043 2018-03-21 09:00:00
#
# [5217044 rows x 16 columns]

# %%
# timestamp convertion 
def convert_timestamp():
    for i, row in weather.iterrows():
        weather.at[i,'datetime']=datetime.fromtimestamp(row['dt'])
    return 

convert_timestamp()
weather['datetime'] = weather['datetime'].astype('datetime64[ns]')

# %%
#weather['datetime'] = weather.datetime.dt.round('H') #  .dt useful
weather
# Out:
#               dt  temp  humidity   wind_speed   clouds  weather_main  \
# 0     1514764800  4.15         87        12.86       40         Rain
# 1     1514768400  4.14         87        11.83       75         Rain
# 2     1514772000  4.61         81        12.35       40       Clouds
# 3     1514775600  4.64         81        12.35       40       Clouds
# 4     1514779200  5.04         81        11.83       40       Clouds
# ...          ...   ...        ...          ...      ...          ...
# 8755  1546282800  9.65         76         4.10       75       Clouds
# 8756  1546286400  9.27         81         4.10       75       Clouds
# 8757  1546290000  9.31         81         5.10       75       Clouds
# 8758  1546293600  9.19         81         5.70       75       Clouds
# 8759  1546297200  8.91         81         5.10       75       Clouds
#
#       extre_weather            datetime
# 0                 0 2018-01-01 08:00:00
# 1                 0 2018-01-01 09:00:00
# 2                 0 2018-01-01 10:00:00
# 3                 0 2018-01-01 11:00:00
# 4                 0 2018-01-01 12:00:00
# ...             ...                 ...
# 8755              0 2019-01-01 03:00:00
# 8756              0 2019-01-01 04:00:00
# 8757              0 2019-01-01 05:00:00
# 8758              0 2019-01-01 06:00:00
# 8759              0 2019-01-01 07:00:00
#
# [8760 rows x 8 columns]

# %%
weather.columns.str.strip()
# Out:
# Index(['dt', 'temp', 'humidity', 'wind_speed', 'clouds', 'weather_main',
#        'extre_weather', 'datetime'],
#       dtype='object')

# %%
weather.head(1)
# Out:
#            dt  temp  humidity   wind_speed   clouds  weather_main  \
# 0  1514764800  4.15         87        12.86       40         Rain
#
#    extre_weather            datetime
# 0              0 2018-01-01 08:00:00

# %%
weather.dtypes
# Out:
# dt                        int64
# temp                    float64
# humidity                  int64
# wind_speed              float64
# clouds                    int64
# weather_main             object
# extre_weather             int64
# datetime         datetime64[ns]
# dtype: object

# %%
combinedata = section.merge(weather, 
                         left_on='weather_merge_time', 
                         right_on='datetime', 
                         how='left')

# %% [markdown]
# ### add hour features

# %%
combinedata['hour']=combinedata['actualARR'].dt.hour

# %%
combinedata
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  ActualTime_Arr  \
# 0         2018-03-03  6280480            1         7391           45441
# 1         2018-03-03  6280480            2          493           45646
# 2         2018-03-03  6280480            3          494           45798
# 3         2018-03-03  6280480            4          495           45875
# 4         2018-03-03  6280480            5          400           45911
# ...              ...      ...          ...          ...             ...
# 5217039   2018-03-21  6390254           36         1019           32356
# 5217040   2018-03-21  6390254           37         1020           32402
# 5217041   2018-03-21  6390254           38         1076           32452
# 5217042   2018-03-21  6390254           39         1021           32486
# 5217043   2018-03-21  6390254           40         6042           32498
#
#          ActualTime_Dep LineID  TripID_2  StopPoint_2  ActualTime_Arr_2  \
# 0                 45441     26   6280480          493             45646
# 1                 45646     26   6280480          494             45798
# 2                 45798     26   6280480          495             45875
# 3                 45875     26   6280480          400             45911
# 4                 45911     26   6280480          346             45939
# ...                 ...    ...       ...          ...               ...
# 5217039           32356    140   6390254         1020             32402
# 5217040           32409    140   6390254         1076             32452
# 5217041           32452    140   6390254         1021             32486
# 5217042           32486    140   6390254         6042             32498
# 5217043           32498    140   6390254         1022             32504
#
#          TravelTime  dayOfWeek  holiday  distance           actualARR  \
# 0               205          6    False     352.0 2018-03-03 12:40:46
# 1               152          6    False     332.0 2018-03-03 12:43:18
# 2                77          6    False     395.0 2018-03-03 12:44:35
# 3                36          6    False     321.0 2018-03-03 12:45:11
# 4                28          6    False     244.0 2018-03-03 12:45:39
# ...             ...        ...      ...       ...                 ...
# 5217039          46          3    False     154.0 2018-03-21 09:00:02
# 5217040          43          3    False     220.0 2018-03-21 09:00:52
# 5217041          34          3    False     202.0 2018-03-21 09:01:26
# 5217042          12          3    False     142.0 2018-03-21 09:01:38
# 5217043           6          3    False      71.0 2018-03-21 09:01:44
#
#          weather_merge_time          dt  temp  humidity   wind_speed   \
# 0       2018-03-03 13:00:00  1520053200  0.20        100         10.8
# 1       2018-03-03 13:00:00  1520053200  0.20        100         10.8
# 2       2018-03-03 13:00:00  1520053200  0.20        100         10.8
# 3       2018-03-03 13:00:00  1520053200  0.20        100         10.8
# 4       2018-03-03 13:00:00  1520053200  0.20        100         10.8
# ...                     ...         ...   ...        ...          ...
# 5217039 2018-03-21 09:00:00  1521594000  0.72         69          3.6
# 5217040 2018-03-21 09:00:00  1521594000  0.72         69          3.6
# 5217041 2018-03-21 09:00:00  1521594000  0.72         69          3.6
# 5217042 2018-03-21 09:00:00  1521594000  0.72         69          3.6
# 5217043 2018-03-21 09:00:00  1521594000  0.72         69          3.6
#
#          clouds  weather_main  extre_weather            datetime  hour
# 0             75       Clouds              0 2018-03-03 13:00:00    12
# 1             75       Clouds              0 2018-03-03 13:00:00    12
# 2             75       Clouds              0 2018-03-03 13:00:00    12
# 3             75       Clouds              0 2018-03-03 13:00:00    12
# 4             75       Clouds              0 2018-03-03 13:00:00    12
# ...          ...          ...            ...                 ...   ...
# 5217039       42       Clouds              0 2018-03-21 09:00:00     9
# 5217040       42       Clouds              0 2018-03-21 09:00:00     9
# 5217041       42       Clouds              0 2018-03-21 09:00:00     9
# 5217042       42       Clouds              0 2018-03-21 09:00:00     9
# 5217043       42       Clouds              0 2018-03-21 09:00:00     9
#
# [5217044 rows x 25 columns]

# %% [markdown]
# ### save current combinedata

# %%
combinedata.to_csv("../clean_data/mar_combinedata_1.csv")

# %% [markdown]
# ### load current combinedata

# %%
import gc
gc.collect()
# Out:
# 122

# %%
combinedata=pd.read_csv("../clean_data/mar_combinedata_1.csv",index_col=0)

# %% [markdown]
# ## clean combine data

# %%
combinedata.dtypes
# Out:
# DayOfService           object
# TripID                  int64
# ProgrNumber             int64
# StopPointID             int64
# ActualTime_Arr          int64
# ActualTime_Dep          int64
# LineID                 object
# TripID_2                int64
# StopPoint_2             int64
# ActualTime_Arr_2        int64
# TravelTime              int64
# dayOfWeek               int64
# holiday                  bool
# distance              float64
# actualARR              object
# weather_merge_time     object
# dt                      int64
# temp                  float64
# humidity                int64
# wind_speed            float64
# clouds                  int64
# weather_main           object
# extre_weather           int64
# datetime               object
# hour                    int64
# dtype: object

# %%
combinedata['DayOfService']=combinedata['DayOfService'].astype('datetime64[ns]')

# %% [markdown]
# ### 1.drop reduntant features

# %%
# drop reduntant rows
combinedata=combinedata[~combinedata['distance'].isnull()]

# %%
combinedata.isnull().any()
# Out:
# DayOfService          False
# TripID                False
# ProgrNumber           False
# StopPointID           False
# ActualTime_Arr        False
# ActualTime_Dep        False
# LineID                False
# TripID_2              False
# StopPoint_2           False
# ActualTime_Arr_2      False
# TravelTime            False
# dayOfWeek             False
# holiday               False
# distance              False
# actualARR             False
# weather_merge_time    False
# dt                    False
# temp                  False
# humidity              False
# wind_speed            False
# clouds                False
# weather_main          False
# extre_weather         False
# datetime              False
# hour                  False
# dtype: bool

# %% [markdown]
# ### 3.get the Unique Stopid combinations

# %%
# all unique stop combinations for a given lineid.
stop_pairs = combinedata[['StopPointID','StopPoint_2']].drop_duplicates()

print("There are %d unique pairs of stops on line: %s" % (stop_pairs.count()[0], combinedata.LineID.unique()[0]))
# Out:
# There are 6388 unique pairs of stops on line: 26

# %% [markdown]
# ### 4.get useful features

# %%
combinedata.head(1)
# Out:
#   DayOfService   TripID  ProgrNumber  StopPointID  ActualTime_Arr  \
# 0   2018-03-03  6280480            1         7391           45441
#
#    ActualTime_Dep LineID  TripID_2  StopPoint_2  ActualTime_Arr_2  TravelTime  \
# 0           45441     26   6280480          493             45646         205
#
#    dayOfWeek  holiday  distance            actualARR   weather_merge_time  \
# 0          6    False     352.0  2018-03-03 12:40:46  2018-03-03 13:00:00
#
#            dt  temp  humidity   wind_speed   clouds  weather_main  \
# 0  1520053200   0.2        100         10.8       75       Clouds
#
#    extre_weather             datetime  hour
# 0              0  2018-03-03 13:00:00    12

# %%
combinedata.columns
# Out:
# Index(['DayOfService', 'TripID', 'ProgrNumber', 'StopPointID',
#        'ActualTime_Arr', 'ActualTime_Dep', 'LineID', 'TripID_2', 'StopPoint_2',
#        'ActualTime_Arr_2', 'TravelTime', 'dayOfWeek', 'holiday', 'distance',
#        'actualARR', 'weather_merge_time', 'dt', 'temp', 'humidity ',
#        'wind_speed ', 'clouds ', 'weather_main', 'extre_weather', 'datetime',
#        'hour'],
#       dtype='object')

# %%
dataset=combinedata[['hour','StopPointID','StopPoint_2','dayOfWeek','holiday','distance','temp','humidity ','wind_speed ','clouds ','weather_main','extre_weather','TravelTime']]

# %%
dataset
# Out:
#          hour  StopPointID  StopPoint_2  dayOfWeek  holiday  distance  temp  \
# 0          12         7391          493          6    False     352.0  0.20
# 1          12          493          494          6    False     332.0  0.20
# 2          12          494          495          6    False     395.0  0.20
# 3          12          495          400          6    False     321.0  0.20
# 4          12          400          346          6    False     244.0  0.20
# ...       ...          ...          ...        ...      ...       ...   ...
# 5217039     9         1019         1020          3    False     154.0  0.72
# 5217040     9         1020         1076          3    False     220.0  0.72
# 5217041     9         1076         1021          3    False     202.0  0.72
# 5217042     9         1021         6042          3    False     142.0  0.72
# 5217043     9         6042         1022          3    False      71.0  0.72
#
#          humidity   wind_speed   clouds  weather_main  extre_weather  \
# 0              100         10.8       75       Clouds              0
# 1              100         10.8       75       Clouds              0
# 2              100         10.8       75       Clouds              0
# 3              100         10.8       75       Clouds              0
# 4              100         10.8       75       Clouds              0
# ...            ...          ...      ...          ...            ...
# 5217039         69          3.6       42       Clouds              0
# 5217040         69          3.6       42       Clouds              0
# 5217041         69          3.6       42       Clouds              0
# 5217042         69          3.6       42       Clouds              0
# 5217043         69          3.6       42       Clouds              0
#
#          TravelTime
# 0               205
# 1               152
# 2                77
# 3                36
# 4                28
# ...             ...
# 5217039          46
# 5217040          43
# 5217041          34
# 5217042          12
# 5217043           6
#
# [5198339 rows x 13 columns]

# %%
dataset.dtypes
# Out:
# hour               int64
# StopPointID        int64
# StopPoint_2        int64
# dayOfWeek          int64
# holiday             bool
# distance         float64
# temp             float64
# humidity           int64
# wind_speed       float64
# clouds             int64
# weather_main      object
# extre_weather      int64
# TravelTime         int64
# dtype: object

# %%
# Note: travel time is continuous but is needed for comparison
categorical_features = ['hour','holiday', 'dayOfWeek','weather_main','extre_weather']

continuous_features  = ['TravelTime','distance','temp','wind_speed ','clouds ','humidity ']

# %%
corr = combinedata[continuous_features].corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow0_col1 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow0_col3 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow0_col5 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow1_col0 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow1_col2 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow1_col3 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow1_col4 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow1_col5 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow2_col0 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow2_col1 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow2_col3 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow2_col4 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow2_col5 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow3_col2 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow3_col4 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow3_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow4_col0 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow4_col2 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow4_col3 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow4_col5 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow5_col0 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow5_col1 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow5_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow5_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow5_col4 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_28e5647a_dab3_11ea_94ca_5c5f6790922crow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_28e5647a_dab3_11ea_94ca_5c5f6790922c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >TravelTime</th>        <th class="col_heading level0 col1" >distance</th>        <th class="col_heading level0 col2" >temp</th>        <th class="col_heading level0 col3" >wind_speed </th>        <th class="col_heading level0 col4" >clouds </th>        <th class="col_heading level0 col5" >humidity </th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_28e5647a_dab3_11ea_94ca_5c5f6790922clevel0_row0" class="row_heading level0 row0" >TravelTime</th>
#                         <td id="T_28e5647a_dab3_11ea_94ca_5c5f6790922crow0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_28e5647a_dab3_11ea_94ca_5c5f6790922crow0_col1" class="data row0 col1" >0.52</td>
#                         <td id="T_28e5647a_dab3_11ea_94ca_5c5f6790922crow0_col2" class="data row0 col2" >-0.01</td>
#                         <td id="T_28e5647a_dab3_11ea_94ca_5c5f6790922crow0_col3" class="data row0 col3" >-0.04</td>
#                         <td id="T_28e5647a_dab3_11ea_94ca_5c5f6790922crow0_col4" class="data row0 col4" >-0.01</td>
#                         <td id="T_28e5647a_dab3_11ea_94ca_5c5f6790922crow0_col5" class="data row0 col5" >0.04</td>
#             </tr>
#             <tr>
#                         <th id="T_28e5647a_dab3_11ea_94ca_5c5f6790922clevel0_row1" class="row_heading level0 row1" >distance</th>
#                         <td id="T_28e5647a_dab3_11ea_94ca_5c5f6790922crow1_col0" class="data row1 col0" >0.52</td>
#                         <td id="T_28e5647a_dab3_11ea_94ca_5c5f6790922crow1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_28e5647a_dab3_11ea_94ca_5c5f6790922crow1_col2" class="data row1 col2" >0.00</td>
#                         <td id="T_28e5647a_dab3_11ea_94ca_5c5f6790922crow1_col3" class="data row1 col3" >-0.00</td>
#                         <td id="T_28e5647a_dab3_11ea_94ca_5c5f6790922crow1_col4" class="data row1 col4" >-0.00</td>
#                         <td id="T_28e5647a_dab3_11ea_94ca_5c5f6790922crow1_col5" class="data row1 col5" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_28e5647a_dab3_11ea_94ca_5c5f6790922clevel0_row2" class="row_heading level0 row2" >temp</th>
#                         <td id="T_28e5647a_dab3_11ea_94ca_5c5f6790922crow2_col0" class="data row2 col0" >-0.01</td>
#                         <td id="T_28e5647a_dab3_11ea_94ca_5c5f6790922crow2_col1" class="data row2 col1" >0.00</td>
#                         <td id="T_28e5647a_dab3_11ea_94ca_5c5f6790922crow2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_28e5647a_dab3_11ea_94ca_5c5f6790922crow2_col3" class="data row2 col3" >0.14</td>
#                         <td id="T_28e5647a_dab3_11ea_94ca_5c5f6790922crow2_col4" class="data row2 col4" >0.27</td>
#                         <td id="T_28e5647a_dab3_11ea_94ca_5c5f6790922crow2_col5" class="data row2 col5" >-0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_28e5647a_dab3_11ea_94ca_5c5f6790922clevel0_row3" class="row_heading level

# %%
for cat_ft in categorical_features:
    combinedata.boxplot(column=['TravelTime'], by=cat_ft, grid=False, figsize=(15,6), showfliers=False)
    plt.show()

# %% [markdown]
# ### 5. Set up dummy features.

# %%
# set up dummies features
dataset = pd.get_dummies(dataset)
dataset.dtypes
# Out:
# hour                      int64
# StopPointID               int64
# StopPoint_2               int64
# dayOfWeek                 int64
# holiday                    bool
# distance                float64
# temp                    float64
# humidity                  int64
# wind_speed              float64
# clouds                    int64
# extre_weather             int64
# TravelTime                int64
# weather_main_Clear        uint8
# weather_main_Clouds       uint8
# weather_main_Drizzle      uint8
# weather_main_Fog          uint8
# weather_main_Mist         uint8
# weather_main_Rain         uint8
# weather_main_Snow         uint8
# dtype: object

# %% [markdown]
# ### uniform the weather main features

# %%
dataset.columns
# Out:
# Index(['hour', 'StopPointID', 'StopPoint_2', 'dayOfWeek', 'holiday',
#        'distance', 'temp', 'humidity ', 'wind_speed ', 'clouds ',
#        'extre_weather', 'TravelTime', 'weather_main_Clear',
#        'weather_main_Clouds', 'weather_main_Drizzle', 'weather_main_Fog',
#        'weather_main_Mist', 'weather_main_Rain', 'weather_main_Snow'],
#       dtype='object')

# %%
order=['hour',
 'StopPointID',
 'StopPoint_2',
 'dayOfWeek',
 'holiday',
 'distance',
 'temp',
 'humidity ',
 'wind_speed ',
 'clouds ',
 'extre_weather',
 'TravelTime',
 'weather_main_Clear',
 'weather_main_Clouds',
 'weather_main_Drizzle',
 'weather_main_Fog',
 'weather_main_Mist',
 'weather_main_Rain',
 'weather_main_Snow']
dataset=dataset[order]

# %% [markdown]
# ### separate the dataset because of the lack of memory

# %%
dataset_random=dataset.sample(frac=0.5)

# %%
# need to put this in a loop over the pairs of stops. (unique)
target = ['TravelTime']

predictors=[]
for col in dataset.columns:
    predictors.append(col)
  
predictors.remove('TravelTime')
# predictors.remove('LineID')
predictors
# Out:
# ['hour',
#  'StopPointID',
#  'StopPoint_2',
#  'dayOfWeek',
#  'holiday',
#  'distance',
#  'temp',
#  'humidity ',
#  'wind_speed ',
#  'clouds ',
#  'extre_weather',
#  'weather_main_Clear',
#  'weather_main_Clouds',
#  'weather_main_Drizzle',
#  'weather_main_Fog',
#  'weather_main_Mist',
#  'weather_main_Rain',
#  'weather_main_Snow']

# %%
print("There are %d rows in model data" % (dataset_random.count()[0]))
print("Average Travel Time between stops: {}".format(dataset_random.TravelTime.mean()))
# Out:
# There are 2599170 rows in model data
# Average Travel Time between stops: 62.37069295198082

# %% [markdown]
# ### 6.iltering outliers

# %%
travel_time_deviation = dataset_random.TravelTime.std()

# Filter outliers from the dataset
General_dataset = dataset_random[abs(dataset_random.TravelTime-dataset_random.TravelTime.mean()) < 3*travel_time_deviation]

# Show spread of data
General_dataset.TravelTime.hist(bins=150)

# %% [markdown]
# ### 6.Train models

# %%
# ========================= Test/Train Splits ========================== #
X_train, X_test, y_train, y_test = train_test_split(General_dataset[predictors],
                                                     General_dataset[target].values.ravel(), 
                                                     test_size=0.3, 
                                                     shuffle=True)
print("original range is: ",General_dataset.shape[0])
print("training range (70%):\t rows 0 to", round(X_train.shape[0]))
print("test range (30%): \t rows", round(X_train.shape[0]), "to", round(X_train.shape[0]) + X_test.shape[0])
# Out:
# original range is:  2565062
# training range (70%):	 rows 0 to 1795543
# test range (30%): 	 rows 1795543 to 2565062

# %%
# ========================== Making DMatrices ========================== #
General_dtrain = xgb.DMatrix(X_train, label=y_train)
General_dtest = xgb.DMatrix(X_test, label=y_test)

# =========================== Training Model =========================== #

param = {
    'tree_method: gpu_hist'
    'eta':0.05,
    'max_depth':15
}
num_rounds = 10000

General_model = xgb.train(param, General_dtrain, num_rounds, evals=[(General_dtest, 'Test')], verbose_eval=5, early_stopping_rounds=100)

# ============================  Predictions ============================ #
General_xgbpreds = General_model.predict(General_dtest)

# ====================== Feature Importance graph ====================== #
xgb.plot_importance(General_model)
# Out:
# [10:43:25] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { tree_method: gpu_histeta } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	Test-rmse:53.49192
# Will train until Test-rmse hasn't improved in 100 rounds.
# [5]	Test-rmse:26.65891
# [10]	Test-rmse:24.33069
# [15]	Test-rmse:23.73596
# [20]	Test-rmse:23.51675
# [25]	Test-rmse:23.38028
# [30]	Test-rmse:23.27213
# [35]	Test-rmse:23.18651
# [40]	Test-rmse:23.15298
# [45]	Test-rmse:23.11418
# [50]	Test-rmse:23.09539
# [55]	Test-rmse:23.07122
# [60]	Test-rmse:23.06854
# [65]	Test-rmse:23.06254
# [70]	Test-rmse:23.06380
# [75]	Test-rmse:23.05675
# [80]	Test-rmse:23.06252
# [85]	Test-rmse:23.07659
# [90]	Test-rmse:23.08634
# [95]	Test-rmse:23.09762
# [100]	Test-rmse:23.11593
# [105]	Test-rmse:23.13938
# [110]	Test-rmse:23.15775
# [115]	Test-rmse:23.17764
# [120]	Test-rmse:23.19882
# [125]	Test-rmse:23.21966
# [130]	Test-rmse:23.24256
# [135]	Test-rmse:23.25599
# [140]	Test-rmse:23.28061
# [145]	Test-rmse:23.30233
# [150]	Test-rmse:23.32538
# [155]	Test-rmse:23.34442
# [160]	Test-rmse:23.36604
# [165]	Test-rmse:23.37791
# [170]	Test-rmse:23.39259
# Stopping. Best iteration:
# [71]	Test-rmse:23.05616

# %%
General_model.save_model('../model/General_3.model')

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, General_xgbpreds)
print("r2: %.2f%%" % (r2 * 100.0))
# Out:
# r2: 72.35%

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, General_xgbpreds)
print("mse: %.2f%%" % (mse))
# Out:
# mse: 547.42%

# %% [markdown]
# ## Evaluate Models

# %% [markdown]
# ### General Model

# %% [markdown]
# #### Plotting Errors

# %%
import scipy
# ========================= Visualising Errors ========================= #
General_xgbresiduals = General_xgbpreds - y_test

# best fit of data
(xmu, xsigma) = stats.norm.fit(General_xgbresiduals)

# # The histogram of the data
xn, xbins, xpatches = plt.hist(General_xgbresiduals, 100, density=True, facecolor='blue', alpha=0.6)

# add a 'best fit' line
xy = scipy.stats.norm.pdf(xbins, xmu, xsigma)
xl = plt.plot(xbins, xy, 'r--', linewidth=2)
plt.show()

print(xsigma,xmu)
# Out:
# 23.397064770806953 -0.014085228982441769

# %% [markdown]
# #### Cross Validation

# %%
General_rmse = np.sqrt(metrics.mean_squared_error(General_xgbpreds, y_test))

print(f"""
General Model RMSE: {General_rmse}
""")
# Out:
# General Model RMSE: 23.397069010519488

# %% [markdown]
# # linear regression model

# %% [markdown]
# select 60% dataset

# %%
dataset_random=dataset.sample(frac=0.6)

# %%
travel_time_deviation = dataset_random.TravelTime.std()

# Filter outliers from the dataset
General_dataset = dataset_random[abs(dataset_random.TravelTime-dataset_random.TravelTime.mean()) < 3*travel_time_deviation]

# Show spread of data
General_dataset.TravelTime.hist(bins=150)

# %%
# ========================= Test/Train Splits ========================== #
X_train, X_test, y_train, y_test = train_test_split(General_dataset[predictors],
                                                     General_dataset[target].values.ravel(), 
                                                     test_size=0.3, 
                                                     shuffle=True)
print("original range is: ",General_dataset.shape[0])
print("training range (70%):\t rows 0 to", round(X_train.shape[0]))
print("test range (30%): \t rows", round(X_train.shape[0]), "to", round(X_train.shape[0]) + X_test.shape[0])
# Out:
# original range is:  5552932
# training range (70%):	 rows 0 to 3887052
# test range (30%): 	 rows 3887052 to 5552932

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### training the linear regression

# %%
# =========================== Training Model =========================== #

general_linreg = LinearRegression().fit(X_train, y_train)

# ============================  Predictions ============================ #
y_predict = general_linreg.predict(X_test)

# %% [markdown]
# ### evaluate the model

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_predict)
print("r2: %.2f%%" % (r2 * 100.0))
# Out:
# r2: 29.37%

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_predict)
print("mse: %.2f%%" % (mse))
# Out:
# mse: 1166.93%

# %%
import scipy
# ========================= Visualising Errors ========================= #
General_xgbresiduals = y_predict - y_test

# best fit of data
(xmu, xsigma) = stats.norm.fit(General_xgbresiduals)

# # The histogram of the data
xn, xbins, xpatches = plt.hist(General_xgbresiduals, 100, density=True, facecolor='blue', alpha=0.6)

# add a 'best fit' line
xy = scipy.stats.norm.pdf(xbins, xmu, xsigma)
xl = plt.plot(xbins, xy, 'r--', linewidth=2)
plt.show()

print(xsigma,xmu)
# Out:
# 34.160391564336685 -0.011934744646832014

# %% [markdown]
# # ridge algorithm

# %%
dataset_random=dataset.sample(frac=0.6)

# %%
travel_time_deviation = dataset_random.TravelTime.std()

# Filter outliers from the dataset
General_dataset = dataset_random[abs(dataset_random.TravelTime-dataset_random.TravelTime.mean()) < 3*travel_time_deviation]

# Show spread of data
General_dataset.TravelTime.hist(bins=150)

# %%
# ========================= Test/Train Splits ========================== #
X_train, X_test, y_train, y_test = train_test_split(General_dataset[predictors],
                                                     General_dataset[target].values.ravel(), 
                                                     test_size=0.3, 
                                                     shuffle=True)
print("original range is: ",General_dataset.shape[0])
print("training range (70%):\t rows 0 to", round(X_train.shape[0]))
print("test range (30%): \t rows", round(X_train.shape[0]), "to", round(X_train.shape[0]) + X_test.shape[0])
# Out:
# original range is:  5552717
# training range (70%):	 rows 0 to 3886901
# test range (30%): 	 rows 3886901 to 5552717

# %%
# import ridge algorithm
from sklearn.linear_model import Ridge
# 创建岭回归模型的对象
reg = Ridge(alpha=.5)
# 利用训练集训练岭回归模型
general_ridge=reg.fit(X_train, y_train) 
#输出各个系数
reg.coef_
reg.intercept_
# Out:
# 32.552749886021154

# %%
# ============================  Predictions ============================ #
y_predict = general_ridge.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_predict)
print("r2: %.2f%%" % (r2 * 100.0))
# Out:
# r2: 29.14%

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_predict)
print("mse: %.2f%%" % (mse))
# Out:
# mse: 1171.16%

# %%
import scipy
# ========================= Visualising Errors ========================= #
General_xgbresiduals = y_predict - y_test

# best fit of data
(xmu, xsigma) = stats.norm.fit(General_xgbresiduals)

# # The histogram of the data
xn, xbins, xpatches = plt.hist(General_xgbresiduals, 100, density=True, facecolor='blue', alpha=0.6)

# add a 'best fit' line
xy = scipy.stats.norm.pdf(xbins, xmu, xsigma)
xl = plt.plot(xbins, xy, 'r--', linewidth=2)
plt.show()

print(xsigma,xmu)
# Out:
# 34.2222679272996 0.006885142747784372

# %% [markdown]
# # LightGBM

# %%
dataset_random=dataset.sample(frac=0.6)

# %%
travel_time_deviation = dataset_random.TravelTime.std()

# Filter outliers from the dataset
General_dataset = dataset_random[abs(dataset_random.TravelTime-dataset_random.TravelTime.mean()) < 3*travel_time_deviation]

# Show spread of data
General_dataset.TravelTime.hist(bins=150)

# %%
# ========================= Test/Train Splits ========================== #
X_train, X_test, y_train, y_test = train_test_split(General_dataset[predictors],
                                                     General_dataset[target].values.ravel(), 
                                                     test_size=0.3, 
                                                     shuffle=True)
print("original range is: ",General_dataset.shape[0])
print("training range (70%):\t rows 0 to", round(X_train.shape[0]))
print("test range (30%): \t rows", round(X_train.shape[0]), "to", round(X_train.shape[0]) + X_test.shape[0])
# Out:
# original range is:  5552302
# training range (70%):	 rows 0 to 3886611
# test range (30%): 	 rows 3886611 to 5552302

# %%
# create dataset for lightgbm
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)
# specify your configurations as a dict
params = {
'task': 'train',
'boosting_type': 'gbdt',
'objective': 'regression',
'metric': {'l2', 'auc'},
'num_leaves': 31,
'learning_rate': 0.05,
'feature_fraction': 0.9,
'bagging_fraction': 0.8,
'bagging_freq': 5,
'verbose': 0
}

print('Start training...')
# train
gbm = lgb.train(params,
                lgb_train,
                num_boost_round=20,
                valid_sets=lgb_eval,
                early_stopping_rounds=5)
#print('Save model...')
# save model to file
#gbm.save_model('lightgbm/model.txt')

print('Start predicting...')
# predict
y_pred = gbm.predict(X_test, num_iteration=gbm.best_iteration)
# eval
print(y_pred)
#print('The roc of prediction is:', roc_auc_score(y_test, y_pred) )
#print('Dump model to JSON...')
# dump model to json (and save to file)
#model_json = gbm.dump_model()
#with open('lightgbm/model.json', 'w+') as f:
#json.dump(model_json, f, indent=4)
#print('Feature names:', gbm.feature_name())
print('Calculate feature importances...')
# feature importances
print('Feature importances:', list(gbm.feature_importance()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-37ef5aedb59c> in <module>
#       1 # create dataset for lightgbm
# ----> 2 lgb_train = lgb.Dataset(X_train, y_train)
#       3 lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)
#       4 # specify your configurations as a dict
#       5 params = {
#
# NameError: name 'lgb' is not defined

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print("r2: %.2f%%" % (r2 * 100.0))

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print("mse: %.2f%%" % (mse))

# %%
import scipy
# ========================= Visualising Errors ========================= #
General_xgbresiduals = y_pred - y_test

# best fit of data
(xmu, xsigma) = stats.norm.fit(General_xgbresiduals)

# # The histogram of the data
xn, xbins, xpatches = plt.hist(General_xgbresiduals, 100, density=True, facecolor='blue', alpha=0.6)

# add a 'best fit' line
xy = scipy.stats.norm.pdf(xbins, xmu, xsigma)
xl = plt.plot(xbins, xy, 'r--', linewidth=2)
plt.show()

print(xsigma,xmu)

# %% [markdown]
# ### Stop Wise Models

# %%
stop_pairs
# Out:
#          StopPointID  StopPoint_2
# 0               7347         3669
# 1               3669         7349
# 2               7349         1631
# 3               1631         1632
# 4               1632         5053
# ...              ...          ...
# 9781627         1347         7347
# 9782351          194          198
# 9785484         3677         3679
# 9794998          827           72
# 9806236         1337         1347
#
# [8690 rows x 2 columns]

# %%
# Training Model for all pairs of stops in the dataset

models = dict()
emptys = []
metric = dict()

no_stops = stop_pairs.count()[0]
print("There are %d models to train." % no_stops)

for pair in tqdm_notebook(stop_pairs.iterrows(), desc="Progress: ", total=no_stops):

    # Travelling From A -> B
    A = pair[1][0]
    B = pair[1][1]
    
    
    # ========================= Rows from A -> B =========================== #
    data = dataset[(dataset.StopPoint_2==B)&(dataset.StopPointID==A)]
    
    if data.count()[0] > 10:
    
        # ========================= Removing Outliers ========================== #
        travel_sigma = data.TravelTime.std()

        # Only allow travel times greater than zero 
        data = data[data.TravelTime >= 0]

        # Filter outliers from the dataset [ 2σ as the cutoff ~95% of data ]
        data = data[abs(data.TravelTime - data.TravelTime.mean()) < 2*travel_sigma]

        # ========================= Remove Null Data =========================== #
        data.dropna(inplace=True)

        # ========================= Test/Train Splits ========================== #
        X_train, X_test, y_train, y_test = train_test_split(data[predictors],data[target].values.ravel(), test_size=0.3, shuffle=True)

        # ========================== Making DMatrices ========================== #
        dtrain = xgb.DMatrix(X_train, label=y_train)
        dtest = xgb.DMatrix(X_test, label=y_test)

        # =========================== Training Model =========================== #

        param = {
            'eta': 0.15,
            'max_depth': 6
        }

        num_rounds = 10000

        try:
            
            # ============ Train ============= #
            model = xgb.train(param, dtrain, num_rounds, evals=[(dtest, 'Test')], verbose_eval=False, early_stopping_rounds=100)
            models[f'{A}_{B}'] = model
            
            # ============ Testing Accuracy ========== #
            preds = model.predict(dtest)
            metric[f'{A}_{B}'] = dict()
            metric[f'{A}_{B}']['rmse'] = np.sqrt(metrics.mean_squared_error(preds, y_test))
            metric[f'{A}_{B}']['preds']= preds
            metric[f'{A}_{B}']['ytest']= y_test
            
            
        except Exception as e:
            print(f"Error with route: {A} -> {B}")
            data.head()
            y_train, y_test
            print(repr(e), end='\n================================================\n')
    else:
