# %% [markdown]
# # 1. Introduction

# %% [markdown]
# The purpose of this notebook is to create initial cleaning of the section data, and to export the cleaned data to a csv file.

# %% [markdown]
# # 2. Setup & Data Load

# %% [markdown]
# Import required modules and packages:

# %%
# import pandas for data analysis
import pandas as pd

#import numpy
import numpy as np

# %%
import gc
gc.collect()
# Out:
# 22

# %% [markdown]
# ### load leavetime

# %%
df_leaveTime=pd.read_csv("../clean_data/leavetime_NOV.csv",index_col=0)
df_leaveTime
# Out:
# D:\Software\Anaconda\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-11-01  8064443            1         6318            29160
# 2         2018-11-01  8064443            3         7246            29233
# 3         2018-11-01  8064443            4         6320            29318
# 4         2018-11-01  8064443            5         4594            29419
# 5         2018-11-01  8064443            6         4595            29570
# ...              ...      ...          ...          ...              ...
# 5711078   2018-11-19  8116184            1         4843            74700
# 5711079   2018-11-19  8116184            2         4905            74743
# 5711080   2018-11-19  8116184            4         4906            74785
# 5711081   2018-11-19  8116184            5         4907            74815
# 5711082   2018-11-19  8116184            6         4908            74834
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID
# 0                 29167           29167    2534808
# 2                 29236           29247    2534808
# 3                 29335           29353    2534808
# 4                 29440           29462    2534808
# 5                 29546           29573    2534808
# ...                 ...             ...        ...
# 5711078           74715           74715    1000956
# 5711079           74744           74744    1000956
# 5711080           74779           74779    1000956
# 5711081           74794           74794    1000956
# 5711082           74803           74803    1000956
#
# [5516490 rows x 8 columns]

# %%
df_leaveTime.sort_values(by=['DayOfService','TripID','ProgrNumber'],ascending=[True,True,True])
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-11-01  8064443            1         6318            29160
# 2         2018-11-01  8064443            3         7246            29233
# 3         2018-11-01  8064443            4         6320            29318
# 4         2018-11-01  8064443            5         4594            29419
# 5         2018-11-01  8064443            6         4595            29570
# ...              ...      ...          ...          ...              ...
# 5711078   2018-11-19  8116184            1         4843            74700
# 5711079   2018-11-19  8116184            2         4905            74743
# 5711080   2018-11-19  8116184            4         4906            74785
# 5711081   2018-11-19  8116184            5         4907            74815
# 5711082   2018-11-19  8116184            6         4908            74834
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID
# 0                 29167           29167    2534808
# 2                 29236           29247    2534808
# 3                 29335           29353    2534808
# 4                 29440           29462    2534808
# 5                 29546           29573    2534808
# ...                 ...             ...        ...
# 5711078           74715           74715    1000956
# 5711079           74744           74744    1000956
# 5711080           74779           74779    1000956
# 5711081           74794           74794    1000956
# 5711082           74803           74803    1000956
#
# [5516490 rows x 8 columns]

# %%
df_leaveTime.columns
# Out:
# Index(['DayOfService', 'TripID', 'ProgrNumber', 'StopPointID',
#        'PlannedTime_Arr', 'ActualTime_Arr', 'ActualTime_Dep', 'VehicleID'],
#       dtype='object')

# %% [markdown]
# ### load trips

# %%
df_trips=pd.read_csv("../initial_data/RT_Trips.csv",index_col=0)
df_trips
# Out:
# D:\Software\Anaconda\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#         ActualTime_Arr  ActualTime_Dep DayOfService Direction  LineID  \
# 0           2018-01-01         5955277           16     16_20       1
# 1           2018-01-01         5955278           16     16_24       2
# 2           2018-01-01         5955279           16     16_20       1
# 3           2018-01-01         5955280           16     16_24       2
# 4           2018-01-01         5955281           16     16_20       1
# ...                ...             ...          ...       ...     ...
# 2182632     2018-12-31         8592110           11     11_42       2
# 2182633     2018-12-31         8592113           7A     7A_85       1
# 2182634     2018-12-31         8592114           7A     7A_87       2
# 2182635     2018-12-31         8592115           7A     7A_85       1
# 2182636     2018-12-31         8592116           7A     7A_87       2
#
#          PlannedTime_Arr  PlannedTime_Dep  RouteID   TripID
# 0                  30000            33932  30029.0  33184.0
# 1                  36000            40588  35865.0  39653.0
# 2                  42000            47365  41980.0  46619.0
# 3                  48000            53590  48008.0  53790.0
# 4                  54000            59288  54221.0  59344.0
# ...                  ...              ...      ...      ...
# 2182632            75600            78677  75659.0  79491.0
# 2182633            38700            42098  38607.0  42454.0
# 2182634            44100            48149  43990.0  48039.0
# 2182635            49500            52723  49622.0  54138.0
# 2182636            54900            58565  54905.0  59262.0
#
# [2182637 rows x 9 columns]

# %%
df_trips.columns=['DayOfService','TripID','LineID','RouteID','Direction','PlannedTime_Dep','PlannedTime_Arr','ActualTime_Dep','ActualTime_Arr']
df_trips
# Out:
#         DayOfService   TripID LineID RouteID  Direction  PlannedTime_Dep  \
# 0         2018-01-01  5955277     16   16_20          1            30000
# 1         2018-01-01  5955278     16   16_24          2            36000
# 2         2018-01-01  5955279     16   16_20          1            42000
# 3         2018-01-01  5955280     16   16_24          2            48000
# 4         2018-01-01  5955281     16   16_20          1            54000
# ...              ...      ...    ...     ...        ...              ...
# 2182632   2018-12-31  8592110     11   11_42          2            75600
# 2182633   2018-12-31  8592113     7A   7A_85          1            38700
# 2182634   2018-12-31  8592114     7A   7A_87          2            44100
# 2182635   2018-12-31  8592115     7A   7A_85          1            49500
# 2182636   2018-12-31  8592116     7A   7A_87          2            54900
#
#          PlannedTime_Arr  ActualTime_Dep  ActualTime_Arr
# 0                  33932         30029.0         33184.0
# 1                  40588         35865.0         39653.0
# 2                  47365         41980.0         46619.0
# 3                  53590         48008.0         53790.0
# 4                  59288         54221.0         59344.0
# ...                  ...             ...             ...
# 2182632            78677         75659.0         79491.0
# 2182633            42098         38607.0         42454.0
# 2182634            48149         43990.0         48039.0
# 2182635            52723         49622.0         54138.0
# 2182636            58565         54905.0         59262.0
#
# [2182637 rows x 9 columns]

# %%
df_trips_simple=df_trips[['DayOfService','TripID','LineID','RouteID']]
df_trips_simple
# Out:
#         DayOfService   TripID LineID RouteID
# 0         2018-01-01  5955277     16   16_20
# 1         2018-01-01  5955278     16   16_24
# 2         2018-01-01  5955279     16   16_20
# 3         2018-01-01  5955280     16   16_24
# 4         2018-01-01  5955281     16   16_20
# ...              ...      ...    ...     ...
# 2182632   2018-12-31  8592110     11   11_42
# 2182633   2018-12-31  8592113     7A   7A_85
# 2182634   2018-12-31  8592114     7A   7A_87
# 2182635   2018-12-31  8592115     7A   7A_85
# 2182636   2018-12-31  8592116     7A   7A_87
#
# [2182637 rows x 4 columns]

# %% [markdown]
# ### merge two dataset

# %%
section=pd.merge(df_leaveTime,df_trips_simple,how='left',on=['DayOfService','TripID'])
section
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-11-01  8064443            1         6318            29160
# 1         2018-11-01  8064443            3         7246            29233
# 2         2018-11-01  8064443            4         6320            29318
# 3         2018-11-01  8064443            5         4594            29419
# 4         2018-11-01  8064443            6         4595            29570
# ...              ...      ...          ...          ...              ...
# 5516485   2018-11-19  8116184            1         4843            74700
# 5516486   2018-11-19  8116184            2         4905            74743
# 5516487   2018-11-19  8116184            4         4906            74785
# 5516488   2018-11-19  8116184            5         4907            74815
# 5516489   2018-11-19  8116184            6         4908            74834
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID
# 0                 29167           29167    2534808     15   15_19
# 1                 29236           29247    2534808     15   15_19
# 2                 29335           29353    2534808     15   15_19
# 3                 29440           29462    2534808     15   15_19
# 4                 29546           29573    2534808     15   15_19
# ...                 ...             ...        ...    ...     ...
# 5516485           74715           74715    1000956    41C  41C_79
# 5516486           74744           74744    1000956    41C  41C_79
# 5516487           74779           74779    1000956    41C  41C_79
# 5516488           74794           74794    1000956    41C  41C_79
# 5516489           74803           74803    1000956    41C  41C_79
#
# [5516490 rows x 10 columns]

# %% [markdown]
# ### add previous stops

# %%
section_copy=section[['TripID','StopPointID','ActualTime_Arr']]
section_copy.columns=['TripID_2','StopPoint_2','ActualTime_Arr_2']
section_copy
# Out:
#          TripID_2  StopPoint_2  ActualTime_Arr_2
# 0         8064443         6318             29167
# 1         8064443         7246             29236
# 2         8064443         6320             29335
# 3         8064443         4594             29440
# 4         8064443         4595             29546
# ...           ...          ...               ...
# 5516485   8116184         4843             74715
# 5516486   8116184         4905             74744
# 5516487   8116184         4906             74779
# 5516488   8116184         4907             74794
# 5516489   8116184         4908             74803
#
# [5516490 rows x 3 columns]

# %%
section_copy.drop(axis=0, index=0,inplace=True)
section_copy
# Out:
# D:\Software\Anaconda\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#          TripID_2  StopPoint_2  ActualTime_Arr_2
# 1         8064443         7246             29236
# 2         8064443         6320             29335
# 3         8064443         4594             29440
# 4         8064443         4595             29546
# 5         8064443         4596             29601
# ...           ...          ...               ...
# 5516485   8116184         4843             74715
# 5516486   8116184         4905             74744
# 5516487   8116184         4906             74779
# 5516488   8116184         4907             74794
# 5516489   8116184         4908             74803
#
# [5516489 rows x 3 columns]

# %%
# add new rows
section_copy.loc['new_raw'] = '3'
section_copy
# Out:
# D:\Software\Anaconda\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#         TripID_2 StopPoint_2 ActualTime_Arr_2
# 1        8064443        7246            29236
# 2        8064443        6320            29335
# 3        8064443        4594            29440
# 4        8064443        4595            29546
# 5        8064443        4596            29601
# ...          ...         ...              ...
# 5516486  8116184        4905            74744
# 5516487  8116184        4906            74779
# 5516488  8116184        4907            74794
# 5516489  8116184        4908            74803
# new_raw        3           3                3
#
# [5516490 rows x 3 columns]

# %%
# adject the index
section_copy.index=np.arange(0,5516490)
section_copy
# Out:
#         TripID_2 StopPoint_2 ActualTime_Arr_2
# 0        8064443        7246            29236
# 1        8064443        6320            29335
# 2        8064443        4594            29440
# 3        8064443        4595            29546
# 4        8064443        4596            29601
# ...          ...         ...              ...
# 5516485  8116184        4905            74744
# 5516486  8116184        4906            74779
# 5516487  8116184        4907            74794
# 5516488  8116184        4908            74803
# 5516489        3           3                3
#
# [5516490 rows x 3 columns]

# %%
section_combine = pd.concat([section, section_copy], axis=1,ignore_index=True)

# %%
col_name=[]
for col in section.columns:
    col_name.append(col)
col_name.append('TripID_2')
col_name.append('StopPoint_2')
col_name.append('ActualTime_Arr_2')
col_name
# Out:
# ['DayOfService',
#  'TripID',
#  'ProgrNumber',
#  'StopPointID',
#  'PlannedTime_Arr',
#  'ActualTime_Arr',
#  'ActualTime_Dep',
#  'VehicleID',
#  'LineID',
#  'RouteID',
#  'TripID_2',
#  'StopPoint_2',
#  'ActualTime_Arr_2']

# %%
section_combine.columns=col_name
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-11-01  8064443            1         6318            29160
# 1         2018-11-01  8064443            3         7246            29233
# 2         2018-11-01  8064443            4         6320            29318
# 3         2018-11-01  8064443            5         4594            29419
# 4         2018-11-01  8064443            6         4595            29570
# ...              ...      ...          ...          ...              ...
# 5516484   2018-11-19  8116183           60         4957            73655
# 5516485   2018-11-19  8116184            1         4843            74700
# 5516486   2018-11-19  8116184            2         4905            74743
# 5516487   2018-11-19  8116184            4         4906            74785
# 5516488   2018-11-19  8116184            5         4907            74815
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 29167           29167    2534808     15   15_19  8064443
# 1                 29236           29247    2534808     15   15_19  8064443
# 2                 29335           29353    2534808     15   15_19  8064443
# 3                 29440           29462    2534808     15   15_19  8064443
# 4                 29546           29573    2534808     15   15_19  8064443
# ...                 ...             ...        ...    ...     ...      ...
# 5516484           73843           73843    1000956    41C  41C_78  8116184
# 5516485           74715           74715    1000956    41C  41C_79  8116184
# 5516486           74744           74744    1000956    41C  41C_79  8116184
# 5516487           74779           74779    1000956    41C  41C_79  8116184
# 5516488           74794           74794    1000956    41C  41C_79  8116184
#
#         StopPoint_2 ActualTime_Arr_2
# 0              7246            29236
# 1              6320            29335
# 2              4594            29440
# 3              4595            29546
# 4              4596            29601
# ...             ...              ...
# 5516484        4843            74715
# 5516485        4905            74744
# 5516486        4906            74779
# 5516487        4907            74794
# 5516488        4908            74803
#
# [5516489 rows x 13 columns]

# %%
#drop the last rows
section_combine.drop(axis=0, index=5516489,inplace=True)
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-11-01  8064443            1         6318            29160
# 1         2018-11-01  8064443            3         7246            29233
# 2         2018-11-01  8064443            4         6320            29318
# 3         2018-11-01  8064443            5         4594            29419
# 4         2018-11-01  8064443            6         4595            29570
# ...              ...      ...          ...          ...              ...
# 5516484   2018-11-19  8116183           60         4957            73655
# 5516485   2018-11-19  8116184            1         4843            74700
# 5516486   2018-11-19  8116184            2         4905            74743
# 5516487   2018-11-19  8116184            4         4906            74785
# 5516488   2018-11-19  8116184            5         4907            74815
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 29167           29167    2534808     15   15_19  8064443
# 1                 29236           29247    2534808     15   15_19  8064443
# 2                 29335           29353    2534808     15   15_19  8064443
# 3                 29440           29462    2534808     15   15_19  8064443
# 4                 29546           29573    2534808     15   15_19  8064443
# ...                 ...             ...        ...    ...     ...      ...
# 5516484           73843           73843    1000956    41C  41C_78  8116184
# 5516485           74715           74715    1000956    41C  41C_79  8116184
# 5516486           74744           74744    1000956    41C  41C_79  8116184
# 5516487           74779           74779    1000956    41C  41C_79  8116184
# 5516488           74794           74794    1000956    41C  41C_79  8116184
#
#         StopPoint_2 ActualTime_Arr_2
# 0              7246            29236
# 1              6320            29335
# 2              4594            29440
# 3              4595            29546
# 4              4596            29601
# ...             ...              ...
# 5516484        4843            74715
# 5516485        4905            74744
# 5516486        4906            74779
# 5516487        4907            74794
# 5516488        4908            74803
#
# [5516489 rows x 13 columns]

# %%
section_combine['trip_q']=section_combine['TripID_2']-section_combine['TripID']

# %%
section_combine
# Out:
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-11-01  8064443            1         6318            29160
# 1         2018-11-01  8064443            3         7246            29233
# 2         2018-11-01  8064443            4         6320            29318
# 3         2018-11-01  8064443            5         4594            29419
# 4         2018-11-01  8064443            6         4595            29570
# ...              ...      ...          ...          ...              ...
# 5516484   2018-11-19  8116183           60         4957            73655
# 5516485   2018-11-19  8116184            1         4843            74700
# 5516486   2018-11-19  8116184            2         4905            74743
# 5516487   2018-11-19  8116184            4         4906            74785
# 5516488   2018-11-19  8116184            5         4907            74815
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 29167           29167    2534808     15   15_19  8064443
# 1                 29236           29247    2534808     15   15_19  8064443
# 2                 29335           29353    2534808     15   15_19  8064443
# 3                 29440           29462    2534808     15   15_19  8064443
# 4                 29546           29573    2534808     15   15_19  8064443
# ...                 ...             ...        ...    ...     ...      ...
# 5516484           73843           73843    1000956    41C  41C_78  8116184
# 5516485           74715           74715    1000956    41C  41C_79  8116184
# 5516486           74744           74744    1000956    41C  41C_79  8116184
# 5516487           74779           74779    1000956    41C  41C_79  8116184
# 5516488           74794           74794    1000956    41C  41C_79  8116184
#
#         StopPoint_2 ActualTime_Arr_2 trip_q
# 0              7246            29236      0
# 1              6320            29335      0
# 2              4594            29440      0
# 3              4595            29546      0
# 4              4596            29601      0
# ...             ...              ...    ...
# 5516484        4843            74715      1
# 5516485        4905            74744      0
# 5516486        4906            74779      0
# 5516487        4907            74794      0
# 5516488        4908            74803      0
#
# [5516489 rows x 14 columns]

# %%
section_combine['trip_q'].value_counts()
# Out:
#  0        5410656
#  1          95246
#  2           1997
#  3            573
#  11           404
#            ...
#  136            1
#  138            1
#  146            1
#  147            1
# -16670          1
# Name: trip_q, Length: 160, dtype: int64

# %%
# if trip_q !=0, we do not need it 
x=section_combine[section_combine['trip_q']==0]

# %%
x['TravelTime']=x['ActualTime_Arr_2']-x['ActualTime_Dep']
x
# Out:
# D:\Software\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         DayOfService   TripID  ProgrNumber  StopPointID  PlannedTime_Arr  \
# 0         2018-11-01  8064443            1         6318            29160
# 1         2018-11-01  8064443            3         7246            29233
# 2         2018-11-01  8064443            4         6320            29318
# 3         2018-11-01  8064443            5         4594            29419
# 4         2018-11-01  8064443            6         4595            29570
# ...              ...      ...          ...          ...              ...
# 5516483   2018-11-19  8116183           59         4915            73614
# 5516485   2018-11-19  8116184            1         4843            74700
# 5516486   2018-11-19  8116184            2         4905            74743
# 5516487   2018-11-19  8116184            4         4906            74785
# 5516488   2018-11-19  8116184            5         4907            74815
#
#          ActualTime_Arr  ActualTime_Dep  VehicleID LineID RouteID TripID_2  \
# 0                 29167           29167    2534808     15   15_19  8064443
# 1                 29236           29247    2534808     15   15_19  8064443
# 2                 29335           29353    2534808     15   15_19  8064443
# 3                 29440           29462    2534808     15   15_19  8064443
# 4                 29546           29573    2534808     15   15_19  8064443
# ...                 ...             ...        ...    ...     ...      ...
# 5516483           73800           73807    1000956    41C  41C_78  8116183
# 5516485           74715           74715    1000956    41C  41C_79  8116184
# 5516486           74744           74744    1000956    41C  41C_79  8116184
# 5516487           74779           74779    1000956    41C  41C_79  8116184
# 5516488           74794           74794    1000956    41C  41C_79  8116184
#
#         StopPoint_2 ActualTime_Arr_2 trip_q TravelTime
# 0              7246            29236      0         69
# 1              6320            29335      0         88
# 2              4594            29440      0         87
# 3              4595            29546      0         84
# 4              4596            29601      0         28
# ...             ...              ...    ...        ...
# 5516483        4957            73843      0         36
# 5516485        4905            74744      0         29
# 5516486        4906            74779      0         35
# 5516487        4907            74794      0         15
# 5516488        4908            74803      0          9
#
# [5410656 rows x 15 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %% [markdown]
# ### there are a lot of unmormal value, drop traveltime which is smaller than 0 first

# %%
x=x[x['TravelTime']>0]

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %%
#drop traveltime >=3000
x=x[x['TravelTime']<3000]

# %%
plt.hist(x['TravelTime'], bins=400, facecolor="blue", edgecolor="black")
# x
plt.xlabel("TravelTime")
# y
plt.ylabel("frequency")

plt.show()

# %%
x.to_csv("../clean_data/nov_section.csv",index=None)
